# %%
class Solution:
    def nextPermutation(self, nums: List[int]) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        temp = 0
        if len(nums) == 1:
            return 0
        if len(nums) == 2:
            nums[1] = temp
            nums[1] = nums[0]
            nums[0] = temp
            return 0
        brr = nums.copy()
        brr.pop(0)
        brr.sort(reverse = True)
        if nums[1:] == brr and nums[0] != max(nums):
            temp = nums[0]
            nums[0] = nums [1]
            nums [1] = temp
            return 0
        else:
            nums.sort()
            return 0

        temp = nums[1]
        nums[1] = nums[len(nums)-1]
        nums[len(nums)-1] = temp
        return 0

# %%
class Solution:
    def nextPermutation(self, nums: List[int]) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        ref = nums.copy()
        temp = 0
        if len(nums) == 1:
            print(nums)
            return 0
        if len(nums) == 2:
            # nums[0],nums[1] = nums[1],nums[0]
            temp = nums[0]
            nums[0] = nums[1]
            nums[1] = temp 
            print(nums)
            return 0
        ref.sort(reverse = True)
        if nums[:] == ref[:]:
            nums.sort()
            print(nums)
            return 0
        print(ref)
        # if nums[1:] == ref[1:].sort(reverse = True):
        #     if nums[0] == max(nums):
        #         nums.sort()
        #         print(nums)
        #         return 0
        
        i = len(nums)-2
        j = i+1
        # while i>= 0:
        #     while nums[j]>nums[i]:


        while True:
            while i>=0:
                if nums[j]>nums[i]:
                    print(i,'i')
                    temp = nums[j]
                    nums[j] = nums[i]
                    nums[i] = temp
                    ref = nums[i+1:]
                    ref.sort()
                    nums[i+1:] = ref
                    return 0
                i-=1
            j-=1
            i=j-1
        print('sos')
