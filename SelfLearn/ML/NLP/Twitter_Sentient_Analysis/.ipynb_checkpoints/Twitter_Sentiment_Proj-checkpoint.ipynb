# %%
import pandas as pd
import numpy as np
import nltk

# %%
data = pd.read_csv('training_twitter_x_y_train.csv')
data
# Out:
#                  tweet_id airline_sentiment     airline  \
# 0      567900433542488064          negative   Southwest
# 1      569989168903819264          positive   Southwest
# 2      568089179520954368          positive      United
# 3      568928195581513728          negative   Southwest
# 4      568594180014014464          negative      United
# ...                   ...               ...         ...
# 10975  569934458364813313           neutral    American
# 10976  568564006329434113          positive      United
# 10977  569643648910028801          negative  US Airways
# 10978  568864981917110272          negative  US Airways
# 10979  568929299350179840          negative      United
#
#       airline_sentiment_gold           name negativereason_gold  \
# 0                        NaN  ColeyGirouard                 NaN
# 1                        NaN  WalterFaddoul                 NaN
# 2                        NaN      LocalKyle                 NaN
# 3                        NaN    amccarthy19                 NaN
# 4                        NaN        J_Okayy                 NaN
# ...                      ...            ...                 ...
# 10975                    NaN  Cottopanama85                 NaN
# 10976                    NaN   PaulBEsteves                 NaN
# 10977                    NaN    runfixsteve                 NaN
# 10978                    NaN     CLChicosky                 NaN
# 10979                    NaN     JW_Blocker                 NaN
#
#        retweet_count                                               text  \
# 0                  0  @SouthwestAir I am scheduled for the morning, ...
# 1                  0  @SouthwestAir seeing your workers time in and ...
# 2                  0  @united Flew ORD to Miami and back and  had gr...
# 3                  0     @SouthwestAir @dultch97 that's horse radish 😤🐴
# 4                  0  @united so our flight into ORD was delayed bec...
# ...              ...                                                ...
# 10975              0                            @AmericanAir followback
# 10976              0  @united thanks for the help. Wish the phone re...
# 10977              0  @usairways the. Worst. Ever. #dca #customerser...
# 10978              0  @nrhodes85: look! Another apology. DO NOT FLY ...
# 10979              1  @united you are by far the worst airline. 4 pl...
#
#       tweet_coord              tweet_created              tweet_location  \
# 0             NaN  2015-02-17 20:16:29 -0800             Washington D.C.
# 1             NaN  2015-02-23 14:36:22 -0800  Indianapolis, Indiana; USA
# 2             NaN  2015-02-18 08:46:29 -0800                    Illinois
# 3             NaN  2015-02-20 16:20:26 -0800                         NaN
# 4             NaN  2015-02-19 18:13:11 -0800                         NaN
# ...           ...                        ...                         ...
# 10975         NaN  2015-02-23 10:58:58 -0800                 ohio,panama
# 10976         NaN  2015-02-19 16:13:17 -0800                    Brooklyn
# 10977         NaN  2015-02-22 15:43:24 -0800      St. Augustine, Florida
# 10978         NaN  2015-02-20 12:09:15 -0800                         NaN
# 10979         NaN  2015-02-20 16:24:49 -0800                         NaN
#
#                     user_timezone
# 0          Atlantic Time (Canada)
# 1      Central Time (US & Canada)
# 2      Central Time (US & Canada)
# 3          Atlantic Time (Canada)
# 4      Eastern Time (US & Canada)
# ...                           ...
# 10975                         NaN
# 10976  Eastern Time (US & Canada)
# 10977                         NaN
# 10978                         NaN
# 10979                         NaN
#
# [10980 rows x 12 columns]

# %%
data.drop(['tweet_id','airline_sentiment_gold','name', 'negativereason_gold','retweet_count','tweet_coord','tweet_created','user_timezone','tweet_location','airline'], axis = 1, inplace = True)

# %%
data
# Out:
#       airline_sentiment                                               text
# 0              negative  @SouthwestAir I am scheduled for the morning, ...
# 1              positive  @SouthwestAir seeing your workers time in and ...
# 2              positive  @united Flew ORD to Miami and back and  had gr...
# 3              negative     @SouthwestAir @dultch97 that's horse radish 😤🐴
# 4              negative  @united so our flight into ORD was delayed bec...
# ...                 ...                                                ...
# 10975           neutral                            @AmericanAir followback
# 10976          positive  @united thanks for the help. Wish the phone re...
# 10977          negative  @usairways the. Worst. Ever. #dca #customerser...
# 10978          negative  @nrhodes85: look! Another apology. DO NOT FLY ...
# 10979          negative  @united you are by far the worst airline. 4 pl...
#
# [10980 rows x 2 columns]

# %%
data.isnull().sum()
# Out:
# airline_sentiment    0
# text                 0
# dtype: int64

# %%
x = np.array(data.text)
y = np.array(data.airline_sentiment)
arr = []
for i in range(len(x)):
    arr.append([x[i],y[i]])
arr
# Out:
# [['@SouthwestAir I am scheduled for the morning, 2 days after the fact, yes..not sure why my evening flight was the only one Cancelled Flightled',
#   'negative'],
#  ['@SouthwestAir seeing your workers time in and time out going above and beyond is why I love flying with you guys. Thank you!',
#   'positive'],
#  ['@united Flew ORD to Miami and back and  had great crew, service on both legs. THANKS',
#   'positive'],
#  ["@SouthwestAir @dultch97 that's horse radish 😤🐴", 'negative'],
#  ['@united so our flight into ORD was delayed because of Air Force One, but the last flight to SBN is at 8:20, 5 mins from now we just landed.',
#   'negative'],
#  ['@united Why did you load us in this flying sardine can if you knew the pilots were 2 hours Late Flight?? #incompetent beyond belief',
#   'negative'],
#  ["@JetBlue that is a stock response. Delays not as frustrating as poor cust serv &amp; being told by 3 ppl to wait &amp; they'd come back but did not.",
#   'negative'],
#  ["@JetBlue That'd be nice! Hoping to rack up enough miles to take a trip to Seattle and enjoy a perfect latte in the city of coffee.",
#   'positive'],
#  ['@united frankly worse customer service ever. Problems will happen, how you deal defines a company. Never again United.',
#   'negative'],
#  ["@SouthwestAir yeah haha. Never been in one. It's expensive 😂😂 and we will!!!!! So much fun! #destinationdragons",
#   'positive'],
#  ["@SouthwestAir MCO-&gt;DCA flight almost full of people screwed by the MSY-DCA Cancelled Flightation. @united and @USAirways didn't Cancelled Flight. SWA=mistake.",
#   'negative'],
#  ["@JetBlue what's the easiest way to get a ticket receipt? Can I get one at check in or can I get one online? Thanks!",
#   'neutral'],
#  ['@USAirways - love the changes in the lounge - cheese, veggies, olives in addition to the crackers and snack mix,',
#   'positive'],
#  ['@SouthwestAir I receive bad customer service and ended up spending several hundred dollars to accommodate my family during each cxl flight',
#   'negative'],
#  ["@USAirways you're killing me sche a flight to board 3 min after mine arrived with gate on other side of airport #genious",
#   'negative'],
#  ["@USAirways 8 weeks to refund this ticket - 0372389047497?!? - totally unacceptable.  Fix this or I'll put it on blast on social media and TV",
#   'negative'],
#  ['@AmericanAir no private msg me and will provide details...u really need customer svc training for your staff',
#   'negative'],
#  ["can you not? RT @JetBlue Our fleet's on fleek. http://t.co/413GiAL0yl",
#   'negative'],
#  ['@JetBlue any info on why flight 704 from SJU to JFK is already delayed 2 1/2 hours?',
#   'negative'],
#  ["@AmericanAir, I've tried no less than 8 times today to get in touch with your service desk beginning at 8:30 EST.  I'm having no luck -help!",
#   'negative'],
#  ["@USAirways new problem...had wrong last name on reservation which is airways fixed. New can't get through TSA",
#   'negative'],
#  ['@SouthwestAir Any possible chance of SWA bringing back service between LGA-BWI? It would make it much easier to connect to the west coast.',
#   'neutral'],
#  ['@USAirways @AmericanAir who runs the show at the airport have a boarding pass says us airways and I have to wait in American line #yousuck',
#   'negative'],
#  ["@united computers are down but you stopped giving updates and took my flight info off the app. That's just ridiculous keep people updated!",
#   'negative'],
#  ['@united good fly!! #United #businessFirst', 'positive'],
#  ['@united I am flying from msp to dxb, my child will turn 2 during the trip do I have to buy a return ticket for my child?',
#   'neutral'],
#  ['@JetBlue loves Cancelled Flightling tickets and not telling their customers #flyunited',
#   'negative'],
#  ['@united In ORD, waited 20 min after crew members left before gate items came. Flight attendant sarcastically said good luck and walked away.',
#   'negative'],
#  ['@SouthwestAir Jason (108639) at Gate #3 in SAN made my afternoon!!! #southwestairlines #stellarservice #thanks!',
#   'positive'],
#  ['@AmericanAir everything for sorted out. Thanks for the help. Excited to get home tonight!',
#   'positive'],
#  ['@AmericanAir understand the weather but would be nice to hear an apology on the phone when you moved my flight to an inconvenient day',
#   'negative'],
#  ['@SouthwestAir and thanks!', 'positive'],
#  ["@united it's been booked into first class with curbside delivery 24 hours from now. I'm counting on it! #TeamUSA",
#   'negative'],
#  ["@JetBlue Oh that totally looks on par with @AmericanAir's Admirals Club; any way you can slide us a couple passes? ;)",
#   'positive'],
#  ["@AmericanAir We've 15 official complaints signed by #AmericanAirlines Lima supervisor. Customer Relations pls compensate 4 the 10-hour delay",
#   'negative'],
#  ["@JetBlue but the 4 hour policy- when I called and they said I didn't report it soon enough. What would have changed if I had noticed sooner?",
#   'negative'],
#  ['@united the most frustrating flying experience. One continuous "I dunno what time you will leave today. ". Dunno?! That\'s code for ...?',
#   'negative'],
#  ["@SouthwestAir Hi I just got a message that part of my flights is Cancelled Flightled. I can't rebook online and nobody answers my phone call. Help me",
#   'negative'],
#  ['@SouthwestAir I need updates on my flights 464 &amp; 3574. I have been on hold for over 2 hours.',
#   'negative'],
#  ["@USAirways I'm supposed to fly through Dallas. Can you help me get a new itinerary?",
#   'neutral'],
#  ['@AmericanAir so you fail again flight to rdu sitting waiting on flight attendants. your logistics are not good',
#   'negative'],
#  ['@united I am impressed with your super-fast reply to @CGJase', 'positive'],
#  ["@united no I don't. Spoke with baggage contact at 1-800 number. Said they will try to get bags to stay at IAD for pick up tmrw",
#   'negative'],
#  ['@USAirways Who intentionally buys a flight with a 10 hour layover?  And what kind of airline would charge $200 to fix it? Wow... #usairways',
#   'negative'],
#  ["@SouthwestAir do you do auto callbacks so I don't have to wait on hold?",
#   'negative'],
#  ['@united can I get your service desk # at IAD?', 'neutral'],
#  ["@JetBlue your blue helped bring out the color of my eyes. And I promise I didn't eat all the free snacks.",
#   'positive'],
#  ['@united Yes ! :D (Y) From @therealaviation on Instagram :)', 'positive'],
#  ["@JetBlue I did not report the updated info - don't know how to reach them without a super long wait on hold at your main number.",
#   'negative'],
#  ['@JetBlue I want to enter the family pooling contest, it says "by 2/19" on the website, can I please enter still!',
#   'neutral'],
#  ['@USAirways and that you can choose the same seat for free after clicking 100 buttons.',
#   'neutral'],
#  ['@united plus what about food? And taxis?', 'negative'],
#  ['@USAirways 3hr30min right now...  any end in sight?', 'negative'],
#  ["@SouthwestAir, you're really going to let @delta and @virginamerica get the best of you? http://t.co/vUdWJm1lYB",
#   'negative'],
#  ['@USAirways claims flight Cancelled Flighted due to weather at destination but Delta has not Cancelled Flighted flight on same route.',
#   'negative'],
#  ['@JetBlue thanks so much for help Us, u r amazing!', 'positive'],
#  ["@AmericanAir haha I did. They said it wasn't their fault somehow? You guys r a joke",
#   'negative'],
#  ["@AmericanAir your customer service is inferior to that of a nationalized third world nation's airline. Get it together.",
#   'negative'],
#  ['@AmericanAir Why does your iPhone app not have any sort of notifications option?',
#   'negative'],
#  ['@united thank you!', 'positive'],
#  ["@AmericanAir I've been trying to reach your customer service for TWO days. I have received zero response. Never traveling AA again.",
#   'negative'],
#  ["@united flight 4567 agent now wandered off. Pilots came out looking for her. Went to charge her personal phone which she'd been txting on",
#   'negative'],
#  ['@united first you lost all my bags, now you Cancelled Flight my flight home. 30 min wait to talk to somebody #poorservice #notgoodenough',
#   'negative'],
#  ['@SouthwestAir sat on a plane for 2+ hrs on 2/15! Then we finally took off.. :(',
#   'negative'],
#  ['@JetBlue ANYWHERE!! http://t.co/FeFHPmFPlE', 'neutral'],
#  ['@USAirways I have to spend more than the cost of the flight just to get a free room and transportation to and from the airport',
#   'negative'],
#  ['@SouthwestAir understand the weather, these kids need to get home! Nice kids doing volunteer work from a RI high school, please help',
#   'neutral'],
#  ["@AmericanAir My friend needs some help on her flt (she's not on Twiiter), can I DM you her info?",
#   'neutral'],
#  ['@AmericanAir my mom’s flight tomorrow Cancelled Flighted w/ no notice. Phone system said callback in 2 hours and it’s been 4. I need to go to bed!',
#   'negative'],
#  ['@americanair flight veers off icy runway at @dfwairport. Most DFW flights Cancelled Flighted Mon http://t.co/Q37pOWn6uv @Cowboycerrone figures right?',
#   'negative'],
#  ['@united Could you tell me if this bag would be accepted as a personal item ? Can i bring one carry-on bag plus this? http://t.co/U390cZpLHl',
#   'neutral'],
#  ['@united yo, you need a new website really badly. This day and age...',
#   'negative'],
#  ['@SouthwestAir  @TheEllenShow @Imaginedragons  @kdepetro313 .what a great first night. #DestinationDragons http://t.co/N3LrFo4UaY',
#   'positive'],
#  ['@USAirways right on. Up. Up &amp; away ✈️🌞', 'positive'],
#  ['@united Now about two dozen back in line to see a single CSR for reFlight Booking Problems final leg. (Kiosks on fritz.)',
#   'negative'],
#  ['@JetBlue Why would you charge money to transfer points to someone?',
#   'negative'],
#  ['@USAirways Is it possible to earn Dividend Miles for a passenger that is not me, even if I am purchasing the tickets?',
#   'neutral'],
#  ["Lmfaooo “@JetBlue: Our fleet's on fleek. http://t.co/1G9RnmYUQe”",
#   'positive'],
#  ['@USAirways Is there a phone line to call into that isn\'t being affected by "bad weather"? Trying to book a vacation, here... 👀',
#   'neutral'],
#  ['@AmericanAir I have never seen such incompetency from a gate agent in years of business travel DFW B16 gate agent needs training or new job',
#   'negative'],
#  ['@USAirways F623 DEN:PHX impressive lack of concern by 1hr+ Late Flight flight attndt wrecking havoc on customer travel #smugsmirk #norush',
#   'negative'],
#  ['@united Have clients with an 11 hr layover at IAH (during the day). Will they have to claim &amp; recheck luggage. Or will it be taken care of?',
#   'neutral'],
#  ['@united even so, change could not be made  online- instructed to call an agent- maybe the syastem should allow agents 2 link passengers!',
#   'negative'],
#  ['@united you can\'t claim "weather" with your hardworking crew pulling seats out of a plane! Do the right thing. But we both know you won\'t',
#   'negative'],
#  ["@AmericanAir finally called! Can't get met Seattle so refund will be processed. Thanks",
#   'positive'],
#  ['@United just played the Most bizarre "safety" video I\'ve ever seen... http://t.co/Hlm2Oks6xl',
#   'neutral'],
#  ["@SouthwestAir I'm not sure I did the messaging part right. Please let me know if you received it.",
#   'neutral'],
#  ['@SouthwestAir booked the 8th.... Save me an emergency exit... Gotta stretch out',
#   'neutral'],
#  ['@SouthwestAir do you not try to get customers to their destinations? No help to get on another airline if you had no flights for 3 days?',
#   'negative'],
#  ['@JetBlue no. Did not catch his name. I am sure Jason will know.',
#   'neutral'],
#  ['@USAirways. Yet another delay/missed connection....and your customer service has an attitude with me? Wow.',
#   'negative'],
#  ['@USAirways No access to Dividend Miles and for a week the automated phone keeps telling me to call back Late Flightr. #FRUSTRATED #LivePersonPlease',
#   'negative'],
#  ['@united When will direct flights from Belfast Intl to Newark resume from their winter break? Thanks.',
#   'neutral'],
#  ["@united LGJW7B. I voluntarily rerouted; 1st leg of journey was in economy and was supposed to be 8B. Res agent said she'd reserve it for me",
#   'neutral'],
#  ['@SouthwestAir Nashville airport has runways open. It appears southwest is only airline Cancelled Flighting flights. Is this likely to change?',
#   'negative'],
#  ['@USAirways no my flight plans have been delayed until tuesday due to your computer crash',
#   'negative'],
#  ['@SouthwestAir This is unbelievable... Thank you so much! #DestinationDragons',
#   'positive'],
#  ['@united big surprise #nogate waiting for our plane. Same fucken issues everything I fly you. #fail #worstairlineever',
#   'negative'],
#  ['@USAirways tough night, two 90 minute calls, on hold, delayed here in Phoenix for two days because of one aircraft not ready? Not acceptable',
#   'negative'],
#  ["@united but it's hard to stay upset at someone when they at least TRY to show remorse.",
#   'negative'],
#  ['@united 50 min on hold trying to book award flight because site errors out.  Agents ask for my pin to see platinum availability??? badbadbad',
#   'negative'],
#  ['@USAirways 23 min on hold... Drove 2.5 hours to get my delayed bag. I just want to pick it up at SJU.',
#   'negative'],
#  ['@USAirways how do I reserve my seat on the AA flight I transfer to from ORD to EVV?',
#   'neutral'],
#  ['@United to start 3xdaily @EmbraerSA #ERJ145 flights from #Chicago @fly2ohare to #Evansville on 4JUN #avgeek',
#   'neutral'],
#  ['@united flight 1136 from Chicago to Houston over 2 hours and no pretzels or peanuts?! Seriously about passed out.',
#   'negative'],
#  ['@united I left my comment with customer care. Thanks for contacting me.',
#   'positive'],
#  ['@united They held the plane! Made it!!', 'positive'],
#  ["@AmericanAir That's ok...You may keep my $25 and lose my bag with no info, but you no longer have my trust. Bad way to handle this.",
#   'negative'],
#  ['@VirginAmerica is that #thestarter??😁', 'neutral'],
#  ['@JetBlue Learning about your awesome twitter management today in my Social Media Marketing class! keep up the good work! @SXU @PhD_Mama_',
#   'positive'],
#  ['@AmericanAir dropping the ball. Again. No catering. Plane switch. No gate attendant. 2 hours Late Flight. Really nice.',
#   'negative'],
#  ['@AmericanAir good care of their customers if anything happen to then take you @Delta  for getting me back to NYC !! Screw you @AmericanAir',
#   'negative'],
#  ["@AmericanAir I don't think you should help him at all based on his behavior. The voucher and cot seem like enough lol 😃",
#   'neutral'],
#  ["@united I think problem resolution should be decided on your end. Especially if you'd like me to continue flying your airline.",
#   'negative'],
#  ["@USAirways I've been on hold for 36 mins and counting cause you charged my credit card for bag but provided no receipt and said error. Awful",
#   'negative'],
#  ['@united great. Looking forward to your response to my DM then', 'positive'],
#  ["@united it's my 21st birthday and my sister is coming to celebrate but her flights keep Cancelled Flighting PLZ do all you can to get her here!!!!",
#   'negative'],
#  ['@USAirways UR employee named VAN @ ticket counter in #Philadelphia. EXTREMELY RUDE! a Father trying to get home to sick kid missed flight.',
#   'negative'],
#  ['@SouthwestAir Horrible experience ever with airline..Have to reconsider any future flights. Customer service ... http://t.co/EczHcmM5vi',
#   'negative'],
#  ['@AmericanAir for tomorrow some sites show flight 1642 from ewr Cancelled Flightled, is it?',
#   'negative'],
#  ['@VirginAmerica I like the customer service but a 40 min delay just for connecting passengers seems too long. VA370',
#   'negative'],
#  ["@VirginAmerica cutest salt and pepper shaker ever. Just when I think you guys can't get any better you just do! http://t.co/vC6Keulg2J",
#   'positive'],
#  ['@AmericanAir Unbelievable that I cannot even wait on hold to speak to a human being to resolve my issue!!!!!!!! The system simply hangs up!',
#   'negative'],
#  ["@AmericanAir continues to win: I've never missed a flight before, but a nice little quiet gate change made it possible. Sheesh.",
#   'positive'],
#  ["@USAirways we even offered to fly in to another airport and they said they couldn't do that. No explanation why they can't.",
#   'neutral'],
#  ["@USAirways the phone number the gate gave me doesn't work either. What is your customer service phone number?",
#   'negative'],
#  ['@JetBlue flight 1041 to Savannah, GA', 'neutral'],
#  ['@AmericanAir yes but you are still human I hope, dealing with all the horror stories people share... I complained to DOT. Everyone should',
#   'negative'],
#  ['@JetBlue they are now being sent off the plane? Does anyone at JetBlue have a clue?',
#   'negative'],
#  ['@SouthwestAir do you have all winners for @Imaginedragons #DestinationDragons',
#   'neutral'],
#  ['@united quick (serious) question - any resources/ratings showing the quality of service is better than 8th place? http://t.co/deWIthPeW2',
#   'negative'],
#  ["@united can you not get the first flight of the day off the ground on time?   #1531.  Let's go.......",
#   'negative'],
#  ['“@SouthwestAir:Southwest mobile boarding passes now available in iOS Passbook! http://t.co/xmRvR4lGEg http://t.co/wJoc9f14SU”@tori_leggieri',
#   'neutral'],
#  ["@SouthwestAir I'm stuck in Fort Lauderdale.", 'negative'],
#  ['@JetBlue I clear that folder regularly and JetBlue is white listed so it never got to me.',
#   'neutral'],
#  ['@united Keep the flights cheap and early/on time and you are good. Flew @AmericanAir  and Cancelled Flightled my flight 4 times last month. United&gt;',
#   'positive'],
#  ["@JetBlue I believe it's Irina. On the flip-side, super disappointed that EatUp Cafe isn't available on this BOS --&gt; SFO flight today.",
#   'negative'],
#  ["@USAirways 5534. That's the flight I was placed on after original flight to Charlotte was Cancelled Flightled.  Now 5534 is on 1hr delay",
#   'negative'],
#  ["@USAirways The captain turned off the seat belt sign so people can get up and walk around.  That's not good.",
#   'negative'],
#  ['@United now what?!? http://t.co/5hpSqVRjK8 flight was gone when I got off plane! #BusinessTravel #goodenoughmother',
#   'negative'],
#  ['@AmericanAir Call me Chairman, or call me Emerald. After what you did today to me, you can call me a former customer.',
#   'negative'],
#  ['@JetBlue we saw one, he was as useless as the tsa agents who inspected my shoes',
#   'negative'],
#  ['@united Thank you for your response!', 'neutral'],
#  ['@AmericanAir no one received text alerts, automated calls, anything either. Literally no information as to what was happening.',
#   'negative'],
#  ["@USAirways made it!!! Send Bloody Mary's to row 27!!!", 'positive'],
#  ['@united 5 gate changes, two delays.  Even the crew thinks the airline sucks',
#   'negative'],
#  ['@USAirways Thank You for your empathy there is more to this story than just the luggage but thank you for reaching out',
#   'positive'],
#  ["@JetBlue Thanks JB. Actually, As a birder I love them too. They just need to be outside. It shouldn't be too hard to trap and move them.",
#   'positive'],
#  ['@USAirways flt 5302 CLT to DAY supposed to depart 5:51; the 6:20...still no crew. #schedule/contact the pilot!',
#   'negative'],
#  ['@JetBlue to allow payment by #Apple Pay - Patriarc http://t.co/bdUaUZFhW2',
#   'neutral'],
#  ["@united and now your rep just hung up on me after over 35 mins on hold because I asked for a supervisor. I'm furious right now.",
#   'negative'],
#  ["@AmericanAir no you're not you're trying to book me PAST when i need 2 arrive but you're still selling seats on the day I'm trying 2 travel",
#   'negative'],
#  ['@USAirways @AmericanAir seriously with all the service issues you are having right now this is what you decide to tweet?? Unbelievable',
#   'negative'],
#  ['@AmericanAir will do. I also passed the website around to other passengers.',
#   'neutral'],
#  ['@united clicked on the link and got this? #confused http://t.co/xMAQcucWZl',
#   'neutral'],
#  ['@AmericanAir well we cleared customs in AUH. I need to get to IAH after I arrive in DFW. Is it possible to retrieve my luggage in IAD?',
#   'neutral'],
#  ['@SouthwestAir @TaylorLumsden Taylor.  U gotta love SWA responsiveness at the@very least huh?',
#   'negative'],
#  ["@AmericanAir flights been Cancelled Flightled, can't get through to the desk and nothing showing online under my reservation - what do I do?",
#   'negative'],
#  ["@AmericanAir @USAirways - I'm pregnant with twins and you're going to abandon me overnight in an airport? No hotel? When it's your fault?",
#   'negative'],
#  ['@united thanks for prompt response.  Another hour to enjoy vacation! Perhaps a bug in the app as it still shows 2:55.',
#   'positive'],
#  ['@united tried that. Cannot figure out where to go to get it.', 'neutral'],
#  ['@united except all of that delayed the flight anyway.', 'negative'],
#  ['@JetBlue get flight 16 into the air', 'negative'],
#  ['@united let me assure you my travel time is 4h2m not 5h2m #timezones #accuratetraveltimes #3rdtimethishashappened http://t.co/e0C9bI09cf',
#   'negative'],
#  ['@united : thanks! i will catch my conection! :)', 'positive'],
#  ["“@JetBlue: Our fleet's on fleek. http://t.co/aJM3BhJVaa” #foh", 'neutral'],
#  ['@VirginAmerica I am all about the in flight artisanal cheese and wine pairing.',
#   'positive'],
#  ['@united flight UA3364 been sitting on tarmac for 30 mins with no report as to why...any input?',
#   'negative'],
#  ['@USAirways sits on a throne of lies', 'negative'],
#  ['@SouthwestAir 3 flights Cancelled Flightled today. Now we have been on hold for over an hour!',
#   'negative'],
#  ["@SouthwestAir Late Flightly you've always been Late Flight! Please get back to the old #SWA!!",
#   'negative'],
#  ['@AmericanAir My ex-boyfriend picks up my calls more than you do! #Cancelled Flightedflight #nocustomerservice #americanairlines #FAIL',
#   'negative'],
#  ['@SouthwestAir I WOULD DO ANYTHING FOR tickets to the VEGAS... ANYTHING. I love imagine dragons so much!!',
#   'positive'],
#  ["@SouthwestAir thanks for your attention, I've been flying southwest for 3 years and haven't had this issue in the past.",
#   'positive'],
#  ["@USAirways never let's me down, every. Single. Flight. Gets delayed.",
#   'negative'],
#  ["@USAirways me and my wife will be flying out of atlanta to vegas on March 7th since couldn't get any out of tricities here in Tn",
#   'neutral'],
#  ['@united \nFlight UA1665 got delayed 2 hours due to a mechanical issue...could use a free drink or 3 to make up for this inconvenience',
#   'negative'],
#  ['@VirginAmerica  DREAM http://t.co/oA2dRfAoQ2 http://t.co/lWWdAc2kHx',
#   'neutral'],
#  ["@SouthwestAir I'm in line at the airport right now. Will you cover hotel fair or am I to sleep in the airport?",
#   'negative'],
#  ["@JetBlue I don't know- no one would tell me where they were coming from - I would guess so as that's where we had all the changes to flights",
#   'negative'],
#  ["@AmericanAir no worries you're swamped I know just dmd back THANK U",
#   'neutral'],
#  ['@SouthwestAir i forgot to put my tsa pre number in before I checked in. It is now in my profile but will it be on my boarding pass in the am',
#   'neutral'],
#  ['@SouthwestAir have five people shown up yet', 'neutral'],
#  ["@AmericanAir I've never had anything bad to say until now. No love for faithful customers.",
#   'negative'],
#  ['@SouthwestAir : Hello..are flights taking off from @DallasLoveField airport this noon. Am supposed to travel on flight 376 to San antonio',
#   'neutral'],
#  ['@SouthwestAir I love and appreciate the fact that you guys rarely Cancelled Flight flights and are on time, but I need a Cancelled Flightlation this time. 🙏',
#   'positive'],
#  ['@AmericanAir Connection is US2065', 'neutral'],
#  ["@united all good man it isn't your fault that plane is having maintenance issues",
#   'positive'],
#  ["@AmericanAir while I'm sensitive to this fact, I don't believe that warrants poor service. A little help &amp; compassion goes a long way.",
#   'negative'],
#  ["@jetblue all your online resources  say we're on time, but clearly we are not.  This is not very information age of you...",
#   'negative'],
#  ['@united You make it hard to fly with you. Delayed over an hour and now the plane  is turning around &amp; heading back to the gate. #connection?',
#   'negative'],
#  ['@USAirways your people are kind and hardworking the infrastructure you have given them is horrid #massivefail #failphone #fail',
#   'negative'],
#  ["@JetBlue THANKS!! Her 80th bday is Saturday. We're having an aviation themed surprise party for her.",
#   'positive'],
#  ["@JetBlue Airways Reveals 'Bluemanity' Livery - TravelPulse http://t.co/fTTfyFMvCO",
#   'positive'],
#  ['@USAirways @JosephTReis Dont bother. They dont pick up the phone. Worst customer service going',
#   'negative'],
#  ['@AmericanAir Are you expecting any delays out of #DFW tomorrow morning?',
#   'neutral'],
#  ["@USAirways flight 1808 is not leaving at 2:45 because we haven't even begun to board yet. Please update your website ASAP",
#   'negative'],
#  ["@AmericanAir what an incredibly arrogant thing to say while I sit here at O'Hare waiting for your incompetent airlines to refuel on a...",
#   'negative'],
#  ['@JetBlue Airline trouble this winter &amp; not getting good customer service? contact http://t.co/aQjn4HwNaC  we negotiate resolutions for You!',
#   'neutral'],
#  ['@united thankful for great service in Newark. Seats fixed and I was seated with my daughter! Fab landing in Fort Myers!',
#   'positive'],
#  ['@united feeling like a true united customer stuck.on the tarmac in dc for over 2 hrs. UNITEDFAIL',
#   'negative'],
#  ["@united it is cool. Your customer told me they didn't care either. It is expected",
#   'negative'],
#  ["@SouthwestAir when does today's scavenger hunt start? I'm trying to help my little brother win! #DestinationDragons",
#   'neutral'],
#  ['@united &lt;&lt;&lt;&lt;&lt;------- shoddy customer service. Of no use whatsoever. #unitedairline',
#   'negative'],
#  ['@JetBlue Any option for luggage assistance on the ground at HPN? Flight 2168 delayed 2+ hours &amp; we will have 2 sleeping kids when we land',
#   'negative'],
#  ["@SouthwestAir I DM'd you", 'neutral'],
#  ['@united yep—used that twice; no case id numbers assigned; just tried it again-get screen that says, “thank you for submitting your request”',
#   'negative'],
#  ['@AmericanAir You guys did an amazing job today! Know it’s hard; thanks to Kate Appleton for all her hard work reFlight Booking Problems my friends and me!',
#   'positive'],
#  ['@AmericanAir you really need some customer service training for your unhappy EEs in the morning in Chicago. Gate K20 at 430 chking her schd',
#   'negative'],
#  ['@SouthwestAir your employees were great!', 'positive'],
#  ["@AmericanAir @SouljaCoy what is AA going to do to fix their utterly embarrassing customer service? You won't even answer the dang phone!",
#   'negative'],
#  ['@SouthwestAir Please bring back RDU to FLL direct route!  I noticed it is missing starting in Late Flight August!  The flights are always packed!',
#   'neutral'],
#  ["@USAirways doesn't want me to get home", 'negative'],
#  ['@USAirways The phone line disconnects. How can I be in the queue to be answered when the phone line simply disconnects when I call?',
#   'negative'],
#  ["@JetBlue I'm sitting on the plane. Too many predictable mechanical problems.  Still onboard. This is getting bad...",
#   'negative'],
#  ['@USAirways @shivadelrahim what about upgrades?', 'neutral'],
#  ['@USAirways never received such horrible service or treated so poorly as Richard P. today. No excuse for attitude &amp; ripping up our tickets!',
#   'neutral'],
#  ['@JetBlue how do I get a copy of my last flight showing original time and delay? I need it for work. Thanks!',
#   'neutral'],
#  ['@JetBlue can we get a honest update on departure of flite 454. Been on plane with infant children',
#   'negative'],
#  ['@USAirways US 728 Wait, now a gate opened. Back we go. (Good, maybe we can get off.)',
#   'neutral'],
#  ['@AmericanAir how do you NOT do maintenance on #MD80 while it sits for two days? Frozen lines found after its boarded? Come on! #faail #mci',
#   'negative'],
#  ["@SouthwestAir is seriously THE WORST. I don't remember the last time I or someone I knew had a flight that wasn't delayed / Cancelled Flightled / etc!",
#   'negative'],
#  ["@united wont transfer flight ticket to accompany an 11 yr old who's active military mom had to have emergency brain surgery? WOW!!",
#   'negative'],
#  ['@USAirways ticket counter people here are not helping and just want to charge more money even after this horrible day.',
#   'negative'],
#  ['@united on a 4 seg flt yvr to zurich, why would you credit all miles and but only 2 segs on full fare?',
#   'negative'],
#  ["@AmericanAir just need to know why it wasn't done like it was promised it would yesterday",
#   'negative'],
#  ["@JetBlue #kudos! And we're done and heading to warmer weather!",
#   'positive'],
#  ["@SouthwestAir why are yall trying to fly me to Chicago when I don't live there?! Send me home now!!!! Bullshit ass customer service",
#   'negative'],
#  ["@SouthwestAir we have to stay in Chicago overnight and meet up with our bags there. I hope they stay put and don't get put on a flight.",
#   'negative'],
#  ['@united severely under staffed at Iah.', 'negative'],
#  ['@AmericanAir fantastic thanks! Will try and tweet a photo of the view :)',
#   'positive'],
#  ['@SouthwestAir I love my Companion Pass (qualified 4th year).  #HollyMais',
#   'positive'],
#  ['@AmericanAir said that AA does not provide in-flight wifi on the routes to China based on some federal laws, but United does, why is that?',
#   'negative'],
#  ['@SouthwestAir boarding passes now compatible with #iPhone #Passbook \nhttp://t.co/1ESmMnIZEk',
#   'neutral'],
#  ['@USAirways - what a disaster! Flight 3739, missed passenger count by 5 since it was done manually!!  Really???',
#   'negative'],
#  ['@JetBlue u suck Big Donkey Balls!', 'negative'],
#  ['@SouthwestAir Thanks! Confirmation number just DMed. Appreciate any help!',
#   'positive'],
#  ["@JetBlue I shouldn't be made to feel like a criminal because I want to sit near my 5 year old on a flight. #jetblue http://t.co/qgtCao1J2U",
#   'negative'],
#  ["@AmericanAir we've already made other arrangements ourselves.", 'neutral'],
#  ['@USAirways cannot add my frequent flyer number on your website.  Can you help?',
#   'negative'],
#  ['@SouthwestAir my ticket was booked 1/27 to CUN. Does the arrival time reflect that CUN is now on EST time?',
#   'neutral'],
#  ['@united there are a lot of unhappy cold people on the bridge in freezing temps for an hour. Not given any info.',
#   'negative'],
#  ["@jetblue We'd love to help Shanese Bryant-Melton, a hard-working grandmother from DC, go to Miami. It's on her bucket list. #flyitforward",
#   'neutral'],
#  ['@united Want to book a multi-city fare. Have miles for 1of 2 flights. An option to pay for 1st flight with miles +2nd with UMP Visa? Thanks!',
#   'neutral'],
#  ["@united When will email address/username sign-on be available? It's been a while.",
#   'negative'],
#  ["@united yes, I've been waiting for four hours and no one has been able to help me.",
#   'negative'],
#  ["@AmericanAir I will thank you. What do I do if I can't get through and my flight on hold Cancelled Flights?",
#   'neutral'],
#  ['@USAirways flight scheduled for 730pm...told at 150am that flight is Cancelled Flightled after sitting on cold plane for 2 hours.',
#   'negative'],
#  ['@united Yes there were PLENTY of seats available.  So why did Vicky Thomas refuse to give one to a million mile flyer?',
#   'negative'],
#  ['@united UA63 from Madrid arrived no agent mass confusion we sent to and fro by 3 UA employees. MaryJo was rude and unhelpful.',
#   'negative'],
#  ['@USAirways @AmericanAir terminal E in Miami is still the worst most smelly airport ever. Thanks for nothing.',
#   'negative'],
#  ["@united great decision making skills flight ops IAH bag makes a 10 minute connection and I don't, flight pushed early. Disappointed!!!!",
#   'negative'],
#  ['@JetBlue When I checked yesterday it looked like it did. Did something change?',
#   'neutral'],
#  ['@united no it weighed 45.5 and it was the only checked bag', 'negative'],
#  ['@USAirways When I check online it states status closed. What does this mean? As I have yet been able to reach a live person...',
#   'negative'],
#  ['@united you asked me to DM then ignore them. Please assist in changing to another flight today- 21 Feb fra to mco avoiding IAD.',
#   'negative'],
#  ['@AmericanAir #AmericanAirlines on approach to mex.... http://t.co/se57dmjHiW',
#   'neutral'],
#  ['@united &amp; finally he was told he couldnt use the front of plane restrm (he was row7) though myself/others in rows behind him used w/no issue',
#   'negative'],
#  ["@AmericanAir any earlier flights SAP-&gt;Mia &amp; Mia -&gt; New York (lga) on 03.03. I'm currently booked on flights 1504 and 1102.",
#   'neutral'],
#  ['@united last night we waited forever at the gate because someone from corporate dispatch FORGOT to call the crew #unfriendlyskies',
#   'negative'],
#  ["@united - SERIOUSLY it's 2015?!?!  NO WiFi on a 5hr flight from CLE-SFO #1589.  You're the ONLY airline without WiFi...",
#   'negative'],
#  ['@united you told me you changed my flight and im in the ottawa airport and AC cant find my reservation! Whats wrong with you',
#   'negative'],
#  ["“@JetBlue: @Analystdoc Unfortunately that's not an available option with our current system. Sorry guys. That's a certain #fail Fix it plz.",
#   'negative'],
#  ["@united don't need your apologies, need my bag. Took 56 minutes from landing to get it. Unacceptable.",
#   'negative'],
#  ['@AmericanAir See photo of B787 scale model &amp; our PN 320008A wheel deflator specified in Chapter 32 of B787 AMM. http://t.co/kfD4WQRkLW',
#   'neutral'],
#  ['@united flying out of STL Saturday where they are expecting ice &amp; snow. When should we start looking for travel waivers? Thanks!',
#   'neutral'],
#  ['@AmericanAir thanks for getting back to me. But I will find other airlines in the future.',
#   'negative'],
#  ['@VirginAmerica you know it. Need it on my spotify stat #guiltypleasures',
#   'positive'],
#  ['@united I will be patient in my luxurious middle seat on my next delayed flight',
#   'negative'],
#  ["@USAirways 4 hours on tarmac in Charleston and still can't get a response after a week. Unacceptable",
#   'negative'],
#  ["@SouthwestAir What's happened to your customer service? 2 Cancelled Flightled flights in 2 days &amp; an uninformed and unapologetic staff. #nolove #cali",
#   'negative'],
#  ['@united 777 from SFO to HNL with ZERO entertainment systems???!!!#youareonyourown',
#   'negative'],
#  ['@AmericanAir 3078 is overweight so you pull 2 dozen passengers off? Why not luggage? Seriously?',
#   'negative'],
#  ['@JetBlue disappointed that my flight back to boston from PR was Cancelled Flightled,rebooked 4 the next day,delayed that one too, and no compensation',
#   'negative'],
#  ['@united have better customer service at John Wayne airport.', 'negative'],
#  ["@AmericanAir after waiting for a delayed plane, we sat on the plane for an hour waiting for a Late Flight passenger. That's BS too..",
#   'negative'],
#  ['@united As it always is. Helps to communicate to customers.', 'negative'],
#  ["@united you're customer service is unbelievably bad. Abysmal. I've been on the phone for well over 2hrs tonight. Hung up on by yr ppl 3x.",
#   'negative'],
#  ['@SouthwestAir 3rd time flying southwest in two years. Have another trip back to mx on October.',
#   'neutral'],
#  ['@AmericanAir Priority baggage evidently means it comes out last',
#   'negative'],
#  ["@united did I mention one bag is an infant car seat &amp; we've been stuck with yr poor replacement on icy mtn roads",
#   'negative'],
#  ['@united Just did, thanks for checking! :)', 'positive'],
#  ['@AmericanAir I understand that, but I\'m not even being put on hold - it says "try again Late Flightr, goodbye".',
#   'negative'],
#  ["@united why I won't check my carry on. Watched a handler throw this bag -- miss the conveyer belt -- sat there 10 min http://t.co/lyoocx5mSH",
#   'negative'],
#  ["@SouthwestAir You rerouted my bf's flight and he's diabetic with little insulin; even though we tried to change it, the agent wouldn't do it",
#   'negative'],
#  ["@AmericanAir there's a lot of talks and no doing. \nMIA-SFO on a 20+ year old plane #nonewplanes #old #shame http://t.co/TwETPXUpPN",
#   'negative'],
#  ["@AmericanAir  flight to dca I need to change asap help can't get through",
#   'negative'],
#  ['@united All these changes. Way to stick it to your Premiere 1K loyal customers. Why make things harder for those that loyal to you?',
#   'negative'],
#  ["@USAirways ok...i know doors close ~10 minutes before takeoff. stop telling me my flight will leave in 20 minutes when we haven't boarded.",
#   'negative'],
#  ['@united I hope not to see the same issue on my return flight tomorrow',
#   'negative'],
#  ['@united customer service 👎', 'negative'],
#  ['@USAirways My wife, sick 3yr-old-twins, and I have been waiting in line now for 2hrs to see an agent! Phone agent said nothing til Tuesday!',
#   'negative'],
#  ['@JetBlue ruining vacations left and right. Who would have thought an airline can Cancelled Flight tickets without telling the buyer',
#   'negative'],
#  ["@SouthwestAir Guys, we've got to do something about the inability to check in online for international  flight that has... (1/2)",
#   'neutral'],
#  ['@USAirways Seriously, flight delay Cinci to Philly due to new ground staff, miss connection to MAN UK and now have to argue for hotel. WTF',
#   'negative'],
#  ['@united, this is the line in Denver to rebook due to weather issues. DO BETTER. http://t.co/tmccExYaaQ',
#   'negative'],
#  ['@USAirways How do I redeem my pass to the admirals club? I have 1 free visit with my barclay card membership. And can I bring a companion?',
#   'neutral'],
#  ['@USAirways #FAILINGYOURCUSTOMER ONE BY ONE', 'negative'],
#  ['@JetBlue you guys continue to impress. Your crew @ MCO gate 4helped our family with seat issues. #professional',
#   'positive'],
#  ['@SouthwestAir doesn\'t charge ticket change fees. Do they not incur the same mysterious "costs" that you incur, @united?',
#   'negative'],
#  ['@AmericanAir how can you not be taking calls? I need to change my flight!',
#   'negative'],
#  ['@USAirways flight 1735 sitting fully loaded for over an hour. Air conditioning barely working :-(',
#   'negative'],
#  ['@JetBlue dropping passengers with small baby and 3 infants at your San Juan terminal. As unloading baby, officer writes me ticket for $75',
#   'negative'],
#  ['@SouthwestAir I continue to be amazed by the amazing customer service.  Thank you SWA!',
#   'positive'],
#  ['@SouthwestAir hilarious flight attendants on Vegas to Detroit tonight http://t.co/nw7vx7DGMF',
#   'neutral'],
#  ['@AmericanAir Are you people cruel or just stupid? Why are you posting my personal email on the damn Internet? Have u lost your mind?!',
#   'negative'],
#  ['@AmericanAir narrowly made standby...lots of snags this trip!', 'negative'],
#  ['@SouthwestAir Thank you!  #thankful #feelingtheluv', 'positive'],
#  ['@AmericanAir Took a flight yesterday fron TPA-DFW-AUS. Bag went to IAH. Today bag went to IAH-DFW and then back to IAH. Still no bag!',
#   'negative'],
#  ['@AmericanAir now down to only one agent helping a stagnant line of almost 100 customers. Super.',
#   'negative'],
#  ["@SouthwestAir do you have a pair of tickets to the @Imaginedragons show in Atlanta?! I'd love to go! #DestinationDragons",
#   'neutral'],
#  ['@SouthwestAir, got "duped" w/ a connection on 1st flight (sneaky), now u won\'t give me a seat on an earlier flight w/ availability. Shameful',
#   'negative'],
#  ['@SouthwestAir is really gonna hear my mouth about this bag situation.',
#   'negative'],
#  ["@virginamerica What is your phone number. I can't find who to call about a flight reservation.",
#   'negative'],
#  ['@USAirways Thanks. It would be better from the gate agent at C14 in Charlotte boarding flight 1791.',
#   'positive'],
#  ['@JetBlue its always a pleasure ☺️', 'positive'],
#  ['@USAirways  #USAirways disappoints AGAIN! #Cancelled Flighted flights #Missed appointments #Promised refund is a lie',
#   'negative'],
#  ["@united can't get anyone to deal with me in person. Cowardly customer service, I can't be looked in the eyes by anyone.",
#   'negative'],
#  ["@AmericanAir is there something wrong with the website? no matter what flight I select, it says it's no longer available.",
#   'negative'],
#  ['@SouthwestAir After multiple attempts, I was finally able to submit them Late Flight last night.',
#   'negative'],
#  ["@SouthwestAir broke the stroller my wife and baby gate checked. They told her it's not their problem. Calling the A List Preferred line now.",
#   'negative'],
#  ['@JetBlue unfortunately no, but hoping I can catch one sometime in the near future!',
#   'neutral'],
#  ["@JetBlue You mean take more of my time to write you a physical letter because the fraud department doesn't have email or telephones. Right?",
#   'negative'],
#  ['@AmericanAir Trip cut 7 hrs short due to flight change/massive layovers/ no peanuts or crackers/ asked for H2O and received about 2oz.',
#   'negative'],
#  ['@united Can you please follow for a Dm on a missing bag?', 'negative'],
#  ["@USAirways please secure the 'footrest' shelf' in business class on A330 airplanes!!! http://t.co/ZL4bVEXmcJ",
#   'negative'],
#  ['@AmericanAir @maryella_green just received it, actually. Thank you!!!!!!!!!',
#   'positive'],
#  ['@JetBlue @Amagrino will you cover the cost of my car service waiting time?!',
#   'negative'],
#  ["@AmericanAir Now you've Cancelled Flightled my flight. First a priority ticket bumped and now this. You're losing customers. People are furious.",
#   'negative'],
#  [".@AmericanAir can you connect me to a person without having to wait 2+ hours on hold? I still haven't been able to resolve the problem.",
#   'negative'],
#  ["@USAirways They're all reservations numbers and none are in Hungary. And my phone not working here. You make it too difficult.",
#   'negative'],
#  ['@SouthwestAir we checked in right at 24hr mark. Boarding C group with kids ages 6&amp;8 dnt want to be split. What sld we do?',
#   'neutral'],
#  ["@JetBlue I'm on flight and no booze being served 30 min in... What gives? #lostrevenue #angryandsober #bachelorpartymishap",
#   'negative'],
#  ["@AmericanAir @sweetmel If weather is bad, wouldn't your folks try extra hard to communicate...or load bags onto flight 1320...or...anything?",
#   'negative'],
#  ['@AmericanAir 4369. about 4 flights all using same gate w/buses to the planes.  Awful boarding process. Hour and a half Late Flight',
#   'negative'],
#  ['@united the staff was rather efficient and got us solutions just freaked me out a little being in limbo in the air.',
#   'positive'],
#  ['@united flight from vegas to houston Cancelled Flighted this morning "due to operation" what does this mean!???? Thank god I woke up early today!',
#   'negative'],
#  ['@USAirways #PHL why does it take an hour to offload bags, especially after taking 30+ min to get a jetway to get off plane after landing?',
#   'negative'],
#  ["@AmericanAir I'd like to apologize to the gate agent for flight AA76, I was not aware that zone 1 was after the nine other precious gems.",
#   'negative'],
#  ['@AmericanAir 4hrs Late Flightr i get a call back, and immediately disconnected',
#   'negative'],
#  ["@USAirways won't waive $200 fee due to #neptune. Can't use credit w/o paying fee. Couldnt get to destination to use their tic #waivethefee",
#   'negative'],
#  ['Is it insulting that @USAirways @AmericanAir offer a "non required $50 voucher as a goodwill offering..At least my bag can fly round trip',
#   'negative'],
#  ["@USAirways I can't even use my return flight home because the change fees you charge are too expensive, forcing me to purchase a new ticket.",
#   'negative'],
#  ["@united I'm rebooked now, but the line was 300 people deep.", 'negative'],
#  ['@USAirways cust serv reps who are unable to change reservations in your system Check in unaware of Cancelled Flights that I got word on night before',
#   'negative'],
#  ["@united just give up.  Your service is terrible.  If I wasn't forced to use United on certain routes, I never would.",
#   'negative'],
#  ['@SouthwestAir can I get any kind of update on the delayed flight from Boston to Houston at 7:30? Really need to be back home tonight!',
#   'negative'],
#  ['@SouthwestAir I was under the impression when there is an 8 hour delay in your flight because of equipment failure, compensation is offered?',
#   'neutral'],
#  ["@SouthwestAir Looks like 'On February 19, 2015, we will open our schedule for sale through October 30, 2015' - know what time that will be?",
#   'neutral'],
#  ["@AmericanAir that would be appreciated. Just please don't send me to the same page with long form &amp; limited characters.\nDirect email?",
#   'negative'],
#  ['@USAirways do you have an email??', 'neutral'],
#  ["@united diverted and missed our connecting flight. Was just told that my bag is on it's way to MSY. If you only had people that cared",
#   'negative'],
#  ['@united need assistance. Line is out the door and travelling with 3 kids.',
#   'negative'],
#  ['@united 100% I will put together a very serious email, with all the issues that arose on our vacation due to your staff I will post it here',
#   'negative'],
#  ['@AmericanAir  upon entering plane to 2 @USAirways stewardesses: "can I have some water?" "no we don\'t do that. please take your seat"',
#   'negative'],
#  ["@JetBlue the amount of money I spent on hotels for a WEEK bc of flight Cancelled Flightlation, another flight doesn't make up for the money lost.",
#   'negative'],
#  ['@USAirways Flight 830 CLT to Phl. I was 1st on list.Someone else got spot. Rude employee in coach. Wouldt give ID. Said he was cute red head',
#   'negative'],
#  ["@AmericanAir thanks. Bummer. Poor planning on my part. I assume the card in Passbook won't work either?",
#   'neutral'],
#  ['@USAirways still crickets from customer service.', 'negative'],
#  ["@united as a 1k, I'm always hoping for improvement.", 'negative'],
#  ['@AmericanAir this merger with @USAirways @usairwis a cluster of inefficiency and misinformation.  When is it going to be done?',
#   'negative'],
#  ['@SouthwestAir much respect!', 'positive'],
#  ['@SouthwestAir really easy for locals to get down to the strip. book.',
#   'positive'],
#  ['@USAirways Charlotte Staff needs prayer....disappointed in response to mishaps ......lotttttttt of pissed off people here!!!!',
#   'negative'],
#  ['@SouthwestAir, on #unscheduled aircraft change, please have a better system in place, not worth the paid upgrade. #REFUND',
#   'negative'],
#  ['@united From the air: Another missed cnxn 2day. ATC went on strike in Belize this AM. Now family &amp; I miss cnxn in EWR. Please see my DMs.',
#   'negative'],
#  ['@USAirways thanks for being so bad you make a two day train trip look appealing!!',
#   'negative'],
#  ["@united this is getting ridiculous. Now we're missing our connection.",
#   'negative'],
#  ['@united You really should clean the food and coffee stains off of the area around the seats when new passengers come aboard. Gross!',
#   'negative'],
#  ["@united Missing flight attendant = Delayed Flight. Prime example how 1 person impacts 100's of people. HNL -&gt; IAH (UA252) #wastedtime",
#   'negative'],
#  ['@USAirways @AmericanAir call the number listed? sure! by next Friday, I should get a real live person on the line http://t.co/8TJUuM22dD',
#   'negative'],
#  ['@AmericanAir change fee = same price of new ticket... Not logical',
#   'negative'],
#  ["Stop this madness RT @JetBlue: Our fleet's on fleek. http://t.co/7x9uSbj2FV",
#   'neutral'],
#  ['@united ok, have sent u info via DM. I appreciate your help and consideration. 😊',
#   'positive'],
#  ["@SouthwestAir Service rep didn't say I was dumb just had the tone of voice like I should have known about it.",
#   'negative'],
#  ['@usairways im trying to get my dads wheelchair and no one is answering at Dulles.we have tried to call back on.multiple times',
#   'negative'],
#  ["@usairways I've been on hold for approaching 2 hrs for an issue when I changed my ticket online. Frustrating.",
#   'negative'],
#  ['@united thank you', 'positive'],
#  ['@united thanks for the effort. I can get the earliest. Though I will make a complaint for a refund as I am losing one business day tomorrow',
#   'positive'],
# ...
#   'negative'],
#  ['@united thanks, keep up the good work', 'positive'],
#  ["@SouthwestAir Is it a temporary site glitch or are you no longer offering flights from GRR to GEG after Feb? Can't find any online :(",
#   'neutral'],
#  ['@USAirways @AskPayPal completed. If that\'s the case then why does it still say "in progress" on Paypal\'s website. I reserved on the 13th.',
#   'negative'],
#  ["@SouthwestAir- Wife's RR pts expired a few days ago, were planning on Flight Booking Problems trip today. Anything you can do for us? On a tight budget...",
#   'neutral'],
#  ['@SouthwestAir On hold for 45 minutes trying to rebook a Cancelled Flightled flight with a companion ticket. Help?',
#   'negative'],
#  ['.@USAirways worst experience of all time. Will never, ever, ever travel with you again. EVER',
#   'negative'],
#  ['@AmericanAir just went to check into flight 24 hr advance, again husband and I are seated separately for 6hr flight! why does this happen??',
#   'negative'],
#  ['@USAirways @GregWallace66 Yea, they will give you 5 cents on the dollar!',
#   'neutral'],
#  ['@AmericanAir second pic from CDG?', 'neutral'],
#  ['@SouthwestAir thank you :)', 'positive'],
#  ['@united no thanks', 'neutral'],
#  ['@united okay. Thanks.', 'neutral'],
#  ['@AmericanAir really appreciate the great customer service... One of your service agents just hung up on me when asking legitimate questions',
#   'negative'],
#  ["@SouthwestAir I did. Still haven't heard a thing.", 'negative'],
#  ['@AmericanAir My chariot tonight. From this angle it looks like a 787, no? http://t.co/3ZZKQWWbJz',
#   'neutral'],
#  ['@USAirways #flight4592 LET US OFF THIS PLANE!!!  please go to a gate.  This is absurd.',
#   'negative'],
#  ['@JetBlue sorry, should have specified I meant ground traffic trying to get into the terminal',
#   'neutral'],
#  ['@AmericanAir Will my us air points now be combined with yours?', 'neutral'],
#  ['@USAirways - been on hold with reservations for over 30 min already! #worstairline',
#   'negative'],
#  ['@SouthwestAir who should I contact about a missing Rapid Rewards credit?',
#   'neutral'],
#  ["@JetBlue it's poop and barely works", 'negative'],
#  ['@USAirways still no rep can talk 3 days Late Flightr. U r asking me to checkin to my flight tmrw and my refund is being requested.  Deal w this!!',
#   'negative'],
#  ['@JetBlue haha. TY. Do you know what time that lane opens at Logan?',
#   'positive'],
#  ["@USAirways only happened because u couldn't get us home the next day. #flydelta #flysouthwest #flyjetblue #theyareallbetter #stillnobags",
#   'negative'],
#  ["“@JetBlue: Our fleet's on fleek. http://t.co/tLGoihqkvS” 😐 make it stop.",
#   'negative'],
#  ['@JetBlue Customer of the year? http://t.co/epqqONHO2H', 'neutral'],
#  ['@AmericanAir Extend rtn flight to bereavement, 22nd I could have change fee dropped, now told no.Worse day of my life #badcustomerservice',
#   'negative'],
#  ['@SouthwestAir App Updated With #Passbook Support http://t.co/WrWqrUblPs via @ubergizmo',
#   'neutral'],
#  ['@JetBlue sooo earlier i said i couldnt fly with you for my school trip but now i can! 😏',
#   'positive'],
#  [".@united I took a screenshot and emailed it to myself. Let's DM and figure this out.",
#   'neutral'],
#  ['@USAirways No kidding. Oy.', 'negative'],
#  ['@USAirways and if the flight is full?', 'neutral'],
#  ['@USAirways Stuck in Philadelphia airport for 32 hours due to "maintenance". Dreading my flight back home. Disgusting.',
#   'negative'],
#  ['@SouthwestAir What are your services? What promotion you have at the moment? #ModeloDeNegocio #innovation #innovacion #BusinessModel',
#   'neutral'],
#  ['.@united Our newest delay, right now http://t.co/96fTLZWtvO', 'negative'],
#  ['@united Hello United. You should take care of your call center in Mexico City Office. Terrible attitude from the lady who was helping me.',
#   'negative'],
#  ['@JetBlue to offer service from Daytona Beach to New York - Albany Business Review http://t.co/dUhBJ41jHx',
#   'positive'],
#  ["@AmericanAir I'm trying to choose my seats but every time I go to the next flight I get system error",
#   'negative'],
#  ["@JetBlue she has...she hasn't heard from anyone in over a week. a nonstop flight and her baggage was lost/stolen. customer service 👎",
#   'negative'],
#  ["@JetBlue we've been delayed for almost 2 hrs. I take JetBlue because I've had good luck, but today is really frustrating.",
#   'negative'],
#  ["@JetBlue only w/ $70 upgrade. Unsure why she can't just switch someone around. I called 24 hrs in advance for this reason.",
#   'negative'],
#  ['@JetBlue Great thanks', 'positive'],
#  ['@united thank you for getting our daughter home when @americanair Cancelled Flightled all their flights to Nashville',
#   'positive'],
#  ['@united yes... A ride home would be perfect.. A fete one would assume possible after charging 1600$ for a domestic flight... Ps we deplaned',
#   'negative'],
#  ['@SouthwestAir Totally ruined my birthday weekend by Cancelled Flighting my flights for no reason and offer no points, drink, transport. #nolove #cali',
#   'negative'],
#  ['@united nope not here. You need a little red stamp from the counter. Check yourself, before you wreck yourself son http://t.co/0pRGySvuRm',
#   'negative'],
#  ['@united is there a referral program for the Milageplus explorer card?',
#   'neutral'],
#  ["@AmericanAir you guys fail again.. all I need to do is use my voucher for a ticket but I can't do it online #yourphonesystemsucks",
#   'negative'],
#  ["@SouthwestAir looks like my 1 yr anni trip has been replaced w someone's itinerary. Worried abt who can c my flight http://t.co/BApE6RuMNE",
#   'negative'],
#  ['@AmericanAir thanks for finally letting me get through to book my flight. Frustration  set in... #donedeal #talktoahuman',
#   'negative'],
#  ['@united took this one just for you. Not a window. Also not fun if you get motion sick. http://t.co/m81rV0blxs',
#   'negative'],
#  ['@JetBlue keeps getting better. No water on the plane.', 'negative'],
#  ["@JetBlue thank you! Hopefully it's soon! We are supposed to leave at 11:23",
#   'negative'],
#  ["@united Thank y'all for being an amazing airline who knows how to treat their customers. you guys rock!",
#   'positive'],
#  ['@SouthwestAir sent. looking for that functionality in your app, though. should be a one click action.',
#   'negative'],
#  ['@AmericanAir I need some help. My record locator is bringing up TWO different flights in your system. One op by AA &amp; one from US Airways.',
#   'neutral'],
#  ["@JetBlue it's okay...I'm actually a tea kinda guy anyway. Thanks!",
#   'positive'],
#  ["@united Held up for almost 45 minutes and then promised free movies and it didn't work and neither did the wifi that was paid for. Boo :(",
#   'negative'],
#  ["@AmericanAir What's with your baggage handlers calling out at DFW today? No luggage onboard the planes.",
#   'negative'],
#  ['@USAirways so I would have to go though the entire process again just to get you people on the phone???????? #usairwayssucks',
#   'negative'],
#  ['@USAirways you have to be crazy! Treated my mom very poorly. Not happy! #usairwaysfail',
#   'negative'],
#  ['@SouthwestAir how many are left?!', 'neutral'],
#  ['@USAirways You all work hard at making sure things flow smoothly. Keeping positive.',
#   'positive'],
#  ["@USAirways Don't blame it on weather. Rep at counter cost me entire day - not weather.  Printed Boarding Pass too Late Flight. #TakeResponsibility",
#   'negative'],
#  ['@united thanks for updating me about the 1+ hour delay the exact second I got to ATL. 🙅🙅🙅',
#   'positive'],
#  ['@united How is this considered "on time" if it\'s arriving at destination half hour Late Flightr than scheduled? http://t.co/YMFTw1uyHr',
#   'negative'],
#  ["@AmericanAir if it I have not rebooked didn't get notified that it was Cancelled Flightled",
#   'negative'],
#  ["@USAirways #ShoutOut 2 Kristie(sp?) from Gate4 @ PVD today. She's a #RockStar, was a tremendous help in a tough situation. #PromoteThatGirl",
#   'positive'],
#  ['@united this is for a check-in luggage. Employee told me not to include wheels in the dimensions.',
#   'neutral'],
#  ['@united 25 minute hold is 1 hr. 25 min. @ABC11_WTVD', 'negative'],
#  ['@USAirways You guys are screwing up my trip. Thanks for nothing. #lazy',
#   'negative'],
#  ['@united the passengers waited inside the flight on the runway and returned back in o gate that should not count as a valid journey',
#   'negative'],
#  ['@USAirways Frustrating days!No flights home, changed airlines. Thank you PHL USAirway employees &amp; @united for help getting me back to IAH.',
#   'positive'],
#  ["@united u guys did it again changed ages and double booked seats so I had to I've even though I have platinum and the other person none",
#   'negative'],
#  ['@USAirways Cancelled Flightled the last part of a ticket and am confused from the email I received whether value remains. Is there someone I can ask?',
#   'neutral'],
#  ['@united If a business decision is made that inconveniences and possibly causes lost customers, is it a good business decision? #Cranky',
#   'negative'],
#  ['@USAirways my flight got Cancelled Flightled to Charlotte. Been on hold for an hour, pls pick up!',
#   'negative'],
#  ['@VirginAmerica wow this just blew my mind', 'positive'],
#  ['@AmericanAir AA2416 on time and awesome flight. Great job American!',
#   'positive'],
#  ["@SouthwestAir didn't realize no clothes until at hotel - suggestions?",
#   'neutral'],
#  ['@SouthwestAir got mine!  Just in time for the wife and my 15th anniversary!',
#   'positive'],
#  ['“@SouthwestAir: @pancho_joe No, no, you must\'ve heard us wrong. Sweet mixtape,though" 4 the record,I didn\'t leave the 80\'s, the 80\'s left me',
#   'neutral'],
#  ['@AmericanAir Sitting at the gate on Flight 719 for an hour due to Sabre being down. What backup plan is in place if Sabre cannot be fixed?',
#   'negative'],
#  ["@SouthwestAir is my favorite airlines. I've never had issues with them. Plus there crew is entertaining.",
#   'positive'],
#  ['@USAirways I made it! Thanks for the help!', 'positive'],
#  ["@USAirways is utterly unreliable! They didn't schedule a pilot for their US624 flight out of Seattle - flights are delayed #usairwaysfail",
#   'negative'],
#  ["@southwestair TREMENDOUS job. Atlanta Airport saw SW celebrate Mardi Gras. Another reason I'm nuts for you guys! http://t.co/8WBzOrRn3C",
#   'neutral'],
#  ['@united it seems like no one from United can help me. Lots of fingers pointed, zero people stepping up. At least the gate has Oreos',
#   'negative'],
#  ['@SouthwestAir 8FKQW is the conf #. Thanks for the reply', 'neutral'],
#  ['@united rebooked 24 hours after original flight, to say your handling of situation was bad would be an understatement.',
#   'negative'],
#  ['@AmericanAir are flights leaving Dallas right now? In Maui trying to figure out how delayed flight 7 is going to be',
#   'negative'],
#  ['@SouthwestAir One heck of an airline http://t.co/CyoOnZfTdC', 'positive'],
#  ["@SouthwestAir flying flight 3130 tonight at 7:20 from PBI- I have boarding position C-42. Is it overbooked? Really don't want to be bumped!",
#   'neutral'],
#  ['@JetBlue Clients got ZERO, in 32 years career never thought this was possible.2 suitcases worth thousands of $$ in Italian clothing robbed.',
#   'negative'],
#  ['@USAirways now what? You Cancelled Flightled my flight again... Are you paying for my hotel?',
#   'negative'],
#  ['@AmericanAir Your response has been incredible. Truly amazed at the steps you have taken to enhance your customer relations. Big thank you 😄',
#   'positive'],
#  ["@AmericanAir just wow Regina just told me I can't file or request a lost bag statement until I finish my travel.  So until I get to DC argg",
#   'negative'],
#  ["@united since I have an international connection at 9am, I'm hoping for the same thing!",
#   'negative'],
#  ['@JetBlue all day', 'negative'],
#  ['@united how long will it take for miles that i re-purchased (they had expired) to show up? I recieved an email that the request had been..',
#   'negative'],
#  ["@united is probably the least satisfactory airline I've ever been on. Never fails to disappoint.",
#   'negative'],
#  ['@United Airlines Is Changing Its MileagePlus Program: Winners And Losers http://t.co/F1yvAiO9ul http://t.co/vGlx6Ykwqg',
#   'neutral'],
#  ["@AmericanAir @SeguineJ AA - this is a joke, right? That line isn't even accepting calls right now - they just hang up.",
#   'negative'],
#  ["@united nonrefundable, hence I wrote $200! Doesn't make sense for my 150 credit. #nothanks",
#   'negative'],
#  ['@JetBlue Even 5 years after the earthquake...Haiti still needs helps in rebuilding #flyingitforward',
#   'neutral'],
#  ['@USAirways despite mechanical issues and many delays followed by a Cancelled Flightlation, still getting to Vegas thanks to great gate agents!',
#   'positive'],
#  ['@JetBlue no excuse though for 3 gate changes though.', 'negative'],
#  ['@JetBlue I may need to. I had a 40 minute layover and now have a 15 min delay on my first flight.',
#   'negative'],
#  ['@united How do I get reimbursed for hotel and taxis for the Cancelled Flightation?',
#   'negative'],
#  ['@AmericanAir but have been yet to receive assistance from one of your agents in securing a new connection. Many will now miss work tomorrow.',
#   'negative'],
#  ['@USAirways @British_Airways three hour flight delay. On the phone for 45min and counting.',
#   'negative'],
#  ['@AmericanAir #2298. Everyone else  was outstanding.', 'negative'],
#  ['@united - I think she was having a rough moment w/ a bad passenger from an earlier flight. Things got considerably better. Thanks!',
#   'positive'],
#  ['@USAirways thanks!', 'positive'],
#  ['@AmericanAir I Cancelled Flightled my ticket and is taking two months ++ to refund and still waiting!',
#   'negative'],
#  ['@USAirways should, but didn’t.', 'negative'],
#  ['@USAirways shout out to the pilots and FC attendant(Eliz) of US 673. Super strong crosswinds during landing. Eliz did a super job throughout',
#   'positive'],
#  ['@united I see you coming to get me and @AggieMensGolf in Hawaii! #12thMan http://t.co/G8DKa3Edhf',
#   'neutral'],
#  ['@AmericanAir @dfwairport you 2 together are the best part of flying!',
#   'positive'],
#  ['@united to Late Flight now, but in future flights, train staff better to handle emergency situations, and ground staff in Customer Service',
#   'negative'],
#  ['@united  oh united, how much I despise thee!', 'negative'],
#  ["@United Airlines' CEO Jeff Smisek: Disloyal to Loyal Workers http://t.co/0cevY3P42b via @HuffPostBiz",
#   'neutral'],
#  ['@united 3/10 disappointed in the service. Will be missing my connection after over an hour delay + cramped seats. At least their app is good',
#   'negative'],
#  ['@AmericanAir we had to sit in the airport a long periolodicly time. the planes were nasty',
#   'negative'],
#  ['@united 618 was flight out of Houston', 'neutral'],
#  ['@united fuck you for not caring 😢', 'negative'],
#  ['@SouthwestAir do you have any info about when #DestinationDragons winners will be announced? me &amp; my best friend are hoping to win. thanks!',
#   'neutral'],
#  ['@SouthwestAir   Thanks', 'positive'],
#  ['@SouthwestAir can tweet through the weekend/ bad weather, but closes down customer relations center to process refunds for Cancelled Flighted flights.',
#   'negative'],
#  ["@SouthwestAir missing out on over 6,000 points in one account. They're now spread over four assuming I create accounts for them",
#   'negative'],
#  ['@united I used to be a committed #ContinentalAirlines flyer until merger. I remember now why I switched to @SouthwestAir #CommunicationFail',
#   'negative'],
#  ['@united I will, as soon as I am done with my article.  Thanks!  ~Tom',
#   'positive'],
#  ["@AmericanAir you're not finding it bc @united  rebooked us on your airline when they realized they couldn't get us home - and we're at ORD",
#   'negative'],
#  ['@USAirways I gave up http://t.co/2eDgc6TbLs', 'negative'],
#  ['@USAirways ticket couldnt be used bc unable to get to departing dest (RSW) bc of blizzard in BOS. Told only way to use credit is $200 fine',
#   'negative'],
#  ...]

# %%
from nltk import word_tokenize
sample = 'hello howo are you'
test = word_tokenize(sample)
test
# Out:
# ['hello', 'howo', 'are', 'you']

# %%
for i in arr:
    i[0] = word_tokenize(i[0])
arr #################### Tokenized every tweet
# Out:
# [[['@',
#    'SouthwestAir',
#    'I',
#    'am',
#    'scheduled',
#    'for',
#    'the',
#    'morning',
#    ',',
#    '2',
#    'days',
#    'after',
#    'the',
#    'fact',
#    ',',
#    'yes',
#    '..',
#    'not',
#    'sure',
#    'why',
#    'my',
#    'evening',
#    'flight',
#    'was',
#    'the',
#    'only',
#    'one',
#    'Cancelled',
#    'Flightled'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'seeing',
#    'your',
#    'workers',
#    'time',
#    'in',
#    'and',
#    'time',
#    'out',
#    'going',
#    'above',
#    'and',
#    'beyond',
#    'is',
#    'why',
#    'I',
#    'love',
#    'flying',
#    'with',
#    'you',
#    'guys',
#    '.',
#    'Thank',
#    'you',
#    '!'],
#   'positive'],
#  [['@',
#    'united',
#    'Flew',
#    'ORD',
#    'to',
#    'Miami',
#    'and',
#    'back',
#    'and',
#    'had',
#    'great',
#    'crew',
#    ',',
#    'service',
#    'on',
#    'both',
#    'legs',
#    '.',
#    'THANKS'],
#   'positive'],
#  [['@',
#    'SouthwestAir',
#    '@',
#    'dultch97',
#    'that',
#    "'s",
#    'horse',
#    'radish',
#    '😤🐴'],
#   'negative'],
#  [['@',
#    'united',
#    'so',
#    'our',
#    'flight',
#    'into',
#    'ORD',
#    'was',
#    'delayed',
#    'because',
#    'of',
#    'Air',
#    'Force',
#    'One',
#    ',',
#    'but',
#    'the',
#    'last',
#    'flight',
#    'to',
#    'SBN',
#    'is',
#    'at',
#    '8:20',
#    ',',
#    '5',
#    'mins',
#    'from',
#    'now',
#    'we',
#    'just',
#    'landed',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    'Why',
#    'did',
#    'you',
#    'load',
#    'us',
#    'in',
#    'this',
#    'flying',
#    'sardine',
#    'can',
#    'if',
#    'you',
#    'knew',
#    'the',
#    'pilots',
#    'were',
#    '2',
#    'hours',
#    'Late',
#    'Flight',
#    '?',
#    '?',
#    '#',
#    'incompetent',
#    'beyond',
#    'belief'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'that',
#    'is',
#    'a',
#    'stock',
#    'response',
#    '.',
#    'Delays',
#    'not',
#    'as',
#    'frustrating',
#    'as',
#    'poor',
#    'cust',
#    'serv',
#    '&',
#    'amp',
#    ';',
#    'being',
#    'told',
#    'by',
#    '3',
#    'ppl',
#    'to',
#    'wait',
#    '&',
#    'amp',
#    ';',
#    'they',
#    "'d",
#    'come',
#    'back',
#    'but',
#    'did',
#    'not',
#    '.'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'That',
#    "'d",
#    'be',
#    'nice',
#    '!',
#    'Hoping',
#    'to',
#    'rack',
#    'up',
#    'enough',
#    'miles',
#    'to',
#    'take',
#    'a',
#    'trip',
#    'to',
#    'Seattle',
#    'and',
#    'enjoy',
#    'a',
#    'perfect',
#    'latte',
#    'in',
#    'the',
#    'city',
#    'of',
#    'coffee',
#    '.'],
#   'positive'],
#  [['@',
#    'united',
#    'frankly',
#    'worse',
#    'customer',
#    'service',
#    'ever',
#    '.',
#    'Problems',
#    'will',
#    'happen',
#    ',',
#    'how',
#    'you',
#    'deal',
#    'defines',
#    'a',
#    'company',
#    '.',
#    'Never',
#    'again',
#    'United',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'yeah',
#    'haha',
#    '.',
#    'Never',
#    'been',
#    'in',
#    'one',
#    '.',
#    'It',
#    "'s",
#    'expensive',
#    '😂😂',
#    'and',
#    'we',
#    'will',
#    '!',
#    '!',
#    '!',
#    '!',
#    '!',
#    'So',
#    'much',
#    'fun',
#    '!',
#    '#',
#    'destinationdragons'],
#   'positive'],
#  [['@',
#    'SouthwestAir',
#    'MCO-',
#    '&',
#    'gt',
#    ';',
#    'DCA',
#    'flight',
#    'almost',
#    'full',
#    'of',
#    'people',
#    'screwed',
#    'by',
#    'the',
#    'MSY-DCA',
#    'Cancelled',
#    'Flightation',
#    '.',
#    '@',
#    'united',
#    'and',
#    '@',
#    'USAirways',
#    'did',
#    "n't",
#    'Cancelled',
#    'Flight',
#    '.',
#    'SWA=mistake',
#    '.'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'what',
#    "'s",
#    'the',
#    'easiest',
#    'way',
#    'to',
#    'get',
#    'a',
#    'ticket',
#    'receipt',
#    '?',
#    'Can',
#    'I',
#    'get',
#    'one',
#    'at',
#    'check',
#    'in',
#    'or',
#    'can',
#    'I',
#    'get',
#    'one',
#    'online',
#    '?',
#    'Thanks',
#    '!'],
#   'neutral'],
#  [['@',
#    'USAirways',
#    '-',
#    'love',
#    'the',
#    'changes',
#    'in',
#    'the',
#    'lounge',
#    '-',
#    'cheese',
#    ',',
#    'veggies',
#    ',',
#    'olives',
#    'in',
#    'addition',
#    'to',
#    'the',
#    'crackers',
#    'and',
#    'snack',
#    'mix',
#    ','],
#   'positive'],
#  [['@',
#    'SouthwestAir',
#    'I',
#    'receive',
#    'bad',
#    'customer',
#    'service',
#    'and',
#    'ended',
#    'up',
#    'spending',
#    'several',
#    'hundred',
#    'dollars',
#    'to',
#    'accommodate',
#    'my',
#    'family',
#    'during',
#    'each',
#    'cxl',
#    'flight'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'you',
#    "'re",
#    'killing',
#    'me',
#    'sche',
#    'a',
#    'flight',
#    'to',
#    'board',
#    '3',
#    'min',
#    'after',
#    'mine',
#    'arrived',
#    'with',
#    'gate',
#    'on',
#    'other',
#    'side',
#    'of',
#    'airport',
#    '#',
#    'genious'],
#   'negative'],
#  [['@',
#    'USAirways',
#    '8',
#    'weeks',
#    'to',
#    'refund',
#    'this',
#    'ticket',
#    '-',
#    '0372389047497',
#    '?',
#    '!',
#    '?',
#    '-',
#    'totally',
#    'unacceptable',
#    '.',
#    'Fix',
#    'this',
#    'or',
#    'I',
#    "'ll",
#    'put',
#    'it',
#    'on',
#    'blast',
#    'on',
#    'social',
#    'media',
#    'and',
#    'TV'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'no',
#    'private',
#    'msg',
#    'me',
#    'and',
#    'will',
#    'provide',
#    'details',
#    '...',
#    'u',
#    'really',
#    'need',
#    'customer',
#    'svc',
#    'training',
#    'for',
#    'your',
#    'staff'],
#   'negative'],
#  [['can',
#    'you',
#    'not',
#    '?',
#    'RT',
#    '@',
#    'JetBlue',
#    'Our',
#    'fleet',
#    "'s",
#    'on',
#    'fleek',
#    '.',
#    'http',
#    ':',
#    '//t.co/413GiAL0yl'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'any',
#    'info',
#    'on',
#    'why',
#    'flight',
#    '704',
#    'from',
#    'SJU',
#    'to',
#    'JFK',
#    'is',
#    'already',
#    'delayed',
#    '2',
#    '1/2',
#    'hours',
#    '?'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    ',',
#    'I',
#    "'ve",
#    'tried',
#    'no',
#    'less',
#    'than',
#    '8',
#    'times',
#    'today',
#    'to',
#    'get',
#    'in',
#    'touch',
#    'with',
#    'your',
#    'service',
#    'desk',
#    'beginning',
#    'at',
#    '8:30',
#    'EST',
#    '.',
#    'I',
#    "'m",
#    'having',
#    'no',
#    'luck',
#    '-help',
#    '!'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'new',
#    'problem',
#    '...',
#    'had',
#    'wrong',
#    'last',
#    'name',
#    'on',
#    'reservation',
#    'which',
#    'is',
#    'airways',
#    'fixed',
#    '.',
#    'New',
#    'ca',
#    "n't",
#    'get',
#    'through',
#    'TSA'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'Any',
#    'possible',
#    'chance',
#    'of',
#    'SWA',
#    'bringing',
#    'back',
#    'service',
#    'between',
#    'LGA-BWI',
#    '?',
#    'It',
#    'would',
#    'make',
#    'it',
#    'much',
#    'easier',
#    'to',
#    'connect',
#    'to',
#    'the',
#    'west',
#    'coast',
#    '.'],
#   'neutral'],
#  [['@',
#    'USAirways',
#    '@',
#    'AmericanAir',
#    'who',
#    'runs',
#    'the',
#    'show',
#    'at',
#    'the',
#    'airport',
#    'have',
#    'a',
#    'boarding',
#    'pass',
#    'says',
#    'us',
#    'airways',
#    'and',
#    'I',
#    'have',
#    'to',
#    'wait',
#    'in',
#    'American',
#    'line',
#    '#',
#    'yousuck'],
#   'negative'],
#  [['@',
#    'united',
#    'computers',
#    'are',
#    'down',
#    'but',
#    'you',
#    'stopped',
#    'giving',
#    'updates',
#    'and',
#    'took',
#    'my',
#    'flight',
#    'info',
#    'off',
#    'the',
#    'app',
#    '.',
#    'That',
#    "'s",
#    'just',
#    'ridiculous',
#    'keep',
#    'people',
#    'updated',
#    '!'],
#   'negative'],
#  [['@',
#    'united',
#    'good',
#    'fly',
#    '!',
#    '!',
#    '#',
#    'United',
#    '#',
#    'businessFirst'],
#   'positive'],
#  [['@',
#    'united',
#    'I',
#    'am',
#    'flying',
#    'from',
#    'msp',
#    'to',
#    'dxb',
#    ',',
#    'my',
#    'child',
#    'will',
#    'turn',
#    '2',
#    'during',
#    'the',
#    'trip',
#    'do',
#    'I',
#    'have',
#    'to',
#    'buy',
#    'a',
#    'return',
#    'ticket',
#    'for',
#    'my',
#    'child',
#    '?'],
#   'neutral'],
#  [['@',
#    'JetBlue',
#    'loves',
#    'Cancelled',
#    'Flightling',
#    'tickets',
#    'and',
#    'not',
#    'telling',
#    'their',
#    'customers',
#    '#',
#    'flyunited'],
#   'negative'],
#  [['@',
#    'united',
#    'In',
#    'ORD',
#    ',',
#    'waited',
#    '20',
#    'min',
#    'after',
#    'crew',
#    'members',
#    'left',
#    'before',
#    'gate',
#    'items',
#    'came',
#    '.',
#    'Flight',
#    'attendant',
#    'sarcastically',
#    'said',
#    'good',
#    'luck',
#    'and',
#    'walked',
#    'away',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'Jason',
#    '(',
#    '108639',
#    ')',
#    'at',
#    'Gate',
#    '#',
#    '3',
#    'in',
#    'SAN',
#    'made',
#    'my',
#    'afternoon',
#    '!',
#    '!',
#    '!',
#    '#',
#    'southwestairlines',
#    '#',
#    'stellarservice',
#    '#',
#    'thanks',
#    '!'],
#   'positive'],
#  [['@',
#    'AmericanAir',
#    'everything',
#    'for',
#    'sorted',
#    'out',
#    '.',
#    'Thanks',
#    'for',
#    'the',
#    'help',
#    '.',
#    'Excited',
#    'to',
#    'get',
#    'home',
#    'tonight',
#    '!'],
#   'positive'],
#  [['@',
#    'AmericanAir',
#    'understand',
#    'the',
#    'weather',
#    'but',
#    'would',
#    'be',
#    'nice',
#    'to',
#    'hear',
#    'an',
#    'apology',
#    'on',
#    'the',
#    'phone',
#    'when',
#    'you',
#    'moved',
#    'my',
#    'flight',
#    'to',
#    'an',
#    'inconvenient',
#    'day'],
#   'negative'],
#  [['@', 'SouthwestAir', 'and', 'thanks', '!'], 'positive'],
#  [['@',
#    'united',
#    'it',
#    "'s",
#    'been',
#    'booked',
#    'into',
#    'first',
#    'class',
#    'with',
#    'curbside',
#    'delivery',
#    '24',
#    'hours',
#    'from',
#    'now',
#    '.',
#    'I',
#    "'m",
#    'counting',
#    'on',
#    'it',
#    '!',
#    '#',
#    'TeamUSA'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'Oh',
#    'that',
#    'totally',
#    'looks',
#    'on',
#    'par',
#    'with',
#    '@',
#    'AmericanAir',
#    "'s",
#    'Admirals',
#    'Club',
#    ';',
#    'any',
#    'way',
#    'you',
#    'can',
#    'slide',
#    'us',
#    'a',
#    'couple',
#    'passes',
#    '?',
#    ';',
#    ')'],
#   'positive'],
#  [['@',
#    'AmericanAir',
#    'We',
#    "'ve",
#    '15',
#    'official',
#    'complaints',
#    'signed',
#    'by',
#    '#',
#    'AmericanAirlines',
#    'Lima',
#    'supervisor',
#    '.',
#    'Customer',
#    'Relations',
#    'pls',
#    'compensate',
#    '4',
#    'the',
#    '10-hour',
#    'delay'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'but',
#    'the',
#    '4',
#    'hour',
#    'policy-',
#    'when',
#    'I',
#    'called',
#    'and',
#    'they',
#    'said',
#    'I',
#    'did',
#    "n't",
#    'report',
#    'it',
#    'soon',
#    'enough',
#    '.',
#    'What',
#    'would',
#    'have',
#    'changed',
#    'if',
#    'I',
#    'had',
#    'noticed',
#    'sooner',
#    '?'],
#   'negative'],
#  [['@',
#    'united',
#    'the',
#    'most',
#    'frustrating',
#    'flying',
#    'experience',
#    '.',
#    'One',
#    'continuous',
#    '``',
#    'I',
#    'dunno',
#    'what',
#    'time',
#    'you',
#    'will',
#    'leave',
#    'today',
#    '.',
#    '``',
#    '.',
#    'Dunno',
#    '?',
#    '!',
#    'That',
#    "'s",
#    'code',
#    'for',
#    '...',
#    '?'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'Hi',
#    'I',
#    'just',
#    'got',
#    'a',
#    'message',
#    'that',
#    'part',
#    'of',
#    'my',
#    'flights',
#    'is',
#    'Cancelled',
#    'Flightled',
#    '.',
#    'I',
#    'ca',
#    "n't",
#    'rebook',
#    'online',
#    'and',
#    'nobody',
#    'answers',
#    'my',
#    'phone',
#    'call',
#    '.',
#    'Help',
#    'me'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'I',
#    'need',
#    'updates',
#    'on',
#    'my',
#    'flights',
#    '464',
#    '&',
#    'amp',
#    ';',
#    '3574',
#    '.',
#    'I',
#    'have',
#    'been',
#    'on',
#    'hold',
#    'for',
#    'over',
#    '2',
#    'hours',
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'I',
#    "'m",
#    'supposed',
#    'to',
#    'fly',
#    'through',
#    'Dallas',
#    '.',
#    'Can',
#    'you',
#    'help',
#    'me',
#    'get',
#    'a',
#    'new',
#    'itinerary',
#    '?'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'so',
#    'you',
#    'fail',
#    'again',
#    'flight',
#    'to',
#    'rdu',
#    'sitting',
#    'waiting',
#    'on',
#    'flight',
#    'attendants',
#    '.',
#    'your',
#    'logistics',
#    'are',
#    'not',
#    'good'],
#   'negative'],
#  [['@',
#    'united',
#    'I',
#    'am',
#    'impressed',
#    'with',
#    'your',
#    'super-fast',
#    'reply',
#    'to',
#    '@',
#    'CGJase'],
#   'positive'],
#  [['@',
#    'united',
#    'no',
#    'I',
#    'do',
#    "n't",
#    '.',
#    'Spoke',
#    'with',
#    'baggage',
#    'contact',
#    'at',
#    '1-800',
#    'number',
#    '.',
#    'Said',
#    'they',
#    'will',
#    'try',
#    'to',
#    'get',
#    'bags',
#    'to',
#    'stay',
#    'at',
#    'IAD',
#    'for',
#    'pick',
#    'up',
#    'tmrw'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'Who',
#    'intentionally',
#    'buys',
#    'a',
#    'flight',
#    'with',
#    'a',
#    '10',
#    'hour',
#    'layover',
#    '?',
#    'And',
#    'what',
#    'kind',
#    'of',
#    'airline',
#    'would',
#    'charge',
#    '$',
#    '200',
#    'to',
#    'fix',
#    'it',
#    '?',
#    'Wow',
#    '...',
#    '#',
#    'usairways'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'do',
#    'you',
#    'do',
#    'auto',
#    'callbacks',
#    'so',
#    'I',
#    'do',
#    "n't",
#    'have',
#    'to',
#    'wait',
#    'on',
#    'hold',
#    '?'],
#   'negative'],
#  [['@',
#    'united',
#    'can',
#    'I',
#    'get',
#    'your',
#    'service',
#    'desk',
#    '#',
#    'at',
#    'IAD',
#    '?'],
#   'neutral'],
#  [['@',
#    'JetBlue',
#    'your',
#    'blue',
#    'helped',
#    'bring',
#    'out',
#    'the',
#    'color',
#    'of',
#    'my',
#    'eyes',
#    '.',
#    'And',
#    'I',
#    'promise',
#    'I',
#    'did',
#    "n't",
#    'eat',
#    'all',
#    'the',
#    'free',
#    'snacks',
#    '.'],
#   'positive'],
#  [['@',
#    'united',
#    'Yes',
#    '!',
#    ':',
#    'D',
#    '(',
#    'Y',
#    ')',
#    'From',
#    '@',
#    'therealaviation',
#    'on',
#    'Instagram',
#    ':',
#    ')'],
#   'positive'],
#  [['@',
#    'JetBlue',
#    'I',
#    'did',
#    'not',
#    'report',
#    'the',
#    'updated',
#    'info',
#    '-',
#    'do',
#    "n't",
#    'know',
#    'how',
#    'to',
#    'reach',
#    'them',
#    'without',
#    'a',
#    'super',
#    'long',
#    'wait',
#    'on',
#    'hold',
#    'at',
#    'your',
#    'main',
#    'number',
#    '.'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'I',
#    'want',
#    'to',
#    'enter',
#    'the',
#    'family',
#    'pooling',
#    'contest',
#    ',',
#    'it',
#    'says',
#    '``',
#    'by',
#    '2/19',
#    "''",
#    'on',
#    'the',
#    'website',
#    ',',
#    'can',
#    'I',
#    'please',
#    'enter',
#    'still',
#    '!'],
#   'neutral'],
#  [['@',
#    'USAirways',
#    'and',
#    'that',
#    'you',
#    'can',
#    'choose',
#    'the',
#    'same',
#    'seat',
#    'for',
#    'free',
#    'after',
#    'clicking',
#    '100',
#    'buttons',
#    '.'],
#   'neutral'],
#  [['@', 'united', 'plus', 'what', 'about', 'food', '?', 'And', 'taxis', '?'],
#   'negative'],
#  [['@',
#    'USAirways',
#    '3hr30min',
#    'right',
#    'now',
#    '...',
#    'any',
#    'end',
#    'in',
#    'sight',
#    '?'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    ',',
#    'you',
#    "'re",
#    'really',
#    'going',
#    'to',
#    'let',
#    '@',
#    'delta',
#    'and',
#    '@',
#    'virginamerica',
#    'get',
#    'the',
#    'best',
#    'of',
#    'you',
#    '?',
#    'http',
#    ':',
#    '//t.co/vUdWJm1lYB'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'claims',
#    'flight',
#    'Cancelled',
#    'Flighted',
#    'due',
#    'to',
#    'weather',
#    'at',
#    'destination',
#    'but',
#    'Delta',
#    'has',
#    'not',
#    'Cancelled',
#    'Flighted',
#    'flight',
#    'on',
#    'same',
#    'route',
#    '.'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'thanks',
#    'so',
#    'much',
#    'for',
#    'help',
#    'Us',
#    ',',
#    'u',
#    'r',
#    'amazing',
#    '!'],
#   'positive'],
#  [['@',
#    'AmericanAir',
#    'haha',
#    'I',
#    'did',
#    '.',
#    'They',
#    'said',
#    'it',
#    'was',
#    "n't",
#    'their',
#    'fault',
#    'somehow',
#    '?',
#    'You',
#    'guys',
#    'r',
#    'a',
#    'joke'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'your',
#    'customer',
#    'service',
#    'is',
#    'inferior',
#    'to',
#    'that',
#    'of',
#    'a',
#    'nationalized',
#    'third',
#    'world',
#    'nation',
#    "'s",
#    'airline',
#    '.',
#    'Get',
#    'it',
#    'together',
#    '.'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'Why',
#    'does',
#    'your',
#    'iPhone',
#    'app',
#    'not',
#    'have',
#    'any',
#    'sort',
#    'of',
#    'notifications',
#    'option',
#    '?'],
#   'negative'],
#  [['@', 'united', 'thank', 'you', '!'], 'positive'],
#  [['@',
#    'AmericanAir',
#    'I',
#    "'ve",
#    'been',
#    'trying',
#    'to',
#    'reach',
#    'your',
#    'customer',
#    'service',
#    'for',
#    'TWO',
#    'days',
#    '.',
#    'I',
#    'have',
#    'received',
#    'zero',
#    'response',
#    '.',
#    'Never',
#    'traveling',
#    'AA',
#    'again',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    'flight',
#    '4567',
#    'agent',
#    'now',
#    'wandered',
#    'off',
#    '.',
#    'Pilots',
#    'came',
#    'out',
#    'looking',
#    'for',
#    'her',
#    '.',
#    'Went',
#    'to',
#    'charge',
#    'her',
#    'personal',
#    'phone',
#    'which',
#    'she',
#    "'d",
#    'been',
#    'txting',
#    'on'],
#   'negative'],
#  [['@',
#    'united',
#    'first',
#    'you',
#    'lost',
#    'all',
#    'my',
#    'bags',
#    ',',
#    'now',
#    'you',
#    'Cancelled',
#    'Flight',
#    'my',
#    'flight',
#    'home',
#    '.',
#    '30',
#    'min',
#    'wait',
#    'to',
#    'talk',
#    'to',
#    'somebody',
#    '#',
#    'poorservice',
#    '#',
#    'notgoodenough'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'sat',
#    'on',
#    'a',
#    'plane',
#    'for',
#    '2+',
#    'hrs',
#    'on',
#    '2/15',
#    '!',
#    'Then',
#    'we',
#    'finally',
#    'took',
#    'off',
#    '..',
#    ':',
#    '('],
#   'negative'],
#  [['@', 'JetBlue', 'ANYWHERE', '!', '!', 'http', ':', '//t.co/FeFHPmFPlE'],
#   'neutral'],
#  [['@',
#    'USAirways',
#    'I',
#    'have',
#    'to',
#    'spend',
#    'more',
#    'than',
#    'the',
#    'cost',
#    'of',
#    'the',
#    'flight',
#    'just',
#    'to',
#    'get',
#    'a',
#    'free',
#    'room',
#    'and',
#    'transportation',
#    'to',
#    'and',
#    'from',
#    'the',
#    'airport'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'understand',
#    'the',
#    'weather',
#    ',',
#    'these',
#    'kids',
#    'need',
#    'to',
#    'get',
#    'home',
#    '!',
#    'Nice',
#    'kids',
#    'doing',
#    'volunteer',
#    'work',
#    'from',
#    'a',
#    'RI',
#    'high',
#    'school',
#    ',',
#    'please',
#    'help'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'My',
#    'friend',
#    'needs',
#    'some',
#    'help',
#    'on',
#    'her',
#    'flt',
#    '(',
#    'she',
#    "'s",
#    'not',
#    'on',
#    'Twiiter',
#    ')',
#    ',',
#    'can',
#    'I',
#    'DM',
#    'you',
#    'her',
#    'info',
#    '?'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'my',
#    'mom',
#    '’',
#    's',
#    'flight',
#    'tomorrow',
#    'Cancelled',
#    'Flighted',
#    'w/',
#    'no',
#    'notice',
#    '.',
#    'Phone',
#    'system',
#    'said',
#    'callback',
#    'in',
#    '2',
#    'hours',
#    'and',
#    'it',
#    '’',
#    's',
#    'been',
#    '4',
#    '.',
#    'I',
#    'need',
#    'to',
#    'go',
#    'to',
#    'bed',
#    '!'],
#   'negative'],
#  [['@',
#    'americanair',
#    'flight',
#    'veers',
#    'off',
#    'icy',
#    'runway',
#    'at',
#    '@',
#    'dfwairport',
#    '.',
#    'Most',
#    'DFW',
#    'flights',
#    'Cancelled',
#    'Flighted',
#    'Mon',
#    'http',
#    ':',
#    '//t.co/Q37pOWn6uv',
#    '@',
#    'Cowboycerrone',
#    'figures',
#    'right',
#    '?'],
#   'negative'],
#  [['@',
#    'united',
#    'Could',
#    'you',
#    'tell',
#    'me',
#    'if',
#    'this',
#    'bag',
#    'would',
#    'be',
#    'accepted',
#    'as',
#    'a',
#    'personal',
#    'item',
#    '?',
#    'Can',
#    'i',
#    'bring',
#    'one',
#    'carry-on',
#    'bag',
#    'plus',
#    'this',
#    '?',
#    'http',
#    ':',
#    '//t.co/U390cZpLHl'],
#   'neutral'],
#  [['@',
#    'united',
#    'yo',
#    ',',
#    'you',
#    'need',
#    'a',
#    'new',
#    'website',
#    'really',
#    'badly',
#    '.',
#    'This',
#    'day',
#    'and',
#    'age',
#    '...'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    '@',
#    'TheEllenShow',
#    '@',
#    'Imaginedragons',
#    '@',
#    'kdepetro313',
#    '.what',
#    'a',
#    'great',
#    'first',
#    'night',
#    '.',
#    '#',
#    'DestinationDragons',
#    'http',
#    ':',
#    '//t.co/N3LrFo4UaY'],
#   'positive'],
#  [['@',
#    'USAirways',
#    'right',
#    'on',
#    '.',
#    'Up',
#    '.',
#    'Up',
#    '&',
#    'amp',
#    ';',
#    'away',
#    '✈️🌞'],
#   'positive'],
#  [['@',
#    'united',
#    'Now',
#    'about',
#    'two',
#    'dozen',
#    'back',
#    'in',
#    'line',
#    'to',
#    'see',
#    'a',
#    'single',
#    'CSR',
#    'for',
#    'reFlight',
#    'Booking',
#    'Problems',
#    'final',
#    'leg',
#    '.',
#    '(',
#    'Kiosks',
#    'on',
#    'fritz',
#    '.',
#    ')'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'Why',
#    'would',
#    'you',
#    'charge',
#    'money',
#    'to',
#    'transfer',
#    'points',
#    'to',
#    'someone',
#    '?'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'Is',
#    'it',
#    'possible',
#    'to',
#    'earn',
#    'Dividend',
#    'Miles',
#    'for',
#    'a',
#    'passenger',
#    'that',
#    'is',
#    'not',
#    'me',
#    ',',
#    'even',
#    'if',
#    'I',
#    'am',
#    'purchasing',
#    'the',
#    'tickets',
#    '?'],
#   'neutral'],
#  [['Lmfaooo',
#    '“',
#    '@',
#    'JetBlue',
#    ':',
#    'Our',
#    'fleet',
#    "'s",
#    'on',
#    'fleek',
#    '.',
#    'http',
#    ':',
#    '//t.co/1G9RnmYUQe',
#    '”'],
#   'positive'],
#  [['@',
#    'USAirways',
#    'Is',
#    'there',
#    'a',
#    'phone',
#    'line',
#    'to',
#    'call',
#    'into',
#    'that',
#    'is',
#    "n't",
#    'being',
#    'affected',
#    'by',
#    '``',
#    'bad',
#    'weather',
#    "''",
#    '?',
#    'Trying',
#    'to',
#    'book',
#    'a',
#    'vacation',
#    ',',
#    'here',
#    '...',
#    '👀'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'I',
#    'have',
#    'never',
#    'seen',
#    'such',
#    'incompetency',
#    'from',
#    'a',
#    'gate',
#    'agent',
#    'in',
#    'years',
#    'of',
#    'business',
#    'travel',
#    'DFW',
#    'B16',
#    'gate',
#    'agent',
#    'needs',
#    'training',
#    'or',
#    'new',
#    'job'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'F623',
#    'DEN',
#    ':',
#    'PHX',
#    'impressive',
#    'lack',
#    'of',
#    'concern',
#    'by',
#    '1hr+',
#    'Late',
#    'Flight',
#    'flight',
#    'attndt',
#    'wrecking',
#    'havoc',
#    'on',
#    'customer',
#    'travel',
#    '#',
#    'smugsmirk',
#    '#',
#    'norush'],
#   'negative'],
#  [['@',
#    'united',
#    'Have',
#    'clients',
#    'with',
#    'an',
#    '11',
#    'hr',
#    'layover',
#    'at',
#    'IAH',
#    '(',
#    'during',
#    'the',
#    'day',
#    ')',
#    '.',
#    'Will',
#    'they',
#    'have',
#    'to',
#    'claim',
#    '&',
#    'amp',
#    ';',
#    'recheck',
#    'luggage',
#    '.',
#    'Or',
#    'will',
#    'it',
#    'be',
#    'taken',
#    'care',
#    'of',
#    '?'],
#   'neutral'],
#  [['@',
#    'united',
#    'even',
#    'so',
#    ',',
#    'change',
#    'could',
#    'not',
#    'be',
#    'made',
#    'online-',
#    'instructed',
#    'to',
#    'call',
#    'an',
#    'agent-',
#    'maybe',
#    'the',
#    'syastem',
#    'should',
#    'allow',
#    'agents',
#    '2',
#    'link',
#    'passengers',
#    '!'],
#   'negative'],
#  [['@',
#    'united',
#    'you',
#    'ca',
#    "n't",
#    'claim',
#    '``',
#    'weather',
#    "''",
#    'with',
#    'your',
#    'hardworking',
#    'crew',
#    'pulling',
#    'seats',
#    'out',
#    'of',
#    'a',
#    'plane',
#    '!',
#    'Do',
#    'the',
#    'right',
#    'thing',
#    '.',
#    'But',
#    'we',
#    'both',
#    'know',
#    'you',
#    'wo',
#    "n't"],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'finally',
#    'called',
#    '!',
#    'Ca',
#    "n't",
#    'get',
#    'met',
#    'Seattle',
#    'so',
#    'refund',
#    'will',
#    'be',
#    'processed',
#    '.',
#    'Thanks'],
#   'positive'],
#  [['@',
#    'United',
#    'just',
#    'played',
#    'the',
#    'Most',
#    'bizarre',
#    '``',
#    'safety',
#    "''",
#    'video',
#    'I',
#    "'ve",
#    'ever',
#    'seen',
#    '...',
#    'http',
#    ':',
#    '//t.co/Hlm2Oks6xl'],
#   'neutral'],
#  [['@',
#    'SouthwestAir',
#    'I',
#    "'m",
#    'not',
#    'sure',
#    'I',
#    'did',
#    'the',
#    'messaging',
#    'part',
#    'right',
#    '.',
#    'Please',
#    'let',
#    'me',
#    'know',
#    'if',
#    'you',
#    'received',
#    'it',
#    '.'],
#   'neutral'],
#  [['@',
#    'SouthwestAir',
#    'booked',
#    'the',
#    '8th',
#    '....',
#    'Save',
#    'me',
#    'an',
#    'emergency',
#    'exit',
#    '...',
#    'Got',
#    'ta',
#    'stretch',
#    'out'],
#   'neutral'],
#  [['@',
#    'SouthwestAir',
#    'do',
#    'you',
#    'not',
#    'try',
#    'to',
#    'get',
#    'customers',
#    'to',
#    'their',
#    'destinations',
#    '?',
#    'No',
#    'help',
#    'to',
#    'get',
#    'on',
#    'another',
#    'airline',
#    'if',
#    'you',
#    'had',
#    'no',
#    'flights',
#    'for',
#    '3',
#    'days',
#    '?'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'no',
#    '.',
#    'Did',
#    'not',
#    'catch',
#    'his',
#    'name',
#    '.',
#    'I',
#    'am',
#    'sure',
#    'Jason',
#    'will',
#    'know',
#    '.'],
#   'neutral'],
#  [['@',
#    'USAirways',
#    '.',
#    'Yet',
#    'another',
#    'delay/missed',
#    'connection',
#    '....',
#    'and',
#    'your',
#    'customer',
#    'service',
#    'has',
#    'an',
#    'attitude',
#    'with',
#    'me',
#    '?',
#    'Wow',
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'No',
#    'access',
#    'to',
#    'Dividend',
#    'Miles',
#    'and',
#    'for',
#    'a',
#    'week',
#    'the',
#    'automated',
#    'phone',
#    'keeps',
#    'telling',
#    'me',
#    'to',
#    'call',
#    'back',
#    'Late',
#    'Flightr',
#    '.',
#    '#',
#    'FRUSTRATED',
#    '#',
#    'LivePersonPlease'],
#   'negative'],
#  [['@',
#    'united',
#    'When',
#    'will',
#    'direct',
#    'flights',
#    'from',
#    'Belfast',
#    'Intl',
#    'to',
#    'Newark',
#    'resume',
#    'from',
#    'their',
#    'winter',
#    'break',
#    '?',
#    'Thanks',
#    '.'],
#   'neutral'],
#  [['@',
#    'united',
#    'LGJW7B',
#    '.',
#    'I',
#    'voluntarily',
#    'rerouted',
#    ';',
#    '1st',
#    'leg',
#    'of',
#    'journey',
#    'was',
#    'in',
#    'economy',
#    'and',
#    'was',
#    'supposed',
#    'to',
#    'be',
#    '8B',
#    '.',
#    'Res',
#    'agent',
#    'said',
#    'she',
#    "'d",
#    'reserve',
#    'it',
#    'for',
#    'me'],
#   'neutral'],
#  [['@',
#    'SouthwestAir',
#    'Nashville',
#    'airport',
#    'has',
#    'runways',
#    'open',
#    '.',
#    'It',
#    'appears',
#    'southwest',
#    'is',
#    'only',
#    'airline',
#    'Cancelled',
#    'Flighting',
#    'flights',
#    '.',
#    'Is',
#    'this',
#    'likely',
#    'to',
#    'change',
#    '?'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'no',
#    'my',
#    'flight',
#    'plans',
#    'have',
#    'been',
#    'delayed',
#    'until',
#    'tuesday',
#    'due',
#    'to',
#    'your',
#    'computer',
#    'crash'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'This',
#    'is',
#    'unbelievable',
#    '...',
#    'Thank',
#    'you',
#    'so',
#    'much',
#    '!',
#    '#',
#    'DestinationDragons'],
#   'positive'],
#  [['@',
#    'united',
#    'big',
#    'surprise',
#    '#',
#    'nogate',
#    'waiting',
#    'for',
#    'our',
#    'plane',
#    '.',
#    'Same',
#    'fucken',
#    'issues',
#    'everything',
#    'I',
#    'fly',
#    'you',
#    '.',
#    '#',
#    'fail',
#    '#',
#    'worstairlineever'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'tough',
#    'night',
#    ',',
#    'two',
#    '90',
#    'minute',
#    'calls',
#    ',',
#    'on',
#    'hold',
#    ',',
#    'delayed',
#    'here',
#    'in',
#    'Phoenix',
#    'for',
#    'two',
#    'days',
#    'because',
#    'of',
#    'one',
#    'aircraft',
#    'not',
#    'ready',
#    '?',
#    'Not',
#    'acceptable'],
#   'negative'],
#  [['@',
#    'united',
#    'but',
#    'it',
#    "'s",
#    'hard',
#    'to',
#    'stay',
#    'upset',
#    'at',
#    'someone',
#    'when',
#    'they',
#    'at',
#    'least',
#    'TRY',
#    'to',
#    'show',
#    'remorse',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    '50',
#    'min',
#    'on',
#    'hold',
#    'trying',
#    'to',
#    'book',
#    'award',
#    'flight',
#    'because',
#    'site',
#    'errors',
#    'out',
#    '.',
#    'Agents',
#    'ask',
#    'for',
#    'my',
#    'pin',
#    'to',
#    'see',
#    'platinum',
#    'availability',
#    '?',
#    '?',
#    '?',
#    'badbadbad'],
#   'negative'],
#  [['@',
#    'USAirways',
#    '23',
#    'min',
#    'on',
#    'hold',
#    '...',
#    'Drove',
#    '2.5',
#    'hours',
#    'to',
#    'get',
#    'my',
#    'delayed',
#    'bag',
#    '.',
#    'I',
#    'just',
#    'want',
#    'to',
#    'pick',
#    'it',
#    'up',
#    'at',
#    'SJU',
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'how',
#    'do',
#    'I',
#    'reserve',
#    'my',
#    'seat',
#    'on',
#    'the',
#    'AA',
#    'flight',
#    'I',
#    'transfer',
#    'to',
#    'from',
#    'ORD',
#    'to',
#    'EVV',
#    '?'],
#   'neutral'],
#  [['@',
#    'United',
#    'to',
#    'start',
#    '3xdaily',
#    '@',
#    'EmbraerSA',
#    '#',
#    'ERJ145',
#    'flights',
#    'from',
#    '#',
#    'Chicago',
#    '@',
#    'fly2ohare',
#    'to',
#    '#',
#    'Evansville',
#    'on',
#    '4JUN',
#    '#',
#    'avgeek'],
#   'neutral'],
#  [['@',
#    'united',
#    'flight',
#    '1136',
#    'from',
#    'Chicago',
#    'to',
#    'Houston',
#    'over',
#    '2',
#    'hours',
#    'and',
#    'no',
#    'pretzels',
#    'or',
#    'peanuts',
#    '?',
#    '!',
#    'Seriously',
#    'about',
#    'passed',
#    'out',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    'I',
#    'left',
#    'my',
#    'comment',
#    'with',
#    'customer',
#    'care',
#    '.',
#    'Thanks',
#    'for',
#    'contacting',
#    'me',
#    '.'],
#   'positive'],
#  [['@', 'united', 'They', 'held', 'the', 'plane', '!', 'Made', 'it', '!', '!'],
#   'positive'],
#  [['@',
#    'AmericanAir',
#    'That',
#    "'s",
#    'ok',
#    '...',
#    'You',
#    'may',
#    'keep',
#    'my',
#    '$',
#    '25',
#    'and',
#    'lose',
#    'my',
#    'bag',
#    'with',
#    'no',
#    'info',
#    ',',
#    'but',
#    'you',
#    'no',
#    'longer',
#    'have',
#    'my',
#    'trust',
#    '.',
#    'Bad',
#    'way',
#    'to',
#    'handle',
#    'this',
#    '.'],
#   'negative'],
#  [['@', 'VirginAmerica', 'is', 'that', '#', 'thestarter', '?', '?', '😁'],
#   'neutral'],
#  [['@',
#    'JetBlue',
#    'Learning',
#    'about',
#    'your',
#    'awesome',
#    'twitter',
#    'management',
#    'today',
#    'in',
#    'my',
#    'Social',
#    'Media',
#    'Marketing',
#    'class',
#    '!',
#    'keep',
#    'up',
#    'the',
#    'good',
#    'work',
#    '!',
#    '@',
#    'SXU',
#    '@',
#    'PhD_Mama_'],
#   'positive'],
#  [['@',
#    'AmericanAir',
#    'dropping',
#    'the',
#    'ball',
#    '.',
#    'Again',
#    '.',
#    'No',
#    'catering',
#    '.',
#    'Plane',
#    'switch',
#    '.',
#    'No',
#    'gate',
#    'attendant',
#    '.',
#    '2',
#    'hours',
#    'Late',
#    'Flight',
#    '.',
#    'Really',
#    'nice',
#    '.'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'good',
#    'care',
#    'of',
#    'their',
#    'customers',
#    'if',
#    'anything',
#    'happen',
#    'to',
#    'then',
#    'take',
#    'you',
#    '@',
#    'Delta',
#    'for',
#    'getting',
#    'me',
#    'back',
#    'to',
#    'NYC',
#    '!',
#    '!',
#    'Screw',
#    'you',
#    '@',
#    'AmericanAir'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'I',
#    'do',
#    "n't",
#    'think',
#    'you',
#    'should',
#    'help',
#    'him',
#    'at',
#    'all',
#    'based',
#    'on',
#    'his',
#    'behavior',
#    '.',
#    'The',
#    'voucher',
#    'and',
#    'cot',
#    'seem',
#    'like',
#    'enough',
#    'lol',
#    '😃'],
#   'neutral'],
#  [['@',
#    'united',
#    'I',
#    'think',
#    'problem',
#    'resolution',
#    'should',
#    'be',
#    'decided',
#    'on',
#    'your',
#    'end',
#    '.',
#    'Especially',
#    'if',
#    'you',
#    "'d",
#    'like',
#    'me',
#    'to',
#    'continue',
#    'flying',
#    'your',
#    'airline',
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'I',
#    "'ve",
#    'been',
#    'on',
#    'hold',
#    'for',
#    '36',
#    'mins',
#    'and',
#    'counting',
#    'cause',
#    'you',
#    'charged',
#    'my',
#    'credit',
#    'card',
#    'for',
#    'bag',
#    'but',
#    'provided',
#    'no',
#    'receipt',
#    'and',
#    'said',
#    'error',
#    '.',
#    'Awful'],
#   'negative'],
#  [['@',
#    'united',
#    'great',
#    '.',
#    'Looking',
#    'forward',
#    'to',
#    'your',
#    'response',
#    'to',
#    'my',
#    'DM',
#    'then'],
#   'positive'],
#  [['@',
#    'united',
#    'it',
#    "'s",
#    'my',
#    '21st',
#    'birthday',
#    'and',
#    'my',
#    'sister',
#    'is',
#    'coming',
#    'to',
#    'celebrate',
#    'but',
#    'her',
#    'flights',
#    'keep',
#    'Cancelled',
#    'Flighting',
#    'PLZ',
#    'do',
#    'all',
#    'you',
#    'can',
#    'to',
#    'get',
#    'her',
#    'here',
#    '!',
#    '!',
#    '!',
#    '!'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'UR',
#    'employee',
#    'named',
#    'VAN',
#    '@',
#    'ticket',
#    'counter',
#    'in',
#    '#',
#    'Philadelphia',
#    '.',
#    'EXTREMELY',
#    'RUDE',
#    '!',
#    'a',
#    'Father',
#    'trying',
#    'to',
#    'get',
#    'home',
#    'to',
#    'sick',
#    'kid',
#    'missed',
#    'flight',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'Horrible',
#    'experience',
#    'ever',
#    'with',
#    'airline',
#    '..',
#    'Have',
#    'to',
#    'reconsider',
#    'any',
#    'future',
#    'flights',
#    '.',
#    'Customer',
#    'service',
#    '...',
#    'http',
#    ':',
#    '//t.co/EczHcmM5vi'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'for',
#    'tomorrow',
#    'some',
#    'sites',
#    'show',
#    'flight',
#    '1642',
#    'from',
#    'ewr',
#    'Cancelled',
#    'Flightled',
#    ',',
#    'is',
#    'it',
#    '?'],
#   'negative'],
#  [['@',
#    'VirginAmerica',
#    'I',
#    'like',
#    'the',
#    'customer',
#    'service',
#    'but',
#    'a',
#    '40',
#    'min',
#    'delay',
#    'just',
#    'for',
#    'connecting',
#    'passengers',
#    'seems',
#    'too',
#    'long',
#    '.',
#    'VA370'],
#   'negative'],
#  [['@',
#    'VirginAmerica',
#    'cutest',
#    'salt',
#    'and',
#    'pepper',
#    'shaker',
#    'ever',
#    '.',
#    'Just',
#    'when',
#    'I',
#    'think',
#    'you',
#    'guys',
#    'ca',
#    "n't",
#    'get',
#    'any',
#    'better',
#    'you',
#    'just',
#    'do',
#    '!',
#    'http',
#    ':',
#    '//t.co/vC6Keulg2J'],
#   'positive'],
#  [['@',
#    'AmericanAir',
#    'Unbelievable',
#    'that',
#    'I',
#    'can',
#    'not',
#    'even',
#    'wait',
#    'on',
#    'hold',
#    'to',
#    'speak',
#    'to',
#    'a',
#    'human',
#    'being',
#    'to',
#    'resolve',
#    'my',
#    'issue',
#    '!',
#    '!',
#    '!',
#    '!',
#    '!',
#    '!',
#    '!',
#    '!',
#    'The',
#    'system',
#    'simply',
#    'hangs',
#    'up',
#    '!'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'continues',
#    'to',
#    'win',
#    ':',
#    'I',
#    "'ve",
#    'never',
#    'missed',
#    'a',
#    'flight',
#    'before',
#    ',',
#    'but',
#    'a',
#    'nice',
#    'little',
#    'quiet',
#    'gate',
#    'change',
#    'made',
#    'it',
#    'possible',
#    '.',
#    'Sheesh',
#    '.'],
#   'positive'],
#  [['@',
#    'USAirways',
#    'we',
#    'even',
#    'offered',
#    'to',
#    'fly',
#    'in',
#    'to',
#    'another',
#    'airport',
#    'and',
#    'they',
#    'said',
#    'they',
#    'could',
#    "n't",
#    'do',
#    'that',
#    '.',
#    'No',
#    'explanation',
#    'why',
#    'they',
#    'ca',
#    "n't",
#    '.'],
#   'neutral'],
#  [['@',
#    'USAirways',
#    'the',
#    'phone',
#    'number',
#    'the',
#    'gate',
#    'gave',
#    'me',
#    'does',
#    "n't",
#    'work',
#    'either',
#    '.',
#    'What',
#    'is',
#    'your',
#    'customer',
#    'service',
#    'phone',
#    'number',
#    '?'],
#   'negative'],
#  [['@', 'JetBlue', 'flight', '1041', 'to', 'Savannah', ',', 'GA'], 'neutral'],
#  [['@',
#    'AmericanAir',
#    'yes',
#    'but',
#    'you',
#    'are',
#    'still',
#    'human',
#    'I',
#    'hope',
#    ',',
#    'dealing',
#    'with',
#    'all',
#    'the',
#    'horror',
#    'stories',
#    'people',
#    'share',
#    '...',
#    'I',
#    'complained',
#    'to',
#    'DOT',
#    '.',
#    'Everyone',
#    'should'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'they',
#    'are',
#    'now',
#    'being',
#    'sent',
#    'off',
#    'the',
#    'plane',
#    '?',
#    'Does',
#    'anyone',
#    'at',
#    'JetBlue',
#    'have',
#    'a',
#    'clue',
#    '?'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'do',
#    'you',
#    'have',
#    'all',
#    'winners',
#    'for',
#    '@',
#    'Imaginedragons',
#    '#',
#    'DestinationDragons'],
#   'neutral'],
#  [['@',
#    'united',
#    'quick',
#    '(',
#    'serious',
#    ')',
#    'question',
#    '-',
#    'any',
#    'resources/ratings',
#    'showing',
#    'the',
#    'quality',
#    'of',
#    'service',
#    'is',
#    'better',
#    'than',
#    '8th',
#    'place',
#    '?',
#    'http',
#    ':',
#    '//t.co/deWIthPeW2'],
#   'negative'],
#  [['@',
#    'united',
#    'can',
#    'you',
#    'not',
#    'get',
#    'the',
#    'first',
#    'flight',
#    'of',
#    'the',
#    'day',
#    'off',
#    'the',
#    'ground',
#    'on',
#    'time',
#    '?',
#    '#',
#    '1531',
#    '.',
#    'Let',
#    "'s",
#    'go',
#    '.......'],
#   'negative'],
#  [['“',
#    '@',
#    'SouthwestAir',
#    ':',
#    'Southwest',
#    'mobile',
#    'boarding',
#    'passes',
#    'now',
#    'available',
#    'in',
#    'iOS',
#    'Passbook',
#    '!',
#    'http',
#    ':',
#    '//t.co/xmRvR4lGEg',
#    'http',
#    ':',
#    '//t.co/wJoc9f14SU',
#    '”',
#    '@',
#    'tori_leggieri'],
#   'neutral'],
#  [['@', 'SouthwestAir', 'I', "'m", 'stuck', 'in', 'Fort', 'Lauderdale', '.'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'I',
#    'clear',
#    'that',
#    'folder',
#    'regularly',
#    'and',
#    'JetBlue',
#    'is',
#    'white',
#    'listed',
#    'so',
#    'it',
#    'never',
#    'got',
#    'to',
#    'me',
#    '.'],
#   'neutral'],
#  [['@',
#    'united',
#    'Keep',
#    'the',
#    'flights',
#    'cheap',
#    'and',
#    'early/on',
#    'time',
#    'and',
#    'you',
#    'are',
#    'good',
#    '.',
#    'Flew',
#    '@',
#    'AmericanAir',
#    'and',
#    'Cancelled',
#    'Flightled',
#    'my',
#    'flight',
#    '4',
#    'times',
#    'last',
#    'month',
#    '.',
#    'United',
#    '&',
#    'gt',
#    ';'],
#   'positive'],
#  [['@',
#    'JetBlue',
#    'I',
#    'believe',
#    'it',
#    "'s",
#    'Irina',
#    '.',
#    'On',
#    'the',
#    'flip-side',
#    ',',
#    'super',
#    'disappointed',
#    'that',
#    'EatUp',
#    'Cafe',
#    'is',
#    "n't",
#    'available',
#    'on',
#    'this',
#    'BOS',
#    '--',
#    '&',
#    'gt',
#    ';',
#    'SFO',
#    'flight',
#    'today',
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    '5534',
#    '.',
#    'That',
#    "'s",
#    'the',
#    'flight',
#    'I',
#    'was',
#    'placed',
#    'on',
#    'after',
#    'original',
#    'flight',
#    'to',
#    'Charlotte',
#    'was',
#    'Cancelled',
#    'Flightled',
#    '.',
#    'Now',
#    '5534',
#    'is',
#    'on',
#    '1hr',
#    'delay'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'The',
#    'captain',
#    'turned',
#    'off',
#    'the',
#    'seat',
#    'belt',
#    'sign',
#    'so',
#    'people',
#    'can',
#    'get',
#    'up',
#    'and',
#    'walk',
#    'around',
#    '.',
#    'That',
#    "'s",
#    'not',
#    'good',
#    '.'],
#   'negative'],
#  [['@',
#    'United',
#    'now',
#    'what',
#    '?',
#    '!',
#    '?',
#    'http',
#    ':',
#    '//t.co/5hpSqVRjK8',
#    'flight',
#    'was',
#    'gone',
#    'when',
#    'I',
#    'got',
#    'off',
#    'plane',
#    '!',
#    '#',
#    'BusinessTravel',
#    '#',
#    'goodenoughmother'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'Call',
#    'me',
#    'Chairman',
#    ',',
#    'or',
#    'call',
#    'me',
#    'Emerald',
#    '.',
#    'After',
#    'what',
#    'you',
#    'did',
#    'today',
#    'to',
#    'me',
#    ',',
#    'you',
#    'can',
#    'call',
#    'me',
#    'a',
#    'former',
#    'customer',
#    '.'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'we',
#    'saw',
#    'one',
#    ',',
#    'he',
#    'was',
#    'as',
#    'useless',
#    'as',
#    'the',
#    'tsa',
#    'agents',
#    'who',
#    'inspected',
#    'my',
#    'shoes'],
#   'negative'],
#  [['@', 'united', 'Thank', 'you', 'for', 'your', 'response', '!'], 'neutral'],
#  [['@',
#    'AmericanAir',
#    'no',
#    'one',
#    'received',
#    'text',
#    'alerts',
#    ',',
#    'automated',
#    'calls',
#    ',',
#    'anything',
#    'either',
#    '.',
#    'Literally',
#    'no',
#    'information',
#    'as',
#    'to',
#    'what',
#    'was',
#    'happening',
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'made',
#    'it',
#    '!',
#    '!',
#    '!',
#    'Send',
#    'Bloody',
#    'Mary',
#    "'s",
#    'to',
#    'row',
#    '27',
#    '!',
#    '!',
#    '!'],
#   'positive'],
#  [['@',
#    'united',
#    '5',
#    'gate',
#    'changes',
#    ',',
#    'two',
#    'delays',
#    '.',
#    'Even',
#    'the',
#    'crew',
#    'thinks',
#    'the',
#    'airline',
#    'sucks'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'Thank',
#    'You',
#    'for',
#    'your',
#    'empathy',
#    'there',
#    'is',
#    'more',
#    'to',
#    'this',
#    'story',
#    'than',
#    'just',
#    'the',
#    'luggage',
#    'but',
#    'thank',
#    'you',
#    'for',
#    'reaching',
#    'out'],
#   'positive'],
#  [['@',
#    'JetBlue',
#    'Thanks',
#    'JB',
#    '.',
#    'Actually',
#    ',',
#    'As',
#    'a',
#    'birder',
#    'I',
#    'love',
#    'them',
#    'too',
#    '.',
#    'They',
#    'just',
#    'need',
#    'to',
#    'be',
#    'outside',
#    '.',
#    'It',
#    'should',
#    "n't",
#    'be',
#    'too',
#    'hard',
#    'to',
#    'trap',
#    'and',
#    'move',
#    'them',
#    '.'],
#   'positive'],
#  [['@',
#    'USAirways',
#    'flt',
#    '5302',
#    'CLT',
#    'to',
#    'DAY',
#    'supposed',
#    'to',
#    'depart',
#    '5:51',
#    ';',
#    'the',
#    '6:20',
#    '...',
#    'still',
#    'no',
#    'crew',
#    '.',
#    '#',
#    'schedule/contact',
#    'the',
#    'pilot',
#    '!'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'to',
#    'allow',
#    'payment',
#    'by',
#    '#',
#    'Apple',
#    'Pay',
#    '-',
#    'Patriarc',
#    'http',
#    ':',
#    '//t.co/bdUaUZFhW2'],
#   'neutral'],
#  [['@',
#    'united',
#    'and',
#    'now',
#    'your',
#    'rep',
#    'just',
#    'hung',
#    'up',
#    'on',
#    'me',
#    'after',
#    'over',
#    '35',
#    'mins',
#    'on',
#    'hold',
#    'because',
#    'I',
#    'asked',
#    'for',
#    'a',
#    'supervisor',
#    '.',
#    'I',
#    "'m",
#    'furious',
#    'right',
#    'now',
#    '.'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'no',
#    'you',
#    "'re",
#    'not',
#    'you',
#    "'re",
#    'trying',
#    'to',
#    'book',
#    'me',
#    'PAST',
#    'when',
#    'i',
#    'need',
#    '2',
#    'arrive',
#    'but',
#    'you',
#    "'re",
#    'still',
#    'selling',
#    'seats',
#    'on',
#    'the',
#    'day',
#    'I',
#    "'m",
#    'trying',
#    '2',
#    'travel'],
#   'negative'],
#  [['@',
#    'USAirways',
#    '@',
#    'AmericanAir',
#    'seriously',
#    'with',
#    'all',
#    'the',
#    'service',
#    'issues',
#    'you',
#    'are',
#    'having',
#    'right',
#    'now',
#    'this',
#    'is',
#    'what',
#    'you',
#    'decide',
#    'to',
#    'tweet',
#    '?',
#    '?',
#    'Unbelievable'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'will',
#    'do',
#    '.',
#    'I',
#    'also',
#    'passed',
#    'the',
#    'website',
#    'around',
#    'to',
#    'other',
#    'passengers',
#    '.'],
#   'neutral'],
#  [['@',
#    'united',
#    'clicked',
#    'on',
#    'the',
#    'link',
#    'and',
#    'got',
#    'this',
#    '?',
#    '#',
#    'confused',
#    'http',
#    ':',
#    '//t.co/xMAQcucWZl'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'well',
#    'we',
#    'cleared',
#    'customs',
#    'in',
#    'AUH',
#    '.',
#    'I',
#    'need',
#    'to',
#    'get',
#    'to',
#    'IAH',
#    'after',
#    'I',
#    'arrive',
#    'in',
#    'DFW',
#    '.',
#    'Is',
#    'it',
#    'possible',
#    'to',
#    'retrieve',
#    'my',
#    'luggage',
#    'in',
#    'IAD',
#    '?'],
#   'neutral'],
#  [['@',
#    'SouthwestAir',
#    '@',
#    'TaylorLumsden',
#    'Taylor',
#    '.',
#    'U',
#    'got',
#    'ta',
#    'love',
#    'SWA',
#    'responsiveness',
#    'at',
#    'the',
#    '@',
#    'very',
#    'least',
#    'huh',
#    '?'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'flights',
#    'been',
#    'Cancelled',
#    'Flightled',
#    ',',
#    'ca',
#    "n't",
#    'get',
#    'through',
#    'to',
#    'the',
#    'desk',
#    'and',
#    'nothing',
#    'showing',
#    'online',
#    'under',
#    'my',
#    'reservation',
#    '-',
#    'what',
#    'do',
#    'I',
#    'do',
#    '?'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    '@',
#    'USAirways',
#    '-',
#    'I',
#    "'m",
#    'pregnant',
#    'with',
#    'twins',
#    'and',
#    'you',
#    "'re",
#    'going',
#    'to',
#    'abandon',
#    'me',
#    'overnight',
#    'in',
#    'an',
#    'airport',
#    '?',
#    'No',
#    'hotel',
#    '?',
#    'When',
#    'it',
#    "'s",
#    'your',
#    'fault',
#    '?'],
#   'negative'],
#  [['@',
#    'united',
#    'thanks',
#    'for',
#    'prompt',
#    'response',
#    '.',
#    'Another',
#    'hour',
#    'to',
#    'enjoy',
#    'vacation',
#    '!',
#    'Perhaps',
#    'a',
#    'bug',
#    'in',
#    'the',
#    'app',
#    'as',
#    'it',
#    'still',
#    'shows',
#    '2:55',
#    '.'],
#   'positive'],
#  [['@',
#    'united',
#    'tried',
#    'that',
#    '.',
#    'Can',
#    'not',
#    'figure',
#    'out',
#    'where',
#    'to',
#    'go',
#    'to',
#    'get',
#    'it',
#    '.'],
#   'neutral'],
#  [['@',
#    'united',
#    'except',
#    'all',
#    'of',
#    'that',
#    'delayed',
#    'the',
#    'flight',
#    'anyway',
#    '.'],
#   'negative'],
#  [['@', 'JetBlue', 'get', 'flight', '16', 'into', 'the', 'air'], 'negative'],
#  [['@',
#    'united',
#    'let',
#    'me',
#    'assure',
#    'you',
#    'my',
#    'travel',
#    'time',
#    'is',
#    '4h2m',
#    'not',
#    '5h2m',
#    '#',
#    'timezones',
#    '#',
#    'accuratetraveltimes',
#    '#',
#    '3rdtimethishashappened',
#    'http',
#    ':',
#    '//t.co/e0C9bI09cf'],
#   'negative'],
#  [['@',
#    'united',
#    ':',
#    'thanks',
#    '!',
#    'i',
#    'will',
#    'catch',
#    'my',
#    'conection',
#    '!',
#    ':',
#    ')'],
#   'positive'],
#  [['“',
#    '@',
#    'JetBlue',
#    ':',
#    'Our',
#    'fleet',
#    "'s",
#    'on',
#    'fleek',
#    '.',
#    'http',
#    ':',
#    '//t.co/aJM3BhJVaa',
#    '”',
#    '#',
#    'foh'],
#   'neutral'],
#  [['@',
#    'VirginAmerica',
#    'I',
#    'am',
#    'all',
#    'about',
#    'the',
#    'in',
#    'flight',
#    'artisanal',
#    'cheese',
#    'and',
#    'wine',
#    'pairing',
#    '.'],
#   'positive'],
#  [['@',
#    'united',
#    'flight',
#    'UA3364',
#    'been',
#    'sitting',
#    'on',
#    'tarmac',
#    'for',
#    '30',
#    'mins',
#    'with',
#    'no',
#    'report',
#    'as',
#    'to',
#    'why',
#    '...',
#    'any',
#    'input',
#    '?'],
#   'negative'],
#  [['@', 'USAirways', 'sits', 'on', 'a', 'throne', 'of', 'lies'], 'negative'],
#  [['@',
#    'SouthwestAir',
#    '3',
#    'flights',
#    'Cancelled',
#    'Flightled',
#    'today',
#    '.',
#    'Now',
#    'we',
#    'have',
#    'been',
#    'on',
#    'hold',
#    'for',
#    'over',
#    'an',
#    'hour',
#    '!'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'Late',
#    'Flightly',
#    'you',
#    "'ve",
#    'always',
#    'been',
#    'Late',
#    'Flight',
#    '!',
#    'Please',
#    'get',
#    'back',
#    'to',
#    'the',
#    'old',
#    '#',
#    'SWA',
#    '!',
#    '!'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'My',
#    'ex-boyfriend',
#    'picks',
#    'up',
#    'my',
#    'calls',
#    'more',
#    'than',
#    'you',
#    'do',
#    '!',
#    '#',
#    'Cancelled',
#    'Flightedflight',
#    '#',
#    'nocustomerservice',
#    '#',
#    'americanairlines',
#    '#',
#    'FAIL'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'I',
#    'WOULD',
#    'DO',
#    'ANYTHING',
#    'FOR',
#    'tickets',
#    'to',
#    'the',
#    'VEGAS',
#    '...',
#    'ANYTHING',
#    '.',
#    'I',
#    'love',
#    'imagine',
#    'dragons',
#    'so',
#    'much',
#    '!',
#    '!'],
#   'positive'],
#  [['@',
#    'SouthwestAir',
#    'thanks',
#    'for',
#    'your',
#    'attention',
#    ',',
#    'I',
#    "'ve",
#    'been',
#    'flying',
#    'southwest',
#    'for',
#    '3',
#    'years',
#    'and',
#    'have',
#    "n't",
#    'had',
#    'this',
#    'issue',
#    'in',
#    'the',
#    'past',
#    '.'],
#   'positive'],
#  [['@',
#    'USAirways',
#    'never',
#    'let',
#    "'s",
#    'me',
#    'down',
#    ',',
#    'every',
#    '.',
#    'Single',
#    '.',
#    'Flight',
#    '.',
#    'Gets',
#    'delayed',
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'me',
#    'and',
#    'my',
#    'wife',
#    'will',
#    'be',
#    'flying',
#    'out',
#    'of',
#    'atlanta',
#    'to',
#    'vegas',
#    'on',
#    'March',
#    '7th',
#    'since',
#    'could',
#    "n't",
#    'get',
#    'any',
#    'out',
#    'of',
#    'tricities',
#    'here',
#    'in',
#    'Tn'],
#   'neutral'],
#  [['@',
#    'united',
#    'Flight',
#    'UA1665',
#    'got',
#    'delayed',
#    '2',
#    'hours',
#    'due',
#    'to',
#    'a',
#    'mechanical',
#    'issue',
#    '...',
#    'could',
#    'use',
#    'a',
#    'free',
#    'drink',
#    'or',
#    '3',
#    'to',
#    'make',
#    'up',
#    'for',
#    'this',
#    'inconvenience'],
#   'negative'],
#  [['@',
#    'VirginAmerica',
#    'DREAM',
#    'http',
#    ':',
#    '//t.co/oA2dRfAoQ2',
#    'http',
#    ':',
#    '//t.co/lWWdAc2kHx'],
#   'neutral'],
#  [['@',
#    'SouthwestAir',
#    'I',
#    "'m",
#    'in',
#    'line',
#    'at',
#    'the',
#    'airport',
#    'right',
#    'now',
#    '.',
#    'Will',
#    'you',
#    'cover',
#    'hotel',
#    'fair',
#    'or',
#    'am',
#    'I',
#    'to',
#    'sleep',
#    'in',
#    'the',
#    'airport',
#    '?'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'I',
#    'do',
#    "n't",
#    'know-',
#    'no',
#    'one',
#    'would',
#    'tell',
#    'me',
#    'where',
#    'they',
#    'were',
#    'coming',
#    'from',
#    '-',
#    'I',
#    'would',
#    'guess',
#    'so',
#    'as',
#    'that',
#    "'s",
#    'where',
#    'we',
#    'had',
#    'all',
#    'the',
#    'changes',
#    'to',
#    'flights'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'no',
#    'worries',
#    'you',
#    "'re",
#    'swamped',
#    'I',
#    'know',
#    'just',
#    'dmd',
#    'back',
#    'THANK',
#    'U'],
#   'neutral'],
#  [['@',
#    'SouthwestAir',
#    'i',
#    'forgot',
#    'to',
#    'put',
#    'my',
#    'tsa',
#    'pre',
#    'number',
#    'in',
#    'before',
#    'I',
#    'checked',
#    'in',
#    '.',
#    'It',
#    'is',
#    'now',
#    'in',
#    'my',
#    'profile',
#    'but',
#    'will',
#    'it',
#    'be',
#    'on',
#    'my',
#    'boarding',
#    'pass',
#    'in',
#    'the',
#    'am'],
#   'neutral'],
#  [['@', 'SouthwestAir', 'have', 'five', 'people', 'shown', 'up', 'yet'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'I',
#    "'ve",
#    'never',
#    'had',
#    'anything',
#    'bad',
#    'to',
#    'say',
#    'until',
#    'now',
#    '.',
#    'No',
#    'love',
#    'for',
#    'faithful',
#    'customers',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    ':',
#    'Hello',
#    '..',
#    'are',
#    'flights',
#    'taking',
#    'off',
#    'from',
#    '@',
#    'DallasLoveField',
#    'airport',
#    'this',
#    'noon',
#    '.',
#    'Am',
#    'supposed',
#    'to',
#    'travel',
#    'on',
#    'flight',
#    '376',
#    'to',
#    'San',
#    'antonio'],
#   'neutral'],
#  [['@',
#    'SouthwestAir',
#    'I',
#    'love',
#    'and',
# ...
#    'united',
#    'this',
#    'is',
#    'for',
#    'a',
#    'check-in',
#    'luggage',
#    '.',
#    'Employee',
#    'told',
#    'me',
#    'not',
#    'to',
#    'include',
#    'wheels',
#    'in',
#    'the',
#    'dimensions',
#    '.'],
#   'neutral'],
#  [['@',
#    'united',
#    '25',
#    'minute',
#    'hold',
#    'is',
#    '1',
#    'hr',
#    '.',
#    '25',
#    'min',
#    '.',
#    '@',
#    'ABC11_WTVD'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'You',
#    'guys',
#    'are',
#    'screwing',
#    'up',
#    'my',
#    'trip',
#    '.',
#    'Thanks',
#    'for',
#    'nothing',
#    '.',
#    '#',
#    'lazy'],
#   'negative'],
#  [['@',
#    'united',
#    'the',
#    'passengers',
#    'waited',
#    'inside',
#    'the',
#    'flight',
#    'on',
#    'the',
#    'runway',
#    'and',
#    'returned',
#    'back',
#    'in',
#    'o',
#    'gate',
#    'that',
#    'should',
#    'not',
#    'count',
#    'as',
#    'a',
#    'valid',
#    'journey'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'Frustrating',
#    'days',
#    '!',
#    'No',
#    'flights',
#    'home',
#    ',',
#    'changed',
#    'airlines',
#    '.',
#    'Thank',
#    'you',
#    'PHL',
#    'USAirway',
#    'employees',
#    '&',
#    'amp',
#    ';',
#    '@',
#    'united',
#    'for',
#    'help',
#    'getting',
#    'me',
#    'back',
#    'to',
#    'IAH',
#    '.'],
#   'positive'],
#  [['@',
#    'united',
#    'u',
#    'guys',
#    'did',
#    'it',
#    'again',
#    'changed',
#    'ages',
#    'and',
#    'double',
#    'booked',
#    'seats',
#    'so',
#    'I',
#    'had',
#    'to',
#    'I',
#    "'ve",
#    'even',
#    'though',
#    'I',
#    'have',
#    'platinum',
#    'and',
#    'the',
#    'other',
#    'person',
#    'none'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'Cancelled',
#    'Flightled',
#    'the',
#    'last',
#    'part',
#    'of',
#    'a',
#    'ticket',
#    'and',
#    'am',
#    'confused',
#    'from',
#    'the',
#    'email',
#    'I',
#    'received',
#    'whether',
#    'value',
#    'remains',
#    '.',
#    'Is',
#    'there',
#    'someone',
#    'I',
#    'can',
#    'ask',
#    '?'],
#   'neutral'],
#  [['@',
#    'united',
#    'If',
#    'a',
#    'business',
#    'decision',
#    'is',
#    'made',
#    'that',
#    'inconveniences',
#    'and',
#    'possibly',
#    'causes',
#    'lost',
#    'customers',
#    ',',
#    'is',
#    'it',
#    'a',
#    'good',
#    'business',
#    'decision',
#    '?',
#    '#',
#    'Cranky'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'my',
#    'flight',
#    'got',
#    'Cancelled',
#    'Flightled',
#    'to',
#    'Charlotte',
#    '.',
#    'Been',
#    'on',
#    'hold',
#    'for',
#    'an',
#    'hour',
#    ',',
#    'pls',
#    'pick',
#    'up',
#    '!'],
#   'negative'],
#  [['@', 'VirginAmerica', 'wow', 'this', 'just', 'blew', 'my', 'mind'],
#   'positive'],
#  [['@',
#    'AmericanAir',
#    'AA2416',
#    'on',
#    'time',
#    'and',
#    'awesome',
#    'flight',
#    '.',
#    'Great',
#    'job',
#    'American',
#    '!'],
#   'positive'],
#  [['@',
#    'SouthwestAir',
#    'did',
#    "n't",
#    'realize',
#    'no',
#    'clothes',
#    'until',
#    'at',
#    'hotel',
#    '-',
#    'suggestions',
#    '?'],
#   'neutral'],
#  [['@',
#    'SouthwestAir',
#    'got',
#    'mine',
#    '!',
#    'Just',
#    'in',
#    'time',
#    'for',
#    'the',
#    'wife',
#    'and',
#    'my',
#    '15th',
#    'anniversary',
#    '!'],
#   'positive'],
#  [['“',
#    '@',
#    'SouthwestAir',
#    ':',
#    '@',
#    'pancho_joe',
#    'No',
#    ',',
#    'no',
#    ',',
#    'you',
#    'must',
#    "'ve",
#    'heard',
#    'us',
#    'wrong',
#    '.',
#    'Sweet',
#    'mixtape',
#    ',',
#    'though',
#    "''",
#    '4',
#    'the',
#    'record',
#    ',',
#    'I',
#    'did',
#    "n't",
#    'leave',
#    'the',
#    '80',
#    "'s",
#    ',',
#    'the',
#    '80',
#    "'s",
#    'left',
#    'me'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    'Sitting',
#    'at',
#    'the',
#    'gate',
#    'on',
#    'Flight',
#    '719',
#    'for',
#    'an',
#    'hour',
#    'due',
#    'to',
#    'Sabre',
#    'being',
#    'down',
#    '.',
#    'What',
#    'backup',
#    'plan',
#    'is',
#    'in',
#    'place',
#    'if',
#    'Sabre',
#    'can',
#    'not',
#    'be',
#    'fixed',
#    '?'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'is',
#    'my',
#    'favorite',
#    'airlines',
#    '.',
#    'I',
#    "'ve",
#    'never',
#    'had',
#    'issues',
#    'with',
#    'them',
#    '.',
#    'Plus',
#    'there',
#    'crew',
#    'is',
#    'entertaining',
#    '.'],
#   'positive'],
#  [['@',
#    'USAirways',
#    'I',
#    'made',
#    'it',
#    '!',
#    'Thanks',
#    'for',
#    'the',
#    'help',
#    '!'],
#   'positive'],
#  [['@',
#    'USAirways',
#    'is',
#    'utterly',
#    'unreliable',
#    '!',
#    'They',
#    'did',
#    "n't",
#    'schedule',
#    'a',
#    'pilot',
#    'for',
#    'their',
#    'US624',
#    'flight',
#    'out',
#    'of',
#    'Seattle',
#    '-',
#    'flights',
#    'are',
#    'delayed',
#    '#',
#    'usairwaysfail'],
#   'negative'],
#  [['@',
#    'southwestair',
#    'TREMENDOUS',
#    'job',
#    '.',
#    'Atlanta',
#    'Airport',
#    'saw',
#    'SW',
#    'celebrate',
#    'Mardi',
#    'Gras',
#    '.',
#    'Another',
#    'reason',
#    'I',
#    "'m",
#    'nuts',
#    'for',
#    'you',
#    'guys',
#    '!',
#    'http',
#    ':',
#    '//t.co/8WBzOrRn3C'],
#   'neutral'],
#  [['@',
#    'united',
#    'it',
#    'seems',
#    'like',
#    'no',
#    'one',
#    'from',
#    'United',
#    'can',
#    'help',
#    'me',
#    '.',
#    'Lots',
#    'of',
#    'fingers',
#    'pointed',
#    ',',
#    'zero',
#    'people',
#    'stepping',
#    'up',
#    '.',
#    'At',
#    'least',
#    'the',
#    'gate',
#    'has',
#    'Oreos'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    '8FKQW',
#    'is',
#    'the',
#    'conf',
#    '#',
#    '.',
#    'Thanks',
#    'for',
#    'the',
#    'reply'],
#   'neutral'],
#  [['@',
#    'united',
#    'rebooked',
#    '24',
#    'hours',
#    'after',
#    'original',
#    'flight',
#    ',',
#    'to',
#    'say',
#    'your',
#    'handling',
#    'of',
#    'situation',
#    'was',
#    'bad',
#    'would',
#    'be',
#    'an',
#    'understatement',
#    '.'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'are',
#    'flights',
#    'leaving',
#    'Dallas',
#    'right',
#    'now',
#    '?',
#    'In',
#    'Maui',
#    'trying',
#    'to',
#    'figure',
#    'out',
#    'how',
#    'delayed',
#    'flight',
#    '7',
#    'is',
#    'going',
#    'to',
#    'be'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'One',
#    'heck',
#    'of',
#    'an',
#    'airline',
#    'http',
#    ':',
#    '//t.co/CyoOnZfTdC'],
#   'positive'],
#  [['@',
#    'SouthwestAir',
#    'flying',
#    'flight',
#    '3130',
#    'tonight',
#    'at',
#    '7:20',
#    'from',
#    'PBI-',
#    'I',
#    'have',
#    'boarding',
#    'position',
#    'C-42',
#    '.',
#    'Is',
#    'it',
#    'overbooked',
#    '?',
#    'Really',
#    'do',
#    "n't",
#    'want',
#    'to',
#    'be',
#    'bumped',
#    '!'],
#   'neutral'],
#  [['@',
#    'JetBlue',
#    'Clients',
#    'got',
#    'ZERO',
#    ',',
#    'in',
#    '32',
#    'years',
#    'career',
#    'never',
#    'thought',
#    'this',
#    'was',
#    'possible.2',
#    'suitcases',
#    'worth',
#    'thousands',
#    'of',
#    '$',
#    '$',
#    'in',
#    'Italian',
#    'clothing',
#    'robbed',
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'now',
#    'what',
#    '?',
#    'You',
#    'Cancelled',
#    'Flightled',
#    'my',
#    'flight',
#    'again',
#    '...',
#    'Are',
#    'you',
#    'paying',
#    'for',
#    'my',
#    'hotel',
#    '?'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'Your',
#    'response',
#    'has',
#    'been',
#    'incredible',
#    '.',
#    'Truly',
#    'amazed',
#    'at',
#    'the',
#    'steps',
#    'you',
#    'have',
#    'taken',
#    'to',
#    'enhance',
#    'your',
#    'customer',
#    'relations',
#    '.',
#    'Big',
#    'thank',
#    'you',
#    '😄'],
#   'positive'],
#  [['@',
#    'AmericanAir',
#    'just',
#    'wow',
#    'Regina',
#    'just',
#    'told',
#    'me',
#    'I',
#    'ca',
#    "n't",
#    'file',
#    'or',
#    'request',
#    'a',
#    'lost',
#    'bag',
#    'statement',
#    'until',
#    'I',
#    'finish',
#    'my',
#    'travel',
#    '.',
#    'So',
#    'until',
#    'I',
#    'get',
#    'to',
#    'DC',
#    'argg'],
#   'negative'],
#  [['@',
#    'united',
#    'since',
#    'I',
#    'have',
#    'an',
#    'international',
#    'connection',
#    'at',
#    '9am',
#    ',',
#    'I',
#    "'m",
#    'hoping',
#    'for',
#    'the',
#    'same',
#    'thing',
#    '!'],
#   'negative'],
#  [['@', 'JetBlue', 'all', 'day'], 'negative'],
#  [['@',
#    'united',
#    'how',
#    'long',
#    'will',
#    'it',
#    'take',
#    'for',
#    'miles',
#    'that',
#    'i',
#    're-purchased',
#    '(',
#    'they',
#    'had',
#    'expired',
#    ')',
#    'to',
#    'show',
#    'up',
#    '?',
#    'I',
#    'recieved',
#    'an',
#    'email',
#    'that',
#    'the',
#    'request',
#    'had',
#    'been',
#    '..'],
#   'negative'],
#  [['@',
#    'united',
#    'is',
#    'probably',
#    'the',
#    'least',
#    'satisfactory',
#    'airline',
#    'I',
#    "'ve",
#    'ever',
#    'been',
#    'on',
#    '.',
#    'Never',
#    'fails',
#    'to',
#    'disappoint',
#    '.'],
#   'negative'],
#  [['@',
#    'United',
#    'Airlines',
#    'Is',
#    'Changing',
#    'Its',
#    'MileagePlus',
#    'Program',
#    ':',
#    'Winners',
#    'And',
#    'Losers',
#    'http',
#    ':',
#    '//t.co/F1yvAiO9ul',
#    'http',
#    ':',
#    '//t.co/vGlx6Ykwqg'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    '@',
#    'SeguineJ',
#    'AA',
#    '-',
#    'this',
#    'is',
#    'a',
#    'joke',
#    ',',
#    'right',
#    '?',
#    'That',
#    'line',
#    'is',
#    "n't",
#    'even',
#    'accepting',
#    'calls',
#    'right',
#    'now',
#    '-',
#    'they',
#    'just',
#    'hang',
#    'up',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    'nonrefundable',
#    ',',
#    'hence',
#    'I',
#    'wrote',
#    '$',
#    '200',
#    '!',
#    'Does',
#    "n't",
#    'make',
#    'sense',
#    'for',
#    'my',
#    '150',
#    'credit',
#    '.',
#    '#',
#    'nothanks'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'Even',
#    '5',
#    'years',
#    'after',
#    'the',
#    'earthquake',
#    '...',
#    'Haiti',
#    'still',
#    'needs',
#    'helps',
#    'in',
#    'rebuilding',
#    '#',
#    'flyingitforward'],
#   'neutral'],
#  [['@',
#    'USAirways',
#    'despite',
#    'mechanical',
#    'issues',
#    'and',
#    'many',
#    'delays',
#    'followed',
#    'by',
#    'a',
#    'Cancelled',
#    'Flightlation',
#    ',',
#    'still',
#    'getting',
#    'to',
#    'Vegas',
#    'thanks',
#    'to',
#    'great',
#    'gate',
#    'agents',
#    '!'],
#   'positive'],
#  [['@',
#    'JetBlue',
#    'no',
#    'excuse',
#    'though',
#    'for',
#    '3',
#    'gate',
#    'changes',
#    'though',
#    '.'],
#   'negative'],
#  [['@',
#    'JetBlue',
#    'I',
#    'may',
#    'need',
#    'to',
#    '.',
#    'I',
#    'had',
#    'a',
#    '40',
#    'minute',
#    'layover',
#    'and',
#    'now',
#    'have',
#    'a',
#    '15',
#    'min',
#    'delay',
#    'on',
#    'my',
#    'first',
#    'flight',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    'How',
#    'do',
#    'I',
#    'get',
#    'reimbursed',
#    'for',
#    'hotel',
#    'and',
#    'taxis',
#    'for',
#    'the',
#    'Cancelled',
#    'Flightation',
#    '?'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'but',
#    'have',
#    'been',
#    'yet',
#    'to',
#    'receive',
#    'assistance',
#    'from',
#    'one',
#    'of',
#    'your',
#    'agents',
#    'in',
#    'securing',
#    'a',
#    'new',
#    'connection',
#    '.',
#    'Many',
#    'will',
#    'now',
#    'miss',
#    'work',
#    'tomorrow',
#    '.'],
#   'negative'],
#  [['@',
#    'USAirways',
#    '@',
#    'British_Airways',
#    'three',
#    'hour',
#    'flight',
#    'delay',
#    '.',
#    'On',
#    'the',
#    'phone',
#    'for',
#    '45min',
#    'and',
#    'counting',
#    '.'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    '#',
#    '2298',
#    '.',
#    'Everyone',
#    'else',
#    'was',
#    'outstanding',
#    '.'],
#   'negative'],
#  [['@',
#    'united',
#    '-',
#    'I',
#    'think',
#    'she',
#    'was',
#    'having',
#    'a',
#    'rough',
#    'moment',
#    'w/',
#    'a',
#    'bad',
#    'passenger',
#    'from',
#    'an',
#    'earlier',
#    'flight',
#    '.',
#    'Things',
#    'got',
#    'considerably',
#    'better',
#    '.',
#    'Thanks',
#    '!'],
#   'positive'],
#  [['@', 'USAirways', 'thanks', '!'], 'positive'],
#  [['@',
#    'AmericanAir',
#    'I',
#    'Cancelled',
#    'Flightled',
#    'my',
#    'ticket',
#    'and',
#    'is',
#    'taking',
#    'two',
#    'months',
#    '++',
#    'to',
#    'refund',
#    'and',
#    'still',
#    'waiting',
#    '!'],
#   'negative'],
#  [['@', 'USAirways', 'should', ',', 'but', 'didn', '’', 't', '.'], 'negative'],
#  [['@',
#    'USAirways',
#    'shout',
#    'out',
#    'to',
#    'the',
#    'pilots',
#    'and',
#    'FC',
#    'attendant',
#    '(',
#    'Eliz',
#    ')',
#    'of',
#    'US',
#    '673',
#    '.',
#    'Super',
#    'strong',
#    'crosswinds',
#    'during',
#    'landing',
#    '.',
#    'Eliz',
#    'did',
#    'a',
#    'super',
#    'job',
#    'throughout'],
#   'positive'],
#  [['@',
#    'united',
#    'I',
#    'see',
#    'you',
#    'coming',
#    'to',
#    'get',
#    'me',
#    'and',
#    '@',
#    'AggieMensGolf',
#    'in',
#    'Hawaii',
#    '!',
#    '#',
#    '12thMan',
#    'http',
#    ':',
#    '//t.co/G8DKa3Edhf'],
#   'neutral'],
#  [['@',
#    'AmericanAir',
#    '@',
#    'dfwairport',
#    'you',
#    '2',
#    'together',
#    'are',
#    'the',
#    'best',
#    'part',
#    'of',
#    'flying',
#    '!'],
#   'positive'],
#  [['@',
#    'united',
#    'to',
#    'Late',
#    'Flight',
#    'now',
#    ',',
#    'but',
#    'in',
#    'future',
#    'flights',
#    ',',
#    'train',
#    'staff',
#    'better',
#    'to',
#    'handle',
#    'emergency',
#    'situations',
#    ',',
#    'and',
#    'ground',
#    'staff',
#    'in',
#    'Customer',
#    'Service'],
#   'negative'],
#  [['@',
#    'united',
#    'oh',
#    'united',
#    ',',
#    'how',
#    'much',
#    'I',
#    'despise',
#    'thee',
#    '!'],
#   'negative'],
#  [['@',
#    'United',
#    'Airlines',
#    "'",
#    'CEO',
#    'Jeff',
#    'Smisek',
#    ':',
#    'Disloyal',
#    'to',
#    'Loyal',
#    'Workers',
#    'http',
#    ':',
#    '//t.co/0cevY3P42b',
#    'via',
#    '@',
#    'HuffPostBiz'],
#   'neutral'],
#  [['@',
#    'united',
#    '3/10',
#    'disappointed',
#    'in',
#    'the',
#    'service',
#    '.',
#    'Will',
#    'be',
#    'missing',
#    'my',
#    'connection',
#    'after',
#    'over',
#    'an',
#    'hour',
#    'delay',
#    '+',
#    'cramped',
#    'seats',
#    '.',
#    'At',
#    'least',
#    'their',
#    'app',
#    'is',
#    'good'],
#   'negative'],
#  [['@',
#    'AmericanAir',
#    'we',
#    'had',
#    'to',
#    'sit',
#    'in',
#    'the',
#    'airport',
#    'a',
#    'long',
#    'periolodicly',
#    'time',
#    '.',
#    'the',
#    'planes',
#    'were',
#    'nasty'],
#   'negative'],
#  [['@', 'united', '618', 'was', 'flight', 'out', 'of', 'Houston'], 'neutral'],
#  [['@', 'united', 'fuck', 'you', 'for', 'not', 'caring', '😢'], 'negative'],
#  [['@',
#    'SouthwestAir',
#    'do',
#    'you',
#    'have',
#    'any',
#    'info',
#    'about',
#    'when',
#    '#',
#    'DestinationDragons',
#    'winners',
#    'will',
#    'be',
#    'announced',
#    '?',
#    'me',
#    '&',
#    'amp',
#    ';',
#    'my',
#    'best',
#    'friend',
#    'are',
#    'hoping',
#    'to',
#    'win',
#    '.',
#    'thanks',
#    '!'],
#   'neutral'],
#  [['@', 'SouthwestAir', 'Thanks'], 'positive'],
#  [['@',
#    'SouthwestAir',
#    'can',
#    'tweet',
#    'through',
#    'the',
#    'weekend/',
#    'bad',
#    'weather',
#    ',',
#    'but',
#    'closes',
#    'down',
#    'customer',
#    'relations',
#    'center',
#    'to',
#    'process',
#    'refunds',
#    'for',
#    'Cancelled',
#    'Flighted',
#    'flights',
#    '.'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'missing',
#    'out',
#    'on',
#    'over',
#    '6,000',
#    'points',
#    'in',
#    'one',
#    'account',
#    '.',
#    'They',
#    "'re",
#    'now',
#    'spread',
#    'over',
#    'four',
#    'assuming',
#    'I',
#    'create',
#    'accounts',
#    'for',
#    'them'],
#   'negative'],
#  [['@',
#    'united',
#    'I',
#    'used',
#    'to',
#    'be',
#    'a',
#    'committed',
#    '#',
#    'ContinentalAirlines',
#    'flyer',
#    'until',
#    'merger',
#    '.',
#    'I',
#    'remember',
#    'now',
#    'why',
#    'I',
#    'switched',
#    'to',
#    '@',
#    'SouthwestAir',
#    '#',
#    'CommunicationFail'],
#   'negative'],
#  [['@',
#    'united',
#    'I',
#    'will',
#    ',',
#    'as',
#    'soon',
#    'as',
#    'I',
#    'am',
#    'done',
#    'with',
#    'my',
#    'article',
#    '.',
#    'Thanks',
#    '!',
#    '~Tom'],
#   'positive'],
#  [['@',
#    'AmericanAir',
#    'you',
#    "'re",
#    'not',
#    'finding',
#    'it',
#    'bc',
#    '@',
#    'united',
#    'rebooked',
#    'us',
#    'on',
#    'your',
#    'airline',
#    'when',
#    'they',
#    'realized',
#    'they',
#    'could',
#    "n't",
#    'get',
#    'us',
#    'home',
#    '-',
#    'and',
#    'we',
#    "'re",
#    'at',
#    'ORD'],
#   'negative'],
#  [['@', 'USAirways', 'I', 'gave', 'up', 'http', ':', '//t.co/2eDgc6TbLs'],
#   'negative'],
#  [['@',
#    'USAirways',
#    'ticket',
#    'couldnt',
#    'be',
#    'used',
#    'bc',
#    'unable',
#    'to',
#    'get',
#    'to',
#    'departing',
#    'dest',
#    '(',
#    'RSW',
#    ')',
#    'bc',
#    'of',
#    'blizzard',
#    'in',
#    'BOS',
#    '.',
#    'Told',
#    'only',
#    'way',
#    'to',
#    'use',
#    'credit',
#    'is',
#    '$',
#    '200',
#    'fine'],
#   'negative'],
#  ...]

# %%
from nltk.corpus import stopwords
from string import punctuation
stopw = stopwords.words('english')
stopw += list(punctuation)
stopw #################### Retrieved list of Stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  '!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
##########lemmatizingg
from nltk.stem import WordNetLemmatizer
lemm = WordNetLemmatizer()

# %%
for i in arr:
    i[0] = [j.lower() for j in i[0] if j not in stopw]
arr #################### Removed Stopwords
# Out:
# [[['southwestair',
#    'i',
#    'scheduled',
#    'morning',
#    '2',
#    'days',
#    'fact',
#    'yes',
#    '..',
#    'sure',
#    'evening',
#    'flight',
#    'one',
#    'cancelled',
#    'flightled'],
#   'negative'],
#  [['southwestair',
#    'seeing',
#    'workers',
#    'time',
#    'time',
#    'going',
#    'beyond',
#    'i',
#    'love',
#    'flying',
#    'guys',
#    'thank'],
#   'positive'],
#  [['united',
#    'flew',
#    'ord',
#    'miami',
#    'back',
#    'great',
#    'crew',
#    'service',
#    'legs',
#    'thanks'],
#   'positive'],
#  [['southwestair', 'dultch97', "'s", 'horse', 'radish', '😤🐴'], 'negative'],
#  [['united',
#    'flight',
#    'ord',
#    'delayed',
#    'air',
#    'force',
#    'one',
#    'last',
#    'flight',
#    'sbn',
#    '8:20',
#    '5',
#    'mins',
#    'landed'],
#   'negative'],
#  [['united',
#    'why',
#    'load',
#    'us',
#    'flying',
#    'sardine',
#    'knew',
#    'pilots',
#    '2',
#    'hours',
#    'late',
#    'flight',
#    'incompetent',
#    'beyond',
#    'belief'],
#   'negative'],
#  [['jetblue',
#    'stock',
#    'response',
#    'delays',
#    'frustrating',
#    'poor',
#    'cust',
#    'serv',
#    'amp',
#    'told',
#    '3',
#    'ppl',
#    'wait',
#    'amp',
#    "'d",
#    'come',
#    'back'],
#   'negative'],
#  [['jetblue',
#    'that',
#    "'d",
#    'nice',
#    'hoping',
#    'rack',
#    'enough',
#    'miles',
#    'take',
#    'trip',
#    'seattle',
#    'enjoy',
#    'perfect',
#    'latte',
#    'city',
#    'coffee'],
#   'positive'],
#  [['united',
#    'frankly',
#    'worse',
#    'customer',
#    'service',
#    'ever',
#    'problems',
#    'happen',
#    'deal',
#    'defines',
#    'company',
#    'never',
#    'united'],
#   'negative'],
#  [['southwestair',
#    'yeah',
#    'haha',
#    'never',
#    'one',
#    'it',
#    "'s",
#    'expensive',
#    '😂😂',
#    'so',
#    'much',
#    'fun',
#    'destinationdragons'],
#   'positive'],
#  [['southwestair',
#    'mco-',
#    'gt',
#    'dca',
#    'flight',
#    'almost',
#    'full',
#    'people',
#    'screwed',
#    'msy-dca',
#    'cancelled',
#    'flightation',
#    'united',
#    'usairways',
#    "n't",
#    'cancelled',
#    'flight',
#    'swa=mistake'],
#   'negative'],
#  [['jetblue',
#    "'s",
#    'easiest',
#    'way',
#    'get',
#    'ticket',
#    'receipt',
#    'can',
#    'i',
#    'get',
#    'one',
#    'check',
#    'i',
#    'get',
#    'one',
#    'online',
#    'thanks'],
#   'neutral'],
#  [['usairways',
#    'love',
#    'changes',
#    'lounge',
#    'cheese',
#    'veggies',
#    'olives',
#    'addition',
#    'crackers',
#    'snack',
#    'mix'],
#   'positive'],
#  [['southwestair',
#    'i',
#    'receive',
#    'bad',
#    'customer',
#    'service',
#    'ended',
#    'spending',
#    'several',
#    'hundred',
#    'dollars',
#    'accommodate',
#    'family',
#    'cxl',
#    'flight'],
#   'negative'],
#  [['usairways',
#    "'re",
#    'killing',
#    'sche',
#    'flight',
#    'board',
#    '3',
#    'min',
#    'mine',
#    'arrived',
#    'gate',
#    'side',
#    'airport',
#    'genious'],
#   'negative'],
#  [['usairways',
#    '8',
#    'weeks',
#    'refund',
#    'ticket',
#    '0372389047497',
#    'totally',
#    'unacceptable',
#    'fix',
#    'i',
#    "'ll",
#    'put',
#    'blast',
#    'social',
#    'media',
#    'tv'],
#   'negative'],
#  [['americanair',
#    'private',
#    'msg',
#    'provide',
#    'details',
#    '...',
#    'u',
#    'really',
#    'need',
#    'customer',
#    'svc',
#    'training',
#    'staff'],
#   'negative'],
#  [['rt',
#    'jetblue',
#    'our',
#    'fleet',
#    "'s",
#    'fleek',
#    'http',
#    '//t.co/413gial0yl'],
#   'negative'],
#  [['jetblue',
#    'info',
#    'flight',
#    '704',
#    'sju',
#    'jfk',
#    'already',
#    'delayed',
#    '2',
#    '1/2',
#    'hours'],
#   'negative'],
#  [['americanair',
#    'i',
#    "'ve",
#    'tried',
#    'less',
#    '8',
#    'times',
#    'today',
#    'get',
#    'touch',
#    'service',
#    'desk',
#    'beginning',
#    '8:30',
#    'est',
#    'i',
#    "'m",
#    'luck',
#    '-help'],
#   'negative'],
#  [['usairways',
#    'new',
#    'problem',
#    '...',
#    'wrong',
#    'last',
#    'name',
#    'reservation',
#    'airways',
#    'fixed',
#    'new',
#    'ca',
#    "n't",
#    'get',
#    'tsa'],
#   'negative'],
#  [['southwestair',
#    'any',
#    'possible',
#    'chance',
#    'swa',
#    'bringing',
#    'back',
#    'service',
#    'lga-bwi',
#    'it',
#    'would',
#    'make',
#    'much',
#    'easier',
#    'connect',
#    'west',
#    'coast'],
#   'neutral'],
#  [['usairways',
#    'americanair',
#    'runs',
#    'show',
#    'airport',
#    'boarding',
#    'pass',
#    'says',
#    'us',
#    'airways',
#    'i',
#    'wait',
#    'american',
#    'line',
#    'yousuck'],
#   'negative'],
#  [['united',
#    'computers',
#    'stopped',
#    'giving',
#    'updates',
#    'took',
#    'flight',
#    'info',
#    'app',
#    'that',
#    "'s",
#    'ridiculous',
#    'keep',
#    'people',
#    'updated'],
#   'negative'],
#  [['united', 'good', 'fly', 'united', 'businessfirst'], 'positive'],
#  [['united',
#    'i',
#    'flying',
#    'msp',
#    'dxb',
#    'child',
#    'turn',
#    '2',
#    'trip',
#    'i',
#    'buy',
#    'return',
#    'ticket',
#    'child'],
#   'neutral'],
#  [['jetblue',
#    'loves',
#    'cancelled',
#    'flightling',
#    'tickets',
#    'telling',
#    'customers',
#    'flyunited'],
#   'negative'],
#  [['united',
#    'in',
#    'ord',
#    'waited',
#    '20',
#    'min',
#    'crew',
#    'members',
#    'left',
#    'gate',
#    'items',
#    'came',
#    'flight',
#    'attendant',
#    'sarcastically',
#    'said',
#    'good',
#    'luck',
#    'walked',
#    'away'],
#   'negative'],
#  [['southwestair',
#    'jason',
#    '108639',
#    'gate',
#    '3',
#    'san',
#    'made',
#    'afternoon',
#    'southwestairlines',
#    'stellarservice',
#    'thanks'],
#   'positive'],
#  [['americanair',
#    'everything',
#    'sorted',
#    'thanks',
#    'help',
#    'excited',
#    'get',
#    'home',
#    'tonight'],
#   'positive'],
#  [['americanair',
#    'understand',
#    'weather',
#    'would',
#    'nice',
#    'hear',
#    'apology',
#    'phone',
#    'moved',
#    'flight',
#    'inconvenient',
#    'day'],
#   'negative'],
#  [['southwestair', 'thanks'], 'positive'],
#  [['united',
#    "'s",
#    'booked',
#    'first',
#    'class',
#    'curbside',
#    'delivery',
#    '24',
#    'hours',
#    'i',
#    "'m",
#    'counting',
#    'teamusa'],
#   'negative'],
#  [['jetblue',
#    'oh',
#    'totally',
#    'looks',
#    'par',
#    'americanair',
#    "'s",
#    'admirals',
#    'club',
#    'way',
#    'slide',
#    'us',
#    'couple',
#    'passes'],
#   'positive'],
#  [['americanair',
#    'we',
#    "'ve",
#    '15',
#    'official',
#    'complaints',
#    'signed',
#    'americanairlines',
#    'lima',
#    'supervisor',
#    'customer',
#    'relations',
#    'pls',
#    'compensate',
#    '4',
#    '10-hour',
#    'delay'],
#   'negative'],
#  [['jetblue',
#    '4',
#    'hour',
#    'policy-',
#    'i',
#    'called',
#    'said',
#    'i',
#    "n't",
#    'report',
#    'soon',
#    'enough',
#    'what',
#    'would',
#    'changed',
#    'i',
#    'noticed',
#    'sooner'],
#   'negative'],
#  [['united',
#    'frustrating',
#    'flying',
#    'experience',
#    'one',
#    'continuous',
#    '``',
#    'i',
#    'dunno',
#    'time',
#    'leave',
#    'today',
#    '``',
#    'dunno',
#    'that',
#    "'s",
#    'code',
#    '...'],
#   'negative'],
#  [['southwestair',
#    'hi',
#    'i',
#    'got',
#    'message',
#    'part',
#    'flights',
#    'cancelled',
#    'flightled',
#    'i',
#    'ca',
#    "n't",
#    'rebook',
#    'online',
#    'nobody',
#    'answers',
#    'phone',
#    'call',
#    'help'],
#   'negative'],
#  [['southwestair',
#    'i',
#    'need',
#    'updates',
#    'flights',
#    '464',
#    'amp',
#    '3574',
#    'i',
#    'hold',
#    '2',
#    'hours'],
#   'negative'],
#  [['usairways',
#    'i',
#    "'m",
#    'supposed',
#    'fly',
#    'dallas',
#    'can',
#    'help',
#    'get',
#    'new',
#    'itinerary'],
#   'neutral'],
#  [['americanair',
#    'fail',
#    'flight',
#    'rdu',
#    'sitting',
#    'waiting',
#    'flight',
#    'attendants',
#    'logistics',
#    'good'],
#   'negative'],
#  [['united', 'i', 'impressed', 'super-fast', 'reply', 'cgjase'], 'positive'],
#  [['united',
#    'i',
#    "n't",
#    'spoke',
#    'baggage',
#    'contact',
#    '1-800',
#    'number',
#    'said',
#    'try',
#    'get',
#    'bags',
#    'stay',
#    'iad',
#    'pick',
#    'tmrw'],
#   'negative'],
#  [['usairways',
#    'who',
#    'intentionally',
#    'buys',
#    'flight',
#    '10',
#    'hour',
#    'layover',
#    'and',
#    'kind',
#    'airline',
#    'would',
#    'charge',
#    '200',
#    'fix',
#    'wow',
#    '...',
#    'usairways'],
#   'negative'],
#  [['southwestair', 'auto', 'callbacks', 'i', "n't", 'wait', 'hold'],
#   'negative'],
#  [['united', 'i', 'get', 'service', 'desk', 'iad'], 'neutral'],
#  [['jetblue',
#    'blue',
#    'helped',
#    'bring',
#    'color',
#    'eyes',
#    'and',
#    'i',
#    'promise',
#    'i',
#    "n't",
#    'eat',
#    'free',
#    'snacks'],
#   'positive'],
#  [['united', 'yes', 'd', 'y', 'from', 'therealaviation', 'instagram'],
#   'positive'],
#  [['jetblue',
#    'i',
#    'report',
#    'updated',
#    'info',
#    "n't",
#    'know',
#    'reach',
#    'without',
#    'super',
#    'long',
#    'wait',
#    'hold',
#    'main',
#    'number'],
#   'negative'],
#  [['jetblue',
#    'i',
#    'want',
#    'enter',
#    'family',
#    'pooling',
#    'contest',
#    'says',
#    '``',
#    '2/19',
#    "''",
#    'website',
#    'i',
#    'please',
#    'enter',
#    'still'],
#   'neutral'],
#  [['usairways', 'choose', 'seat', 'free', 'clicking', '100', 'buttons'],
#   'neutral'],
#  [['united', 'plus', 'food', 'and', 'taxis'], 'negative'],
#  [['usairways', '3hr30min', 'right', '...', 'end', 'sight'], 'negative'],
#  [['southwestair',
#    "'re",
#    'really',
#    'going',
#    'let',
#    'delta',
#    'virginamerica',
#    'get',
#    'best',
#    'http',
#    '//t.co/vudwjm1lyb'],
#   'negative'],
#  [['usairways',
#    'claims',
#    'flight',
#    'cancelled',
#    'flighted',
#    'due',
#    'weather',
#    'destination',
#    'delta',
#    'cancelled',
#    'flighted',
#    'flight',
#    'route'],
#   'negative'],
#  [['jetblue', 'thanks', 'much', 'help', 'us', 'u', 'r', 'amazing'],
#   'positive'],
#  [['americanair',
#    'haha',
#    'i',
#    'they',
#    'said',
#    "n't",
#    'fault',
#    'somehow',
#    'you',
#    'guys',
#    'r',
#    'joke'],
#   'negative'],
#  [['americanair',
#    'customer',
#    'service',
#    'inferior',
#    'nationalized',
#    'third',
#    'world',
#    'nation',
#    "'s",
#    'airline',
#    'get',
#    'together'],
#   'negative'],
#  [['americanair', 'why', 'iphone', 'app', 'sort', 'notifications', 'option'],
#   'negative'],
#  [['united', 'thank'], 'positive'],
#  [['americanair',
#    'i',
#    "'ve",
#    'trying',
#    'reach',
#    'customer',
#    'service',
#    'two',
#    'days',
#    'i',
#    'received',
#    'zero',
#    'response',
#    'never',
#    'traveling',
#    'aa'],
#   'negative'],
#  [['united',
#    'flight',
#    '4567',
#    'agent',
#    'wandered',
#    'pilots',
#    'came',
#    'looking',
#    'went',
#    'charge',
#    'personal',
#    'phone',
#    "'d",
#    'txting'],
#   'negative'],
#  [['united',
#    'first',
#    'lost',
#    'bags',
#    'cancelled',
#    'flight',
#    'flight',
#    'home',
#    '30',
#    'min',
#    'wait',
#    'talk',
#    'somebody',
#    'poorservice',
#    'notgoodenough'],
#   'negative'],
#  [['southwestair',
#    'sat',
#    'plane',
#    '2+',
#    'hrs',
#    '2/15',
#    'then',
#    'finally',
#    'took',
#    '..'],
#   'negative'],
#  [['jetblue', 'anywhere', 'http', '//t.co/fefhpmfple'], 'neutral'],
#  [['usairways',
#    'i',
#    'spend',
#    'cost',
#    'flight',
#    'get',
#    'free',
#    'room',
#    'transportation',
#    'airport'],
#   'negative'],
#  [['southwestair',
#    'understand',
#    'weather',
#    'kids',
#    'need',
#    'get',
#    'home',
#    'nice',
#    'kids',
#    'volunteer',
#    'work',
#    'ri',
#    'high',
#    'school',
#    'please',
#    'help'],
#   'neutral'],
#  [['americanair',
#    'my',
#    'friend',
#    'needs',
#    'help',
#    'flt',
#    "'s",
#    'twiiter',
#    'i',
#    'dm',
#    'info'],
#   'neutral'],
#  [['americanair',
#    'mom',
#    '’',
#    'flight',
#    'tomorrow',
#    'cancelled',
#    'flighted',
#    'w/',
#    'notice',
#    'phone',
#    'system',
#    'said',
#    'callback',
#    '2',
#    'hours',
#    '’',
#    '4',
#    'i',
#    'need',
#    'go',
#    'bed'],
#   'negative'],
#  [['americanair',
#    'flight',
#    'veers',
#    'icy',
#    'runway',
#    'dfwairport',
#    'most',
#    'dfw',
#    'flights',
#    'cancelled',
#    'flighted',
#    'mon',
#    'http',
#    '//t.co/q37pown6uv',
#    'cowboycerrone',
#    'figures',
#    'right'],
#   'negative'],
#  [['united',
#    'could',
#    'tell',
#    'bag',
#    'would',
#    'accepted',
#    'personal',
#    'item',
#    'can',
#    'bring',
#    'one',
#    'carry-on',
#    'bag',
#    'plus',
#    'http',
#    '//t.co/u390czplhl'],
#   'neutral'],
#  [['united',
#    'yo',
#    'need',
#    'new',
#    'website',
#    'really',
#    'badly',
#    'this',
#    'day',
#    'age',
#    '...'],
#   'negative'],
#  [['southwestair',
#    'theellenshow',
#    'imaginedragons',
#    'kdepetro313',
#    '.what',
#    'great',
#    'first',
#    'night',
#    'destinationdragons',
#    'http',
#    '//t.co/n3lrfo4uay'],
#   'positive'],
#  [['usairways', 'right', 'up', 'up', 'amp', 'away', '✈️🌞'], 'positive'],
#  [['united',
#    'now',
#    'two',
#    'dozen',
#    'back',
#    'line',
#    'see',
#    'single',
#    'csr',
#    'reflight',
#    'booking',
#    'problems',
#    'final',
#    'leg',
#    'kiosks',
#    'fritz'],
#   'negative'],
#  [['jetblue',
#    'why',
#    'would',
#    'charge',
#    'money',
#    'transfer',
#    'points',
#    'someone'],
#   'negative'],
#  [['usairways',
#    'is',
#    'possible',
#    'earn',
#    'dividend',
#    'miles',
#    'passenger',
#    'even',
#    'i',
#    'purchasing',
#    'tickets'],
#   'neutral'],
#  [['lmfaooo',
#    '“',
#    'jetblue',
#    'our',
#    'fleet',
#    "'s",
#    'fleek',
#    'http',
#    '//t.co/1g9rnmyuqe',
#    '”'],
#   'positive'],
#  [['usairways',
#    'is',
#    'phone',
#    'line',
#    'call',
#    "n't",
#    'affected',
#    '``',
#    'bad',
#    'weather',
#    "''",
#    'trying',
#    'book',
#    'vacation',
#    '...',
#    '👀'],
#   'neutral'],
#  [['americanair',
#    'i',
#    'never',
#    'seen',
#    'incompetency',
#    'gate',
#    'agent',
#    'years',
#    'business',
#    'travel',
#    'dfw',
#    'b16',
#    'gate',
#    'agent',
#    'needs',
#    'training',
#    'new',
#    'job'],
#   'negative'],
#  [['usairways',
#    'f623',
#    'den',
#    'phx',
#    'impressive',
#    'lack',
#    'concern',
#    '1hr+',
#    'late',
#    'flight',
#    'flight',
#    'attndt',
#    'wrecking',
#    'havoc',
#    'customer',
#    'travel',
#    'smugsmirk',
#    'norush'],
#   'negative'],
#  [['united',
#    'have',
#    'clients',
#    '11',
#    'hr',
#    'layover',
#    'iah',
#    'day',
#    'will',
#    'claim',
#    'amp',
#    'recheck',
#    'luggage',
#    'or',
#    'taken',
#    'care'],
#   'neutral'],
#  [['united',
#    'even',
#    'change',
#    'could',
#    'made',
#    'online-',
#    'instructed',
#    'call',
#    'agent-',
#    'maybe',
#    'syastem',
#    'allow',
#    'agents',
#    '2',
#    'link',
#    'passengers'],
#   'negative'],
#  [['united',
#    'ca',
#    "n't",
#    'claim',
#    '``',
#    'weather',
#    "''",
#    'hardworking',
#    'crew',
#    'pulling',
#    'seats',
#    'plane',
#    'do',
#    'right',
#    'thing',
#    'but',
#    'know',
#    'wo',
#    "n't"],
#   'negative'],
#  [['americanair',
#    'finally',
#    'called',
#    'ca',
#    "n't",
#    'get',
#    'met',
#    'seattle',
#    'refund',
#    'processed',
#    'thanks'],
#   'positive'],
#  [['united',
#    'played',
#    'most',
#    'bizarre',
#    '``',
#    'safety',
#    "''",
#    'video',
#    'i',
#    "'ve",
#    'ever',
#    'seen',
#    '...',
#    'http',
#    '//t.co/hlm2oks6xl'],
#   'neutral'],
#  [['southwestair',
#    'i',
#    "'m",
#    'sure',
#    'i',
#    'messaging',
#    'part',
#    'right',
#    'please',
#    'let',
#    'know',
#    'received'],
#   'neutral'],
#  [['southwestair',
#    'booked',
#    '8th',
#    '....',
#    'save',
#    'emergency',
#    'exit',
#    '...',
#    'got',
#    'ta',
#    'stretch'],
#   'neutral'],
#  [['southwestair',
#    'try',
#    'get',
#    'customers',
#    'destinations',
#    'no',
#    'help',
#    'get',
#    'another',
#    'airline',
#    'flights',
#    '3',
#    'days'],
#   'negative'],
#  [['jetblue', 'did', 'catch', 'name', 'i', 'sure', 'jason', 'know'],
#   'neutral'],
#  [['usairways',
#    'yet',
#    'another',
#    'delay/missed',
#    'connection',
#    '....',
#    'customer',
#    'service',
#    'attitude',
#    'wow'],
#   'negative'],
#  [['usairways',
#    'no',
#    'access',
#    'dividend',
#    'miles',
#    'week',
#    'automated',
#    'phone',
#    'keeps',
#    'telling',
#    'call',
#    'back',
#    'late',
#    'flightr',
#    'frustrated',
#    'livepersonplease'],
#   'negative'],
#  [['united',
#    'when',
#    'direct',
#    'flights',
#    'belfast',
#    'intl',
#    'newark',
#    'resume',
#    'winter',
#    'break',
#    'thanks'],
#   'neutral'],
#  [['united',
#    'lgjw7b',
#    'i',
#    'voluntarily',
#    'rerouted',
#    '1st',
#    'leg',
#    'journey',
#    'economy',
#    'supposed',
#    '8b',
#    'res',
#    'agent',
#    'said',
#    "'d",
#    'reserve'],
#   'neutral'],
#  [['southwestair',
#    'nashville',
#    'airport',
#    'runways',
#    'open',
#    'it',
#    'appears',
#    'southwest',
#    'airline',
#    'cancelled',
#    'flighting',
#    'flights',
#    'is',
#    'likely',
#    'change'],
#   'negative'],
#  [['usairways',
#    'flight',
#    'plans',
#    'delayed',
#    'tuesday',
#    'due',
#    'computer',
#    'crash'],
#   'negative'],
#  [['southwestair',
#    'this',
#    'unbelievable',
#    '...',
#    'thank',
#    'much',
#    'destinationdragons'],
#   'positive'],
#  [['united',
#    'big',
#    'surprise',
#    'nogate',
#    'waiting',
#    'plane',
#    'same',
#    'fucken',
#    'issues',
#    'everything',
#    'i',
#    'fly',
#    'fail',
#    'worstairlineever'],
#   'negative'],
#  [['usairways',
#    'tough',
#    'night',
#    'two',
#    '90',
#    'minute',
#    'calls',
#    'hold',
#    'delayed',
#    'phoenix',
#    'two',
#    'days',
#    'one',
#    'aircraft',
#    'ready',
#    'not',
#    'acceptable'],
#   'negative'],
#  [['united',
#    "'s",
#    'hard',
#    'stay',
#    'upset',
#    'someone',
#    'least',
#    'try',
#    'show',
#    'remorse'],
#   'negative'],
#  [['united',
#    '50',
#    'min',
#    'hold',
#    'trying',
#    'book',
#    'award',
#    'flight',
#    'site',
#    'errors',
#    'agents',
#    'ask',
#    'pin',
#    'see',
#    'platinum',
#    'availability',
#    'badbadbad'],
#   'negative'],
#  [['usairways',
#    '23',
#    'min',
#    'hold',
#    '...',
#    'drove',
#    '2.5',
#    'hours',
#    'get',
#    'delayed',
#    'bag',
#    'i',
#    'want',
#    'pick',
#    'sju'],
#   'negative'],
#  [['usairways',
#    'i',
#    'reserve',
#    'seat',
#    'aa',
#    'flight',
#    'i',
#    'transfer',
#    'ord',
#    'evv'],
#   'neutral'],
#  [['united',
#    'start',
#    '3xdaily',
#    'embraersa',
#    'erj145',
#    'flights',
#    'chicago',
#    'fly2ohare',
#    'evansville',
#    '4jun',
#    'avgeek'],
#   'neutral'],
#  [['united',
#    'flight',
#    '1136',
#    'chicago',
#    'houston',
#    '2',
#    'hours',
#    'pretzels',
#    'peanuts',
#    'seriously',
#    'passed'],
#   'negative'],
#  [['united',
#    'i',
#    'left',
#    'comment',
#    'customer',
#    'care',
#    'thanks',
#    'contacting'],
#   'positive'],
#  [['united', 'they', 'held', 'plane', 'made'], 'positive'],
#  [['americanair',
#    'that',
#    "'s",
#    'ok',
#    '...',
#    'you',
#    'may',
#    'keep',
#    '25',
#    'lose',
#    'bag',
#    'info',
#    'longer',
#    'trust',
#    'bad',
#    'way',
#    'handle'],
#   'negative'],
#  [['virginamerica', 'thestarter', '😁'], 'neutral'],
#  [['jetblue',
#    'learning',
#    'awesome',
#    'twitter',
#    'management',
#    'today',
#    'social',
#    'media',
#    'marketing',
#    'class',
#    'keep',
#    'good',
#    'work',
#    'sxu',
#    'phd_mama_'],
#   'positive'],
#  [['americanair',
#    'dropping',
#    'ball',
#    'again',
#    'no',
#    'catering',
#    'plane',
#    'switch',
#    'no',
#    'gate',
#    'attendant',
#    '2',
#    'hours',
#    'late',
#    'flight',
#    'really',
#    'nice'],
#   'negative'],
#  [['americanair',
#    'good',
#    'care',
#    'customers',
#    'anything',
#    'happen',
#    'take',
#    'delta',
#    'getting',
#    'back',
#    'nyc',
#    'screw',
#    'americanair'],
#   'negative'],
#  [['americanair',
#    'i',
#    "n't",
#    'think',
#    'help',
#    'based',
#    'behavior',
#    'the',
#    'voucher',
#    'cot',
#    'seem',
#    'like',
#    'enough',
#    'lol',
#    '😃'],
#   'neutral'],
#  [['united',
#    'i',
#    'think',
#    'problem',
#    'resolution',
#    'decided',
#    'end',
#    'especially',
#    "'d",
#    'like',
#    'continue',
#    'flying',
#    'airline'],
#   'negative'],
#  [['usairways',
#    'i',
#    "'ve",
#    'hold',
#    '36',
#    'mins',
#    'counting',
#    'cause',
#    'charged',
#    'credit',
#    'card',
#    'bag',
#    'provided',
#    'receipt',
#    'said',
#    'error',
#    'awful'],
#   'negative'],
#  [['united', 'great', 'looking', 'forward', 'response', 'dm'], 'positive'],
#  [['united',
#    "'s",
#    '21st',
#    'birthday',
#    'sister',
#    'coming',
#    'celebrate',
#    'flights',
#    'keep',
#    'cancelled',
#    'flighting',
#    'plz',
#    'get'],
#   'negative'],
#  [['usairways',
#    'ur',
#    'employee',
#    'named',
#    'van',
#    'ticket',
#    'counter',
#    'philadelphia',
#    'extremely',
#    'rude',
#    'father',
#    'trying',
#    'get',
#    'home',
#    'sick',
#    'kid',
#    'missed',
#    'flight'],
#   'negative'],
#  [['southwestair',
#    'horrible',
#    'experience',
#    'ever',
#    'airline',
#    '..',
#    'have',
#    'reconsider',
#    'future',
#    'flights',
#    'customer',
#    'service',
#    '...',
#    'http',
#    '//t.co/eczhcmm5vi'],
#   'negative'],
#  [['americanair',
#    'tomorrow',
#    'sites',
#    'show',
#    'flight',
#    '1642',
#    'ewr',
#    'cancelled',
#    'flightled'],
#   'negative'],
#  [['virginamerica',
#    'i',
#    'like',
#    'customer',
#    'service',
#    '40',
#    'min',
#    'delay',
#    'connecting',
#    'passengers',
#    'seems',
#    'long',
#    'va370'],
#   'negative'],
#  [['virginamerica',
#    'cutest',
#    'salt',
#    'pepper',
#    'shaker',
#    'ever',
#    'just',
#    'i',
#    'think',
#    'guys',
#    'ca',
#    "n't",
#    'get',
#    'better',
#    'http',
#    '//t.co/vc6keulg2j'],
#   'positive'],
#  [['americanair',
#    'unbelievable',
#    'i',
#    'even',
#    'wait',
#    'hold',
#    'speak',
#    'human',
#    'resolve',
#    'issue',
#    'the',
#    'system',
#    'simply',
#    'hangs'],
#   'negative'],
#  [['americanair',
#    'continues',
#    'win',
#    'i',
#    "'ve",
#    'never',
#    'missed',
#    'flight',
#    'nice',
#    'little',
#    'quiet',
#    'gate',
#    'change',
#    'made',
#    'possible',
#    'sheesh'],
#   'positive'],
#  [['usairways',
#    'even',
#    'offered',
#    'fly',
#    'another',
#    'airport',
#    'said',
#    'could',
#    "n't",
#    'no',
#    'explanation',
#    'ca',
#    "n't"],
#   'neutral'],
#  [['usairways',
#    'phone',
#    'number',
#    'gate',
#    'gave',
#    "n't",
#    'work',
#    'either',
#    'what',
#    'customer',
#    'service',
#    'phone',
#    'number'],
#   'negative'],
#  [['jetblue', 'flight', '1041', 'savannah', 'ga'], 'neutral'],
#  [['americanair',
#    'yes',
#    'still',
#    'human',
#    'i',
#    'hope',
#    'dealing',
#    'horror',
#    'stories',
#    'people',
#    'share',
#    '...',
#    'i',
#    'complained',
#    'dot',
#    'everyone'],
#   'negative'],
#  [['jetblue', 'sent', 'plane', 'does', 'anyone', 'jetblue', 'clue'],
#   'negative'],
#  [['southwestair', 'winners', 'imaginedragons', 'destinationdragons'],
#   'neutral'],
#  [['united',
#    'quick',
#    'serious',
#    'question',
#    'resources/ratings',
#    'showing',
#    'quality',
#    'service',
#    'better',
#    '8th',
#    'place',
#    'http',
#    '//t.co/dewithpew2'],
#   'negative'],
#  [['united',
#    'get',
#    'first',
#    'flight',
#    'day',
#    'ground',
#    'time',
#    '1531',
#    'let',
#    "'s",
#    'go',
#    '.......'],
#   'negative'],
#  [['“',
#    'southwestair',
#    'southwest',
#    'mobile',
#    'boarding',
#    'passes',
#    'available',
#    'ios',
#    'passbook',
#    'http',
#    '//t.co/xmrvr4lgeg',
#    'http',
#    '//t.co/wjoc9f14su',
#    '”',
#    'tori_leggieri'],
#   'neutral'],
#  [['southwestair', 'i', "'m", 'stuck', 'fort', 'lauderdale'], 'negative'],
#  [['jetblue',
#    'i',
#    'clear',
#    'folder',
#    'regularly',
#    'jetblue',
#    'white',
#    'listed',
#    'never',
#    'got'],
#   'neutral'],
#  [['united',
#    'keep',
#    'flights',
#    'cheap',
#    'early/on',
#    'time',
#    'good',
#    'flew',
#    'americanair',
#    'cancelled',
#    'flightled',
#    'flight',
#    '4',
#    'times',
#    'last',
#    'month',
#    'united',
#    'gt'],
#   'positive'],
#  [['jetblue',
#    'i',
#    'believe',
#    "'s",
#    'irina',
#    'on',
#    'flip-side',
#    'super',
#    'disappointed',
#    'eatup',
#    'cafe',
#    "n't",
#    'available',
#    'bos',
#    '--',
#    'gt',
#    'sfo',
#    'flight',
#    'today'],
#   'negative'],
#  [['usairways',
#    '5534',
#    'that',
#    "'s",
#    'flight',
#    'i',
#    'placed',
#    'original',
#    'flight',
#    'charlotte',
#    'cancelled',
#    'flightled',
#    'now',
#    '5534',
#    '1hr',
#    'delay'],
#   'negative'],
#  [['usairways',
#    'the',
#    'captain',
#    'turned',
#    'seat',
#    'belt',
#    'sign',
#    'people',
#    'get',
#    'walk',
#    'around',
#    'that',
#    "'s",
#    'good'],
#   'negative'],
#  [['united',
#    'http',
#    '//t.co/5hpsqvrjk8',
#    'flight',
#    'gone',
#    'i',
#    'got',
#    'plane',
#    'businesstravel',
#    'goodenoughmother'],
#   'negative'],
#  [['americanair',
#    'call',
#    'chairman',
#    'call',
#    'emerald',
#    'after',
#    'today',
#    'call',
#    'former',
#    'customer'],
#   'negative'],
#  [['jetblue', 'saw', 'one', 'useless', 'tsa', 'agents', 'inspected', 'shoes'],
#   'negative'],
#  [['united', 'thank', 'response'], 'neutral'],
#  [['americanair',
#    'one',
#    'received',
#    'text',
#    'alerts',
#    'automated',
#    'calls',
#    'anything',
#    'either',
#    'literally',
#    'information',
#    'happening'],
#   'negative'],
#  [['usairways', 'made', 'send', 'bloody', 'mary', "'s", 'row', '27'],
#   'positive'],
#  [['united',
#    '5',
#    'gate',
#    'changes',
#    'two',
#    'delays',
#    'even',
#    'crew',
#    'thinks',
#    'airline',
#    'sucks'],
#   'negative'],
#  [['usairways',
#    'thank',
#    'you',
#    'empathy',
#    'story',
#    'luggage',
#    'thank',
#    'reaching'],
#   'positive'],
#  [['jetblue',
#    'thanks',
#    'jb',
#    'actually',
#    'as',
#    'birder',
#    'i',
#    'love',
#    'they',
#    'need',
#    'outside',
#    'it',
#    "n't",
#    'hard',
#    'trap',
#    'move'],
#   'positive'],
#  [['usairways',
#    'flt',
#    '5302',
#    'clt',
#    'day',
#    'supposed',
#    'depart',
#    '5:51',
#    '6:20',
#    '...',
#    'still',
#    'crew',
#    'schedule/contact',
#    'pilot'],
#   'negative'],
#  [['jetblue',
#    'allow',
#    'payment',
#    'apple',
#    'pay',
#    'patriarc',
#    'http',
#    '//t.co/bduauzfhw2'],
#   'neutral'],
#  [['united',
#    'rep',
#    'hung',
#    '35',
#    'mins',
#    'hold',
#    'i',
#    'asked',
#    'supervisor',
#    'i',
#    "'m",
#    'furious',
#    'right'],
#   'negative'],
#  [['americanair',
#    "'re",
#    "'re",
#    'trying',
#    'book',
#    'past',
#    'need',
#    '2',
#    'arrive',
#    "'re",
#    'still',
#    'selling',
#    'seats',
#    'day',
#    'i',
#    "'m",
#    'trying',
#    '2',
#    'travel'],
#   'negative'],
#  [['usairways',
#    'americanair',
#    'seriously',
#    'service',
#    'issues',
#    'right',
#    'decide',
#    'tweet',
#    'unbelievable'],
#   'negative'],
#  [['americanair', 'i', 'also', 'passed', 'website', 'around', 'passengers'],
#   'neutral'],
#  [['united',
#    'clicked',
#    'link',
#    'got',
#    'confused',
#    'http',
#    '//t.co/xmaqcucwzl'],
#   'neutral'],
#  [['americanair',
#    'well',
#    'cleared',
#    'customs',
#    'auh',
#    'i',
#    'need',
#    'get',
#    'iah',
#    'i',
#    'arrive',
#    'dfw',
#    'is',
#    'possible',
#    'retrieve',
#    'luggage',
#    'iad'],
#   'neutral'],
#  [['southwestair',
#    'taylorlumsden',
#    'taylor',
#    'u',
#    'got',
#    'ta',
#    'love',
#    'swa',
#    'responsiveness',
#    'least',
#    'huh'],
#   'negative'],
#  [['americanair',
#    'flights',
#    'cancelled',
#    'flightled',
#    'ca',
#    "n't",
#    'get',
#    'desk',
#    'nothing',
#    'showing',
#    'online',
#    'reservation',
#    'i'],
#   'negative'],
#  [['americanair',
#    'usairways',
#    'i',
#    "'m",
#    'pregnant',
#    'twins',
#    "'re",
#    'going',
#    'abandon',
#    'overnight',
#    'airport',
#    'no',
#    'hotel',
#    'when',
#    "'s",
#    'fault'],
#   'negative'],
#  [['united',
#    'thanks',
#    'prompt',
#    'response',
#    'another',
#    'hour',
#    'enjoy',
#    'vacation',
#    'perhaps',
#    'bug',
#    'app',
#    'still',
#    'shows',
#    '2:55'],
#   'positive'],
#  [['united', 'tried', 'can', 'figure', 'go', 'get'], 'neutral'],
#  [['united', 'except', 'delayed', 'flight', 'anyway'], 'negative'],
#  [['jetblue', 'get', 'flight', '16', 'air'], 'negative'],
#  [['united',
#    'let',
#    'assure',
#    'travel',
#    'time',
#    '4h2m',
#    '5h2m',
#    'timezones',
#    'accuratetraveltimes',
#    '3rdtimethishashappened',
#    'http',
#    '//t.co/e0c9bi09cf'],
#   'negative'],
#  [['united', 'thanks', 'catch', 'conection'], 'positive'],
#  [['“',
#    'jetblue',
#    'our',
#    'fleet',
#    "'s",
#    'fleek',
#    'http',
#    '//t.co/ajm3bhjvaa',
#    '”',
#    'foh'],
#   'neutral'],
#  [['virginamerica', 'i', 'flight', 'artisanal', 'cheese', 'wine', 'pairing'],
#   'positive'],
#  [['united',
#    'flight',
#    'ua3364',
#    'sitting',
#    'tarmac',
#    '30',
#    'mins',
#    'report',
#    '...',
#    'input'],
#   'negative'],
#  [['usairways', 'sits', 'throne', 'lies'], 'negative'],
#  [['southwestair',
#    '3',
#    'flights',
#    'cancelled',
#    'flightled',
#    'today',
#    'now',
#    'hold',
#    'hour'],
#   'negative'],
#  [['southwestair',
#    'late',
#    'flightly',
#    "'ve",
#    'always',
#    'late',
#    'flight',
#    'please',
#    'get',
#    'back',
#    'old',
#    'swa'],
#   'negative'],
#  [['americanair',
#    'my',
#    'ex-boyfriend',
#    'picks',
#    'calls',
#    'cancelled',
#    'flightedflight',
#    'nocustomerservice',
#    'americanairlines',
#    'fail'],
#   'negative'],
#  [['southwestair',
#    'i',
#    'would',
#    'do',
#    'anything',
#    'for',
#    'tickets',
#    'vegas',
#    '...',
#    'anything',
#    'i',
#    'love',
#    'imagine',
#    'dragons',
#    'much'],
#   'positive'],
#  [['southwestair',
#    'thanks',
#    'attention',
#    'i',
#    "'ve",
#    'flying',
#    'southwest',
#    '3',
#    'years',
#    "n't",
#    'issue',
#    'past'],
#   'positive'],
#  [['usairways',
#    'never',
#    'let',
#    "'s",
#    'every',
#    'single',
#    'flight',
#    'gets',
#    'delayed'],
#   'negative'],
#  [['usairways',
#    'wife',
#    'flying',
#    'atlanta',
#    'vegas',
#    'march',
#    '7th',
#    'since',
#    'could',
#    "n't",
#    'get',
#    'tricities',
#    'tn'],
#   'neutral'],
#  [['united',
#    'flight',
#    'ua1665',
#    'got',
#    'delayed',
#    '2',
#    'hours',
#    'due',
#    'mechanical',
#    'issue',
#    '...',
#    'could',
#    'use',
#    'free',
#    'drink',
#    '3',
#    'make',
#    'inconvenience'],
#   'negative'],
#  [['virginamerica',
#    'dream',
#    'http',
#    '//t.co/oa2drfaoq2',
#    'http',
#    '//t.co/lwwdac2khx'],
#   'neutral'],
#  [['southwestair',
#    'i',
#    "'m",
#    'line',
#    'airport',
#    'right',
#    'will',
#    'cover',
#    'hotel',
#    'fair',
#    'i',
#    'sleep',
#    'airport'],
#   'negative'],
#  [['jetblue',
#    'i',
#    "n't",
#    'know-',
#    'one',
#    'would',
#    'tell',
#    'coming',
#    'i',
#    'would',
#    'guess',
#    "'s",
#    'changes',
#    'flights'],
#   'negative'],
#  [['americanair',
#    'worries',
#    "'re",
#    'swamped',
#    'i',
#    'know',
#    'dmd',
#    'back',
#    'thank',
#    'u'],
#   'neutral'],
#  [['southwestair',
#    'forgot',
#    'put',
#    'tsa',
#    'pre',
#    'number',
#    'i',
#    'checked',
#    'it',
#    'profile',
#    'boarding',
#    'pass'],
#   'neutral'],
#  [['southwestair', 'five', 'people', 'shown', 'yet'], 'neutral'],
#  [['americanair',
#    'i',
#    "'ve",
#    'never',
#    'anything',
#    'bad',
#    'say',
#    'no',
#    'love',
#    'faithful',
#    'customers'],
#   'negative'],
#  [['southwestair',
#    'hello',
#    '..',
#    'flights',
#    'taking',
#    'dallaslovefield',
#    'airport',
#    'noon',
#    'am',
#    'supposed',
#    'travel',
#    'flight',
#    '376',
#    'san',
#    'antonio'],
#   'neutral'],
#  [['southwestair',
#    'i',
#    'love',
#    'appreciate',
#    'fact',
#    'guys',
#    'rarely',
#    'cancelled',
#    'flight',
#    'flights',
#    'time',
#    'i',
#    'need',
#    'cancelled',
#    'flightlation',
#    'time',
#    '🙏'],
#   'positive'],
#  [['americanair', 'connection', 'us2065'], 'neutral'],
#  [['united', 'good', 'man', "n't", 'fault', 'plane', 'maintenance', 'issues'],
#   'positive'],
#  [['americanair',
#    'i',
#    "'m",
#    'sensitive',
#    'fact',
#    'i',
#    "n't",
#    'believe',
#    'warrants',
#    'poor',
#    'service',
#    'a',
#    'little',
#    'help',
#    'amp',
#    'compassion',
#    'goes',
#    'long',
#    'way'],
#   'negative'],
#  [['jetblue',
#    'online',
#    'resources',
#    'say',
#    "'re",
#    'time',
#    'clearly',
#    'this',
#    'information',
#    'age',
#    '...'],
#   'negative'],
#  [['united',
#    'you',
#    'make',
#    'hard',
#    'fly',
#    'delayed',
#    'hour',
#    'plane',
#    'turning',
#    'around',
#    'amp',
#    'heading',
#    'back',
#    'gate',
#    'connection'],
#   'negative'],
#  [['usairways',
#    'people',
#    'kind',
#    'hardworking',
#    'infrastructure',
#    'given',
#    'horrid',
#    'massivefail',
#    'failphone',
#    'fail'],
#   'negative'],
#  [['jetblue',
#    'thanks',
#    'her',
#    '80th',
#    'bday',
#    'saturday',
#    'we',
#    "'re",
#    'aviation',
#    'themed',
#    'surprise',
#    'party'],
#   'positive'],
#  [['jetblue',
#    'airways',
#    'reveals',
#    "'bluemanity",
#    'livery',
#    'travelpulse',
#    'http',
#    '//t.co/fttfyfmvco'],
#   'positive'],
#  [['usairways',
#    'josephtreis',
#    'dont',
#    'bother',
#    'they',
#    'dont',
#    'pick',
#    'phone',
#    'worst',
#    'customer',
#    'service',
#    'going'],
#   'negative'],
#  [['americanair', 'are', 'expecting', 'delays', 'dfw', 'tomorrow', 'morning'],
#   'neutral'],
#  [['usairways',
#    'flight',
#    '1808',
#    'leaving',
#    '2:45',
#    "n't",
#    'even',
#    'begun',
#    'board',
#    'yet',
#    'please',
#    'update',
#    'website',
#    'asap'],
#   'negative'],
#  [['americanair',
#    'incredibly',
#    'arrogant',
#    'thing',
#    'say',
#    'i',
#    'sit',
#    "o'hare",
#    'waiting',
#    'incompetent',
#    'airlines',
#    'refuel',
#    '...'],
#   'negative'],
#  [['jetblue',
#    'airline',
#    'trouble',
#    'winter',
#    'amp',
#    'getting',
#    'good',
#    'customer',
#    'service',
#    'contact',
#    'http',
#    '//t.co/aqjn4hwnac',
#    'negotiate',
#    'resolutions',
#    'you'],
#   'neutral'],
#  [['united',
#    'thankful',
#    'great',
#    'service',
#    'newark',
#    'seats',
#    'fixed',
#    'i',
#    'seated',
#    'daughter',
#    'fab',
#    'landing',
#    'fort',
#    'myers'],
#   'positive'],
#  [['united',
#    'feeling',
#    'like',
#    'true',
#    'united',
#    'customer',
#    'stuck.on',
#    'tarmac',
#    'dc',
#    '2',
#    'hrs',
#    'unitedfail'],
#   'negative'],
#  [['united',
#    'cool',
#    'your',
#    'customer',
#    'told',
#    "n't",
#    'care',
#    'either',
#    'it',
#    'expected'],
#   'negative'],
#  [['southwestair',
#    'today',
#    "'s",
#    'scavenger',
#    'hunt',
#    'start',
#    'i',
#    "'m",
#    'trying',
#    'help',
#    'little',
#    'brother',
#    'win',
#    'destinationdragons'],
#   'neutral'],
#  [['united',
#    'lt',
#    'lt',
#    'lt',
#    'lt',
#    'lt',
#    '--',
#    '--',
#    '--',
#    'shoddy',
#    'customer',
#    'service',
#    'of',
#    'use',
#    'whatsoever',
#    'unitedairline'],
#   'negative'],
#  [['jetblue',
#    'any',
#    'option',
#    'luggage',
#    'assistance',
#    'ground',
#    'hpn',
#    'flight',
#    '2168',
#    'delayed',
#    '2+',
#    'hours',
#    'amp',
#    '2',
#    'sleeping',
#    'kids',
#    'land'],
#   'negative'],
#  [['southwestair', 'i', 'dm', "'d"], 'neutral'],
#  [['united',
#    'yep—used',
#    'twice',
#    'case',
#    'id',
#    'numbers',
#    'assigned',
#    'tried',
#    'again-get',
#    'screen',
#    'says',
#    '“',
#    'thank',
#    'submitting',
#    'request',
#    '”'],
#   'negative'],
#  [['americanair',
#    'you',
#    'guys',
#    'amazing',
#    'job',
#    'today',
#    'know',
#    '’',
#    'hard',
#    'thanks',
#    'kate',
#    'appleton',
#    'hard',
#    'work',
#    'reflight',
#    'booking',
#    'problems',
#    'friends'],
#   'positive'],
#  [['americanair',
#    'really',
#    'need',
#    'customer',
#    'service',
#    'training',
#    'unhappy',
#    'ees',
#    'morning',
#    'chicago',
#    'gate',
#    'k20',
#    '430',
#    'chking',
#    'schd'],
#   'negative'],
#  [['southwestair', 'employees', 'great'], 'positive'],
#  [['americanair',
#    'souljacoy',
#    'aa',
#    'going',
#    'fix',
#    'utterly',
#    'embarrassing',
#    'customer',
#    'service',
#    'you',
#    'wo',
#    "n't",
#    'even',
#    'answer',
#    'dang',
#    'phone'],
#   'negative'],
#  [['southwestair',
#    'please',
#    'bring',
#    'back',
#    'rdu',
#    'fll',
#    'direct',
#    'route',
#    'i',
#    'noticed',
#    'missing',
#    'starting',
#    'late',
#    'flight',
#    'august',
#    'the',
#    'flights',
#    'always',
#    'packed'],
#   'neutral'],
#  [['usairways', "n't", 'want', 'get', 'home'], 'negative'],
#  [['usairways',
#    'the',
#    'phone',
#    'line',
#    'disconnects',
#    'how',
#    'i',
#    'queue',
#    'answered',
#    'phone',
#    'line',
#    'simply',
#    'disconnects',
#    'i',
#    'call'],
#   'negative'],
#  [['jetblue',
#    'i',
#    "'m",
#    'sitting',
#    'plane',
#    'too',
#    'many',
#    'predictable',
#    'mechanical',
#    'problems',
#    'still',
#    'onboard',
#    'this',
#    'getting',
#    'bad',
#    '...'],
#   'negative'],
#  [['usairways', 'shivadelrahim', 'upgrades'], 'neutral'],
#  [['usairways',
#    'never',
#    'received',
#    'horrible',
#    'service',
#    'treated',
#    'poorly',
#    'richard',
#    'p.',
#    'today',
#    'no',
#    'excuse',
#    'attitude',
#    'amp',
#    'ripping',
#    'tickets'],
#   'neutral'],
#  [['jetblue',
#    'i',
#    'get',
#    'copy',
#    'last',
#    'flight',
#    'showing',
#    'original',
#    'time',
#    'delay',
#    'i',
#    'need',
#    'work',
#    'thanks'],
#   'neutral'],
#  [['jetblue',
#    'get',
#    'honest',
#    'update',
#    'departure',
#    'flite',
#    '454',
#    'been',
#    'plane',
#    'infant',
#    'children'],
#   'negative'],
#  [['usairways',
#    'us',
#    '728',
#    'wait',
#    'gate',
#    'opened',
#    'back',
#    'go',
#    'good',
#    'maybe',
#    'get'],
#   'neutral'],
#  [['americanair',
#    'not',
#    'maintenance',
#    'md80',
#    'sits',
#    'two',
#    'days',
#    'frozen',
#    'lines',
#    'found',
#    'boarded',
#    'come',
#    'faail',
#    'mci'],
#   'negative'],
#  [['southwestair',
#    'seriously',
#    'the',
#    'worst',
#    'i',
#    "n't",
#    'remember',
#    'last',
#    'time',
#    'i',
#    'someone',
#    'i',
#    'knew',
#    'flight',
#    "n't",
#    'delayed',
#    'cancelled',
#    'flightled',
#    'etc'],
#   'negative'],
#  [['united',
#    'wont',
#    'transfer',
#    'flight',
#    'ticket',
#    'accompany',
#    '11',
#    'yr',
#    'old',
#    "'s",
#    'active',
#    'military',
#    'mom',
#    'emergency',
#    'brain',
#    'surgery',
#    'wow'],
#   'negative'],
#  [['usairways',
#    'ticket',
#    'counter',
#    'people',
#    'helping',
#    'want',
#    'charge',
#    'money',
#    'even',
#    'horrible',
#    'day'],
#   'negative'],
#  [['united',
#    '4',
#    'seg',
#    'flt',
#    'yvr',
#    'zurich',
#    'would',
#    'credit',
#    'miles',
#    '2',
#    'segs',
#    'full',
#    'fare'],
#   'negative'],
#  [['americanair',
#    'need',
#    'know',
#    "n't",
#    'done',
#    'like',
#    'promised',
#    'would',
#    'yesterday'],
#   'negative'],
#  [['jetblue', 'kudos', 'and', "'re", 'done', 'heading', 'warmer', 'weather'],
#   'positive'],
#  [['southwestair',
#    'yall',
#    'trying',
#    'fly',
#    'chicago',
#    'i',
#    "n't",
#    'live',
#    'send',
#    'home',
#    'bullshit',
#    'ass',
#    'customer',
#    'service'],
#   'negative'],
#  [['southwestair',
#    'stay',
#    'chicago',
#    'overnight',
#    'meet',
#    'bags',
#    'i',
#    'hope',
#    'stay',
#    'put',
#    "n't",
#    'get',
#    'put',
#    'flight'],
#   'negative'],
#  [['united', 'severely', 'staffed', 'iah'], 'negative'],
#  [['americanair',
#    'fantastic',
#    'thanks',
#    'will',
#    'try',
#    'tweet',
#    'photo',
#    'view'],
#   'positive'],
#  [['southwestair',
#    'i',
#    'love',
#    'companion',
#    'pass',
#    'qualified',
#    '4th',
#    'year',
#    'hollymais'],
#   'positive'],
#  [['americanair',
#    'said',
#    'aa',
#    'provide',
#    'in-flight',
#    'wifi',
#    'routes',
#    'china',
#    'based',
#    'federal',
#    'laws',
#    'united'],
#   'negative'],
#  [['southwestair',
#    'boarding',
#    'passes',
#    'compatible',
#    'iphone',
#    'passbook',
#    'http',
#    '//t.co/1esmmnizek'],
#   'neutral'],
#  [['usairways',
#    'disaster',
#    'flight',
#    '3739',
#    'missed',
#    'passenger',
#    'count',
#    '5',
#    'since',
#    'done',
#    'manually',
#    'really'],
#   'negative'],
#  [['jetblue', 'u', 'suck', 'big', 'donkey', 'balls'], 'negative'],
#  [['southwestair',
#    'thanks',
#    'confirmation',
#    'number',
#    'dmed',
#    'appreciate',
#    'help'],
#   'positive'],
#  [['jetblue',
#    'i',
#    "n't",
#    'made',
#    'feel',
#    'like',
#    'criminal',
#    'i',
#    'want',
#    'sit',
#    'near',
#    '5',
#    'year',
#    'old',
#    'flight',
#    'jetblue',
#    'http',
#    '//t.co/qgtcao1j2u'],
#   'negative'],
#  [['americanair', "'ve", 'already', 'made', 'arrangements'], 'neutral'],
#  [['usairways',
#    'add',
#    'frequent',
#    'flyer',
#    'number',
#    'website',
#    'can',
#    'help'],
#   'negative'],
#  [['southwestair',
#    'ticket',
#    'booked',
#    '1/27',
#    'cun',
#    'does',
#    'arrival',
#    'time',
#    'reflect',
#    'cun',
#    'est',
#    'time'],
#   'neutral'],
#  [['united',
#    'lot',
#    'unhappy',
#    'cold',
#    'people',
#    'bridge',
#    'freezing',
#    'temps',
#    'hour',
#    'not',
#    'given',
#    'info'],
#   'negative'],
#  [['jetblue',
#    'we',
#    "'d",
#    'love',
#    'help',
#    'shanese',
#    'bryant-melton',
#    'hard-working',
#    'grandmother',
#    'dc',
#    'go',
#    'miami',
#    'it',
#    "'s",
#    'bucket',
#    'list',
#    'flyitforward'],
#   'neutral'],
#  [['united',
#    'want',
#    'book',
#    'multi-city',
#    'fare',
#    'have',
#    'miles',
#    '1of',
#    '2',
#    'flights',
#    'an',
#    'option',
#    'pay',
#    '1st',
#    'flight',
#    'miles',
#    '+2nd',
#    'ump',
#    'visa',
#    'thanks'],
#   'neutral'],
#  [['united',
#    'when',
#    'email',
#    'address/username',
#    'sign-on',
#    'available',
#    'it',
#    "'s"],
#   'negative'],
#  [['united',
#    'yes',
#    'i',
#    "'ve",
#    'waiting',
#    'four',
#    'hours',
#    'one',
#    'able',
#    'help'],
#   'negative'],
#  [['americanair',
#    'i',
#    'thank',
#    'what',
#    'i',
#    'i',
#    'ca',
#    "n't",
#    'get',
#    'flight',
#    'hold',
#    'cancelled',
#    'flights'],
#   'neutral'],
#  [['usairways',
#    'flight',
#    'scheduled',
#    '730pm',
#    '...',
#    'told',
#    '150am',
#    'flight',
#    'cancelled',
#    'flightled',
#    'sitting',
#    'cold',
#    'plane',
#    '2',
#    'hours'],
#   'negative'],
#  [['united',
#    'yes',
#    'plenty',
#    'seats',
#    'available',
#    'so',
#    'vicky',
#    'thomas',
#    'refuse',
#    'give',
#    'one',
#    'million',
#    'mile',
#    'flyer'],
#   'negative'],
#  [['united',
#    'ua63',
#    'madrid',
#    'arrived',
#    'agent',
#    'mass',
#    'confusion',
#    'sent',
#    'fro',
#    '3',
#    'ua',
#    'employees',
#    'maryjo',
#    'rude',
#    'unhelpful'],
#   'negative'],
#  [['usairways',
#    'americanair',
#    'terminal',
#    'e',
#    'miami',
#    'still',
#    'worst',
#    'smelly',
#    'airport',
#    'ever',
#    'thanks',
#    'nothing'],
#   'negative'],
#  [['united',
#    'great',
#    'decision',
#    'making',
#    'skills',
#    'flight',
#    'ops',
#    'iah',
#    'bag',
#    'makes',
#    '10',
#    'minute',
#    'connection',
#    'i',
#    "n't",
#    'flight',
#    'pushed',
#    'early',
#    'disappointed'],
#   'negative'],
#  [['jetblue',
#    'when',
#    'i',
#    'checked',
#    'yesterday',
#    'looked',
#    'like',
#    'did',
#    'something',
#    'change'],
#   'neutral'],
#  [['united', 'weighed', '45.5', 'checked', 'bag'], 'negative'],
#  [['usairways',
#    'when',
#    'i',
#    'check',
#    'online',
#    'states',
#    'status',
#    'closed',
#    'what',
#    'mean',
#    'as',
#    'i',
#    'yet',
#    'able',
#    'reach',
#    'live',
#    'person',
#    '...'],
#   'negative'],
#  [['united',
#    'asked',
#    'dm',
#    'ignore',
#    'please',
#    'assist',
#    'changing',
#    'another',
#    'flight',
#    'today-',
#    '21',
#    'feb',
#    'fra',
#    'mco',
#    'avoiding',
#    'iad'],
#   'negative'],
#  [['americanair',
#    'americanairlines',
#    'approach',
#    'mex',
#    '....',
#    'http',
#    '//t.co/se57dmjhiw'],
#   'neutral'],
#  [['united',
#    'amp',
#    'finally',
#    'told',
#    'couldnt',
#    'use',
#    'front',
#    'plane',
#    'restrm',
#    'row7',
#    'though',
#    'myself/others',
#    'rows',
#    'behind',
#    'used',
#    'w/no',
#    'issue'],
#   'negative'],
#  [['americanair',
#    'earlier',
#    'flights',
#    'sap-',
#    'gt',
#    'mia',
#    'amp',
#    'mia',
#    'gt',
#    'new',
#    'york',
#    'lga',
#    '03.03',
#    'i',
#    "'m",
#    'currently',
#    'booked',
#    'flights',
#    '1504',
#    '1102'],
#   'neutral'],
#  [['united',
#    'last',
#    'night',
#    'waited',
#    'forever',
#    'gate',
#    'someone',
#    'corporate',
#    'dispatch',
#    'forgot',
#    'call',
#    'crew',
#    'unfriendlyskies'],
#   'negative'],
#  [['united',
#    'seriously',
#    "'s",
#    '2015',
#    'no',
#    'wifi',
#    '5hr',
#    'flight',
#    'cle-sfo',
#    '1589',
#    'you',
#    "'re",
#    'only',
#    'airline',
#    'without',
#    'wifi',
#    '...'],
#   'negative'],
#  [['united',
#    'told',
#    'changed',
#    'flight',
#    'im',
#    'ottawa',
#    'airport',
#    'ac',
#    'cant',
#    'find',
#    'reservation',
#    'whats',
#    'wrong'],
#   'negative'],
#  [['“',
#    'jetblue',
#    'analystdoc',
#    'unfortunately',
#    "'s",
#    'available',
#    'option',
#    'current',
#    'system',
#    'sorry',
#    'guys',
#    'that',
#    "'s",
#    'certain',
#    'fail',
#    'fix',
#    'plz'],
#   'negative'],
#  [['united',
#    "n't",
#    'need',
#    'apologies',
#    'need',
#    'bag',
#    'took',
#    '56',
#    'minutes',
#    'landing',
#    'get',
#    'unacceptable'],
#   'negative'],
#  [['americanair',
#    'see',
#    'photo',
#    'b787',
#    'scale',
#    'model',
#    'amp',
#    'pn',
#    '320008a',
#    'wheel',
#    'deflator',
#    'specified',
#    'chapter',
#    '32',
#    'b787',
#    'amm',
#    'http',
#    '//t.co/kfd4wqrklw'],
#   'neutral'],
#  [['united',
#    'flying',
#    'stl',
#    'saturday',
#    'expecting',
#    'ice',
#    'amp',
#    'snow',
#    'when',
#    'start',
#    'looking',
#    'travel',
#    'waivers',
#    'thanks'],
#   'neutral'],
#  [['americanair',
#    'thanks',
#    'getting',
#    'back',
#    'but',
#    'i',
#    'find',
#    'airlines',
#    'future'],
#   'negative'],
#  [['virginamerica', 'know', 'need', 'spotify', 'stat', 'guiltypleasures'],
#   'positive'],
#  [['united',
#    'i',
#    'patient',
#    'luxurious',
#    'middle',
#    'seat',
#    'next',
#    'delayed',
#    'flight'],
#   'negative'],
#  [['usairways',
#    '4',
#    'hours',
#    'tarmac',
#    'charleston',
#    'still',
#    'ca',
#    "n't",
#    'get',
#    'response',
#    'week',
#    'unacceptable'],
#   'negative'],
#  [['southwestair',
#    'what',
#    "'s",
#    'happened',
#    'customer',
#    'service',
#    '2',
#    'cancelled',
#    'flightled',
#    'flights',
#    '2',
#    'days',
#    'amp',
#    'uninformed',
#    'unapologetic',
#    'staff',
#    'nolove',
#    'cali'],
#   'negative'],
#  [['united',
#    '777',
#    'sfo',
#    'hnl',
#    'zero',
#    'entertainment',
#    'systems',
#    'youareonyourown'],
#   'negative'],
#  [['americanair',
#    '3078',
#    'overweight',
#    'pull',
#    '2',
#    'dozen',
#    'passengers',
#    'why',
#    'luggage',
#    'seriously'],
#   'negative'],
#  [['jetblue',
#    'disappointed',
#    'flight',
#    'back',
#    'boston',
#    'pr',
#    'cancelled',
#    'flightled',
#    'rebooked',
#    '4',
#    'next',
#    'day',
#    'delayed',
#    'one',
#    'compensation'],
#   'negative'],
#  [['united', 'better', 'customer', 'service', 'john', 'wayne', 'airport'],
#   'negative'],
#  [['americanair',
#    'waiting',
#    'delayed',
#    'plane',
#    'sat',
#    'plane',
#    'hour',
#    'waiting',
#    'late',
#    'flight',
#    'passenger',
#    'that',
#    "'s",
#    'bs',
#    '..'],
#   'negative'],
#  [['united', 'as', 'always', 'helps', 'communicate', 'customers'], 'negative'],
#  [['united',
#    "'re",
#    'customer',
#    'service',
#    'unbelievably',
#    'bad',
#    'abysmal',
#    'i',
#    "'ve",
#    'phone',
#    'well',
#    '2hrs',
#    'tonight',
#    'hung',
#    'yr',
#    'ppl',
#    '3x'],
#   'negative'],
#  [['southwestair',
#    '3rd',
#    'time',
#    'flying',
#    'southwest',
#    'two',
#    'years',
#    'have',
#    'another',
#    'trip',
#    'back',
#    'mx',
#    'october'],
#   'neutral'],
#  [['americanair',
#    'priority',
#    'baggage',
#    'evidently',
#    'means',
#    'comes',
#    'last'],
#   'negative'],
#  [['united',
#    'i',
#    'mention',
#    'one',
#    'bag',
#    'infant',
#    'car',
#    'seat',
#    'amp',
#    "'ve",
#    'stuck',
#    'yr',
#    'poor',
#    'replacement',
#    'icy',
#    'mtn',
#    'roads'],
#   'negative'],
#  [['united', 'just', 'thanks', 'checking'], 'positive'],
#  [['americanair',
#    'i',
#    'understand',
#    'i',
#    "'m",
#    'even',
#    'put',
#    'hold',
#    'says',
#    '``',
#    'try',
#    'late',
#    'flightr',
#    'goodbye',
#    "''"],
#   'negative'],
#  [['united',
#    'i',
#    'wo',
#    "n't",
#    'check',
#    'carry',
#    'watched',
#    'handler',
#    'throw',
#    'bag',
#    '--',
#    'miss',
#    'conveyer',
#    'belt',
#    '--',
#    'sat',
#    '10',
#    'min',
#    'http',
#    '//t.co/lyoocx5msh'],
#   'negative'],
#  [['southwestair',
#    'you',
#    'rerouted',
#    'bf',
#    "'s",
#    'flight',
#    "'s",
#    'diabetic',
#    'little',
#    'insulin',
#    'even',
#    'though',
#    'tried',
#    'change',
#    'agent',
#    'would',
#    "n't"],
#   'negative'],
#  [['americanair',
#    "'s",
#    'lot',
#    'talks',
#    'mia-sfo',
#    '20+',
#    'year',
#    'old',
#    'plane',
#    'nonewplanes',
#    'old',
#    'shame',
#    'http',
#    '//t.co/twetpxuppn'],
#   'negative'],
#  [['americanair',
#    'flight',
#    'dca',
#    'i',
#    'need',
#    'change',
#    'asap',
#    'help',
#    'ca',
#    "n't",
#    'get'],
#   'negative'],
#  [['united',
#    'all',
#    'changes',
#    'way',
#    'stick',
#    'premiere',
#    '1k',
#    'loyal',
#    'customers',
#    'why',
#    'make',
#    'things',
#    'harder',
#    'loyal'],
#   'negative'],
#  [['usairways',
#    'ok',
#    '...',
#    'know',
#    'doors',
#    'close',
#    '~10',
#    'minutes',
#    'takeoff',
#    'stop',
#    'telling',
#    'flight',
#    'leave',
#    '20',
#    'minutes',
#    "n't",
#    'boarded'],
#   'negative'],
#  [['united', 'i', 'hope', 'see', 'issue', 'return', 'flight', 'tomorrow'],
#   'negative'],
#  [['united', 'customer', 'service', '👎'], 'negative'],
#  [['usairways',
#    'my',
#    'wife',
#    'sick',
# ...
#   'neutral'],
#  [['united', 'our', 'newest', 'delay', 'right', 'http', '//t.co/96ftlzwtvo'],
#   'negative'],
#  [['united',
#    'hello',
#    'united',
#    'you',
#    'take',
#    'care',
#    'call',
#    'center',
#    'mexico',
#    'city',
#    'office',
#    'terrible',
#    'attitude',
#    'lady',
#    'helping'],
#   'negative'],
#  [['jetblue',
#    'offer',
#    'service',
#    'daytona',
#    'beach',
#    'new',
#    'york',
#    'albany',
#    'business',
#    'review',
#    'http',
#    '//t.co/duhbj41jhx'],
#   'positive'],
#  [['americanair',
#    'i',
#    "'m",
#    'trying',
#    'choose',
#    'seats',
#    'every',
#    'time',
#    'i',
#    'go',
#    'next',
#    'flight',
#    'i',
#    'get',
#    'system',
#    'error'],
#   'negative'],
#  [['jetblue',
#    '...',
#    "n't",
#    'heard',
#    'anyone',
#    'week',
#    'nonstop',
#    'flight',
#    'baggage',
#    'lost/stolen',
#    'customer',
#    'service',
#    '👎'],
#   'negative'],
#  [['jetblue',
#    "'ve",
#    'delayed',
#    'almost',
#    '2',
#    'hrs',
#    'i',
#    'take',
#    'jetblue',
#    'i',
#    "'ve",
#    'good',
#    'luck',
#    'today',
#    'really',
#    'frustrating'],
#   'negative'],
#  [['jetblue',
#    'w/',
#    '70',
#    'upgrade',
#    'unsure',
#    'ca',
#    "n't",
#    'switch',
#    'someone',
#    'around',
#    'i',
#    'called',
#    '24',
#    'hrs',
#    'advance',
#    'reason'],
#   'negative'],
#  [['jetblue', 'great', 'thanks'], 'positive'],
#  [['united',
#    'thank',
#    'getting',
#    'daughter',
#    'home',
#    'americanair',
#    'cancelled',
#    'flightled',
#    'flights',
#    'nashville'],
#   'positive'],
#  [['united',
#    'yes',
#    '...',
#    'a',
#    'ride',
#    'home',
#    'would',
#    'perfect',
#    '..',
#    'a',
#    'fete',
#    'one',
#    'would',
#    'assume',
#    'possible',
#    'charging',
#    '1600',
#    'domestic',
#    'flight',
#    '...',
#    'ps',
#    'deplaned'],
#   'negative'],
#  [['southwestair',
#    'totally',
#    'ruined',
#    'birthday',
#    'weekend',
#    'cancelled',
#    'flighting',
#    'flights',
#    'reason',
#    'offer',
#    'points',
#    'drink',
#    'transport',
#    'nolove',
#    'cali'],
#   'negative'],
#  [['united',
#    'nope',
#    'you',
#    'need',
#    'little',
#    'red',
#    'stamp',
#    'counter',
#    'check',
#    'wreck',
#    'son',
#    'http',
#    '//t.co/0prgysvurm'],
#   'negative'],
#  [['united', 'referral', 'program', 'milageplus', 'explorer', 'card'],
#   'neutral'],
#  [['americanair',
#    'guys',
#    'fail',
#    '..',
#    'i',
#    'need',
#    'use',
#    'voucher',
#    'ticket',
#    'i',
#    'ca',
#    "n't",
#    'online',
#    'yourphonesystemsucks'],
#   'negative'],
#  [['southwestair',
#    'looks',
#    'like',
#    '1',
#    'yr',
#    'anni',
#    'trip',
#    'replaced',
#    'w',
#    'someone',
#    "'s",
#    'itinerary',
#    'worried',
#    'abt',
#    'c',
#    'flight',
#    'http',
#    '//t.co/bape6rumne'],
#   'negative'],
#  [['americanair',
#    'thanks',
#    'finally',
#    'letting',
#    'get',
#    'book',
#    'flight',
#    'frustration',
#    'set',
#    '...',
#    'donedeal',
#    'talktoahuman'],
#   'negative'],
#  [['united',
#    'took',
#    'one',
#    'not',
#    'window',
#    'also',
#    'fun',
#    'get',
#    'motion',
#    'sick',
#    'http',
#    '//t.co/m81rv0blxs'],
#   'negative'],
#  [['jetblue', 'keeps', 'getting', 'better', 'no', 'water', 'plane'],
#   'negative'],
#  [['jetblue',
#    'thank',
#    'hopefully',
#    "'s",
#    'soon',
#    'we',
#    'supposed',
#    'leave',
#    '11:23'],
#   'negative'],
#  [['united',
#    'thank',
#    "y'all",
#    'amazing',
#    'airline',
#    'knows',
#    'treat',
#    'customers',
#    'guys',
#    'rock'],
#   'positive'],
#  [['southwestair',
#    'sent',
#    'looking',
#    'functionality',
#    'app',
#    'though',
#    'one',
#    'click',
#    'action'],
#   'negative'],
#  [['americanair',
#    'i',
#    'need',
#    'help',
#    'my',
#    'record',
#    'locator',
#    'bringing',
#    'two',
#    'different',
#    'flights',
#    'system',
#    'one',
#    'op',
#    'aa',
#    'amp',
#    'one',
#    'us',
#    'airways'],
#   'neutral'],
#  [['jetblue',
#    "'s",
#    'okay',
#    '...',
#    'i',
#    "'m",
#    'actually',
#    'tea',
#    'kinda',
#    'guy',
#    'anyway',
#    'thanks'],
#   'positive'],
#  [['united',
#    'held',
#    'almost',
#    '45',
#    'minutes',
#    'promised',
#    'free',
#    'movies',
#    "n't",
#    'work',
#    'neither',
#    'wifi',
#    'paid',
#    'boo'],
#   'negative'],
#  [['americanair',
#    'what',
#    "'s",
#    'baggage',
#    'handlers',
#    'calling',
#    'dfw',
#    'today',
#    'no',
#    'luggage',
#    'onboard',
#    'planes'],
#   'negative'],
#  [['usairways',
#    'i',
#    'would',
#    'go',
#    'though',
#    'entire',
#    'process',
#    'get',
#    'people',
#    'phone',
#    'usairwayssucks'],
#   'negative'],
#  [['usairways',
#    'crazy',
#    'treated',
#    'mom',
#    'poorly',
#    'not',
#    'happy',
#    'usairwaysfail'],
#   'negative'],
#  [['southwestair', 'many', 'left'], 'neutral'],
#  [['usairways',
#    'you',
#    'work',
#    'hard',
#    'making',
#    'sure',
#    'things',
#    'flow',
#    'smoothly',
#    'keeping',
#    'positive'],
#   'positive'],
#  [['usairways',
#    'do',
#    "n't",
#    'blame',
#    'weather',
#    'rep',
#    'counter',
#    'cost',
#    'entire',
#    'day',
#    'weather',
#    'printed',
#    'boarding',
#    'pass',
#    'late',
#    'flight',
#    'takeresponsibility'],
#   'negative'],
#  [['united',
#    'thanks',
#    'updating',
#    '1+',
#    'hour',
#    'delay',
#    'exact',
#    'second',
#    'i',
#    'got',
#    'atl',
#    '🙅🙅🙅'],
#   'positive'],
#  [['united',
#    'how',
#    'considered',
#    '``',
#    'time',
#    "''",
#    "'s",
#    'arriving',
#    'destination',
#    'half',
#    'hour',
#    'late',
#    'flightr',
#    'scheduled',
#    'http',
#    '//t.co/ymftw1uyhr'],
#   'negative'],
#  [['americanair',
#    'i',
#    'rebooked',
#    "n't",
#    'get',
#    'notified',
#    'cancelled',
#    'flightled'],
#   'negative'],
#  [['usairways',
#    'shoutout',
#    '2',
#    'kristie',
#    'sp',
#    'gate4',
#    'pvd',
#    'today',
#    'she',
#    "'s",
#    'rockstar',
#    'tremendous',
#    'help',
#    'tough',
#    'situation',
#    'promotethatgirl'],
#   'positive'],
#  [['united',
#    'check-in',
#    'luggage',
#    'employee',
#    'told',
#    'include',
#    'wheels',
#    'dimensions'],
#   'neutral'],
#  [['united', '25', 'minute', 'hold', '1', 'hr', '25', 'min', 'abc11_wtvd'],
#   'negative'],
#  [['usairways',
#    'you',
#    'guys',
#    'screwing',
#    'trip',
#    'thanks',
#    'nothing',
#    'lazy'],
#   'negative'],
#  [['united',
#    'passengers',
#    'waited',
#    'inside',
#    'flight',
#    'runway',
#    'returned',
#    'back',
#    'gate',
#    'count',
#    'valid',
#    'journey'],
#   'negative'],
#  [['usairways',
#    'frustrating',
#    'days',
#    'no',
#    'flights',
#    'home',
#    'changed',
#    'airlines',
#    'thank',
#    'phl',
#    'usairway',
#    'employees',
#    'amp',
#    'united',
#    'help',
#    'getting',
#    'back',
#    'iah'],
#   'positive'],
#  [['united',
#    'u',
#    'guys',
#    'changed',
#    'ages',
#    'double',
#    'booked',
#    'seats',
#    'i',
#    'i',
#    "'ve",
#    'even',
#    'though',
#    'i',
#    'platinum',
#    'person',
#    'none'],
#   'negative'],
#  [['usairways',
#    'cancelled',
#    'flightled',
#    'last',
#    'part',
#    'ticket',
#    'confused',
#    'email',
#    'i',
#    'received',
#    'whether',
#    'value',
#    'remains',
#    'is',
#    'someone',
#    'i',
#    'ask'],
#   'neutral'],
#  [['united',
#    'if',
#    'business',
#    'decision',
#    'made',
#    'inconveniences',
#    'possibly',
#    'causes',
#    'lost',
#    'customers',
#    'good',
#    'business',
#    'decision',
#    'cranky'],
#   'negative'],
#  [['usairways',
#    'flight',
#    'got',
#    'cancelled',
#    'flightled',
#    'charlotte',
#    'been',
#    'hold',
#    'hour',
#    'pls',
#    'pick'],
#   'negative'],
#  [['virginamerica', 'wow', 'blew', 'mind'], 'positive'],
#  [['americanair',
#    'aa2416',
#    'time',
#    'awesome',
#    'flight',
#    'great',
#    'job',
#    'american'],
#   'positive'],
#  [['southwestair', "n't", 'realize', 'clothes', 'hotel', 'suggestions'],
#   'neutral'],
#  [['southwestair',
#    'got',
#    'mine',
#    'just',
#    'time',
#    'wife',
#    '15th',
#    'anniversary'],
#   'positive'],
#  [['“',
#    'southwestair',
#    'pancho_joe',
#    'no',
#    'must',
#    "'ve",
#    'heard',
#    'us',
#    'wrong',
#    'sweet',
#    'mixtape',
#    'though',
#    "''",
#    '4',
#    'record',
#    'i',
#    "n't",
#    'leave',
#    '80',
#    "'s",
#    '80',
#    "'s",
#    'left'],
#   'neutral'],
#  [['americanair',
#    'sitting',
#    'gate',
#    'flight',
#    '719',
#    'hour',
#    'due',
#    'sabre',
#    'what',
#    'backup',
#    'plan',
#    'place',
#    'sabre',
#    'fixed'],
#   'negative'],
#  [['southwestair',
#    'favorite',
#    'airlines',
#    'i',
#    "'ve",
#    'never',
#    'issues',
#    'plus',
#    'crew',
#    'entertaining'],
#   'positive'],
#  [['usairways', 'i', 'made', 'thanks', 'help'], 'positive'],
#  [['usairways',
#    'utterly',
#    'unreliable',
#    'they',
#    "n't",
#    'schedule',
#    'pilot',
#    'us624',
#    'flight',
#    'seattle',
#    'flights',
#    'delayed',
#    'usairwaysfail'],
#   'negative'],
#  [['southwestair',
#    'tremendous',
#    'job',
#    'atlanta',
#    'airport',
#    'saw',
#    'sw',
#    'celebrate',
#    'mardi',
#    'gras',
#    'another',
#    'reason',
#    'i',
#    "'m",
#    'nuts',
#    'guys',
#    'http',
#    '//t.co/8wbzorrn3c'],
#   'neutral'],
#  [['united',
#    'seems',
#    'like',
#    'one',
#    'united',
#    'help',
#    'lots',
#    'fingers',
#    'pointed',
#    'zero',
#    'people',
#    'stepping',
#    'at',
#    'least',
#    'gate',
#    'oreos'],
#   'negative'],
#  [['southwestair', '8fkqw', 'conf', 'thanks', 'reply'], 'neutral'],
#  [['united',
#    'rebooked',
#    '24',
#    'hours',
#    'original',
#    'flight',
#    'say',
#    'handling',
#    'situation',
#    'bad',
#    'would',
#    'understatement'],
#   'negative'],
#  [['americanair',
#    'flights',
#    'leaving',
#    'dallas',
#    'right',
#    'in',
#    'maui',
#    'trying',
#    'figure',
#    'delayed',
#    'flight',
#    '7',
#    'going'],
#   'negative'],
#  [['southwestair', 'one', 'heck', 'airline', 'http', '//t.co/cyoonzftdc'],
#   'positive'],
#  [['southwestair',
#    'flying',
#    'flight',
#    '3130',
#    'tonight',
#    '7:20',
#    'pbi-',
#    'i',
#    'boarding',
#    'position',
#    'c-42',
#    'is',
#    'overbooked',
#    'really',
#    "n't",
#    'want',
#    'bumped'],
#   'neutral'],
#  [['jetblue',
#    'clients',
#    'got',
#    'zero',
#    '32',
#    'years',
#    'career',
#    'never',
#    'thought',
#    'possible.2',
#    'suitcases',
#    'worth',
#    'thousands',
#    'italian',
#    'clothing',
#    'robbed'],
#   'negative'],
#  [['usairways',
#    'you',
#    'cancelled',
#    'flightled',
#    'flight',
#    '...',
#    'are',
#    'paying',
#    'hotel'],
#   'negative'],
#  [['americanair',
#    'your',
#    'response',
#    'incredible',
#    'truly',
#    'amazed',
#    'steps',
#    'taken',
#    'enhance',
#    'customer',
#    'relations',
#    'big',
#    'thank',
#    '😄'],
#   'positive'],
#  [['americanair',
#    'wow',
#    'regina',
#    'told',
#    'i',
#    'ca',
#    "n't",
#    'file',
#    'request',
#    'lost',
#    'bag',
#    'statement',
#    'i',
#    'finish',
#    'travel',
#    'so',
#    'i',
#    'get',
#    'dc',
#    'argg'],
#   'negative'],
#  [['united',
#    'since',
#    'i',
#    'international',
#    'connection',
#    '9am',
#    'i',
#    "'m",
#    'hoping',
#    'thing'],
#   'negative'],
#  [['jetblue', 'day'], 'negative'],
#  [['united',
#    'long',
#    'take',
#    'miles',
#    're-purchased',
#    'expired',
#    'show',
#    'i',
#    'recieved',
#    'email',
#    'request',
#    '..'],
#   'negative'],
#  [['united',
#    'probably',
#    'least',
#    'satisfactory',
#    'airline',
#    'i',
#    "'ve",
#    'ever',
#    'never',
#    'fails',
#    'disappoint'],
#   'negative'],
#  [['united',
#    'airlines',
#    'is',
#    'changing',
#    'its',
#    'mileageplus',
#    'program',
#    'winners',
#    'and',
#    'losers',
#    'http',
#    '//t.co/f1yvaio9ul',
#    'http',
#    '//t.co/vglx6ykwqg'],
#   'neutral'],
#  [['americanair',
#    'seguinej',
#    'aa',
#    'joke',
#    'right',
#    'that',
#    'line',
#    "n't",
#    'even',
#    'accepting',
#    'calls',
#    'right',
#    'hang'],
#   'negative'],
#  [['united',
#    'nonrefundable',
#    'hence',
#    'i',
#    'wrote',
#    '200',
#    'does',
#    "n't",
#    'make',
#    'sense',
#    '150',
#    'credit',
#    'nothanks'],
#   'negative'],
#  [['jetblue',
#    'even',
#    '5',
#    'years',
#    'earthquake',
#    '...',
#    'haiti',
#    'still',
#    'needs',
#    'helps',
#    'rebuilding',
#    'flyingitforward'],
#   'neutral'],
#  [['usairways',
#    'despite',
#    'mechanical',
#    'issues',
#    'many',
#    'delays',
#    'followed',
#    'cancelled',
#    'flightlation',
#    'still',
#    'getting',
#    'vegas',
#    'thanks',
#    'great',
#    'gate',
#    'agents'],
#   'positive'],
#  [['jetblue', 'excuse', 'though', '3', 'gate', 'changes', 'though'],
#   'negative'],
#  [['jetblue',
#    'i',
#    'may',
#    'need',
#    'i',
#    '40',
#    'minute',
#    'layover',
#    '15',
#    'min',
#    'delay',
#    'first',
#    'flight'],
#   'negative'],
#  [['united',
#    'how',
#    'i',
#    'get',
#    'reimbursed',
#    'hotel',
#    'taxis',
#    'cancelled',
#    'flightation'],
#   'negative'],
#  [['americanair',
#    'yet',
#    'receive',
#    'assistance',
#    'one',
#    'agents',
#    'securing',
#    'new',
#    'connection',
#    'many',
#    'miss',
#    'work',
#    'tomorrow'],
#   'negative'],
#  [['usairways',
#    'british_airways',
#    'three',
#    'hour',
#    'flight',
#    'delay',
#    'on',
#    'phone',
#    '45min',
#    'counting'],
#   'negative'],
#  [['americanair', '2298', 'everyone', 'else', 'outstanding'], 'negative'],
#  [['united',
#    'i',
#    'think',
#    'rough',
#    'moment',
#    'w/',
#    'bad',
#    'passenger',
#    'earlier',
#    'flight',
#    'things',
#    'got',
#    'considerably',
#    'better',
#    'thanks'],
#   'positive'],
#  [['usairways', 'thanks'], 'positive'],
#  [['americanair',
#    'i',
#    'cancelled',
#    'flightled',
#    'ticket',
#    'taking',
#    'two',
#    'months',
#    '++',
#    'refund',
#    'still',
#    'waiting'],
#   'negative'],
#  [['usairways', '’'], 'negative'],
#  [['usairways',
#    'shout',
#    'pilots',
#    'fc',
#    'attendant',
#    'eliz',
#    'us',
#    '673',
#    'super',
#    'strong',
#    'crosswinds',
#    'landing',
#    'eliz',
#    'super',
#    'job',
#    'throughout'],
#   'positive'],
#  [['united',
#    'i',
#    'see',
#    'coming',
#    'get',
#    'aggiemensgolf',
#    'hawaii',
#    '12thman',
#    'http',
#    '//t.co/g8dka3edhf'],
#   'neutral'],
#  [['americanair', 'dfwairport', '2', 'together', 'best', 'part', 'flying'],
#   'positive'],
#  [['united',
#    'late',
#    'flight',
#    'future',
#    'flights',
#    'train',
#    'staff',
#    'better',
#    'handle',
#    'emergency',
#    'situations',
#    'ground',
#    'staff',
#    'customer',
#    'service'],
#   'negative'],
#  [['united', 'oh', 'united', 'much', 'i', 'despise', 'thee'], 'negative'],
#  [['united',
#    'airlines',
#    'ceo',
#    'jeff',
#    'smisek',
#    'disloyal',
#    'loyal',
#    'workers',
#    'http',
#    '//t.co/0cevy3p42b',
#    'via',
#    'huffpostbiz'],
#   'neutral'],
#  [['united',
#    '3/10',
#    'disappointed',
#    'service',
#    'will',
#    'missing',
#    'connection',
#    'hour',
#    'delay',
#    'cramped',
#    'seats',
#    'at',
#    'least',
#    'app',
#    'good'],
#   'negative'],
#  [['americanair',
#    'sit',
#    'airport',
#    'long',
#    'periolodicly',
#    'time',
#    'planes',
#    'nasty'],
#   'negative'],
#  [['united', '618', 'flight', 'houston'], 'neutral'],
#  [['united', 'fuck', 'caring', '😢'], 'negative'],
#  [['southwestair',
#    'info',
#    'destinationdragons',
#    'winners',
#    'announced',
#    'amp',
#    'best',
#    'friend',
#    'hoping',
#    'win',
#    'thanks'],
#   'neutral'],
#  [['southwestair', 'thanks'], 'positive'],
#  [['southwestair',
#    'tweet',
#    'weekend/',
#    'bad',
#    'weather',
#    'closes',
#    'customer',
#    'relations',
#    'center',
#    'process',
#    'refunds',
#    'cancelled',
#    'flighted',
#    'flights'],
#   'negative'],
#  [['southwestair',
#    'missing',
#    '6,000',
#    'points',
#    'one',
#    'account',
#    'they',
#    "'re",
#    'spread',
#    'four',
#    'assuming',
#    'i',
#    'create',
#    'accounts'],
#   'negative'],
#  [['united',
#    'i',
#    'used',
#    'committed',
#    'continentalairlines',
#    'flyer',
#    'merger',
#    'i',
#    'remember',
#    'i',
#    'switched',
#    'southwestair',
#    'communicationfail'],
#   'negative'],
#  [['united', 'i', 'soon', 'i', 'done', 'article', 'thanks', '~tom'],
#   'positive'],
#  [['americanair',
#    "'re",
#    'finding',
#    'bc',
#    'united',
#    'rebooked',
#    'us',
#    'airline',
#    'realized',
#    'could',
#    "n't",
#    'get',
#    'us',
#    'home',
#    "'re",
#    'ord'],
#   'negative'],
#  [['usairways', 'i', 'gave', 'http', '//t.co/2edgc6tbls'], 'negative'],
#  [['usairways',
#    'ticket',
#    'couldnt',
#    'used',
#    'bc',
#    'unable',
#    'get',
#    'departing',
#    'dest',
#    'rsw',
#    'bc',
#    'blizzard',
#    'bos',
#    'told',
#    'way',
#    'use',
#    'credit',
#    '200',
#    'fine'],
#   'negative'],
#  ...]

# %%
for i in arr:
    i[0] = [lemm.lemmatize(j) for j in i[0]]
arr
# Out:
# [[['southwestair',
#    'i',
#    'scheduled',
#    'morning',
#    '2',
#    'day',
#    'fact',
#    'yes',
#    '..',
#    'sure',
#    'evening',
#    'flight',
#    'one',
#    'cancelled',
#    'flightled'],
#   'negative'],
#  [['southwestair',
#    'seeing',
#    'worker',
#    'time',
#    'time',
#    'going',
#    'beyond',
#    'i',
#    'love',
#    'flying',
#    'guy',
#    'thank'],
#   'positive'],
#  [['united',
#    'flew',
#    'ord',
#    'miami',
#    'back',
#    'great',
#    'crew',
#    'service',
#    'leg',
#    'thanks'],
#   'positive'],
#  [['southwestair', 'dultch97', "'s", 'horse', 'radish', '😤🐴'], 'negative'],
#  [['united',
#    'flight',
#    'ord',
#    'delayed',
#    'air',
#    'force',
#    'one',
#    'last',
#    'flight',
#    'sbn',
#    '8:20',
#    '5',
#    'min',
#    'landed'],
#   'negative'],
#  [['united',
#    'why',
#    'load',
#    'u',
#    'flying',
#    'sardine',
#    'knew',
#    'pilot',
#    '2',
#    'hour',
#    'late',
#    'flight',
#    'incompetent',
#    'beyond',
#    'belief'],
#   'negative'],
#  [['jetblue',
#    'stock',
#    'response',
#    'delay',
#    'frustrating',
#    'poor',
#    'cust',
#    'serv',
#    'amp',
#    'told',
#    '3',
#    'ppl',
#    'wait',
#    'amp',
#    "'d",
#    'come',
#    'back'],
#   'negative'],
#  [['jetblue',
#    'that',
#    "'d",
#    'nice',
#    'hoping',
#    'rack',
#    'enough',
#    'mile',
#    'take',
#    'trip',
#    'seattle',
#    'enjoy',
#    'perfect',
#    'latte',
#    'city',
#    'coffee'],
#   'positive'],
#  [['united',
#    'frankly',
#    'worse',
#    'customer',
#    'service',
#    'ever',
#    'problem',
#    'happen',
#    'deal',
#    'defines',
#    'company',
#    'never',
#    'united'],
#   'negative'],
#  [['southwestair',
#    'yeah',
#    'haha',
#    'never',
#    'one',
#    'it',
#    "'s",
#    'expensive',
#    '😂😂',
#    'so',
#    'much',
#    'fun',
#    'destinationdragons'],
#   'positive'],
#  [['southwestair',
#    'mco-',
#    'gt',
#    'dca',
#    'flight',
#    'almost',
#    'full',
#    'people',
#    'screwed',
#    'msy-dca',
#    'cancelled',
#    'flightation',
#    'united',
#    'usairways',
#    "n't",
#    'cancelled',
#    'flight',
#    'swa=mistake'],
#   'negative'],
#  [['jetblue',
#    "'s",
#    'easiest',
#    'way',
#    'get',
#    'ticket',
#    'receipt',
#    'can',
#    'i',
#    'get',
#    'one',
#    'check',
#    'i',
#    'get',
#    'one',
#    'online',
#    'thanks'],
#   'neutral'],
#  [['usairways',
#    'love',
#    'change',
#    'lounge',
#    'cheese',
#    'veggie',
#    'olive',
#    'addition',
#    'cracker',
#    'snack',
#    'mix'],
#   'positive'],
#  [['southwestair',
#    'i',
#    'receive',
#    'bad',
#    'customer',
#    'service',
#    'ended',
#    'spending',
#    'several',
#    'hundred',
#    'dollar',
#    'accommodate',
#    'family',
#    'cxl',
#    'flight'],
#   'negative'],
#  [['usairways',
#    "'re",
#    'killing',
#    'sche',
#    'flight',
#    'board',
#    '3',
#    'min',
#    'mine',
#    'arrived',
#    'gate',
#    'side',
#    'airport',
#    'genious'],
#   'negative'],
#  [['usairways',
#    '8',
#    'week',
#    'refund',
#    'ticket',
#    '0372389047497',
#    'totally',
#    'unacceptable',
#    'fix',
#    'i',
#    "'ll",
#    'put',
#    'blast',
#    'social',
#    'medium',
#    'tv'],
#   'negative'],
#  [['americanair',
#    'private',
#    'msg',
#    'provide',
#    'detail',
#    '...',
#    'u',
#    'really',
#    'need',
#    'customer',
#    'svc',
#    'training',
#    'staff'],
#   'negative'],
#  [['rt',
#    'jetblue',
#    'our',
#    'fleet',
#    "'s",
#    'fleek',
#    'http',
#    '//t.co/413gial0yl'],
#   'negative'],
#  [['jetblue',
#    'info',
#    'flight',
#    '704',
#    'sju',
#    'jfk',
#    'already',
#    'delayed',
#    '2',
#    '1/2',
#    'hour'],
#   'negative'],
#  [['americanair',
#    'i',
#    "'ve",
#    'tried',
#    'le',
#    '8',
#    'time',
#    'today',
#    'get',
#    'touch',
#    'service',
#    'desk',
#    'beginning',
#    '8:30',
#    'est',
#    'i',
#    "'m",
#    'luck',
#    '-help'],
#   'negative'],
#  [['usairways',
#    'new',
#    'problem',
#    '...',
#    'wrong',
#    'last',
#    'name',
#    'reservation',
#    'airway',
#    'fixed',
#    'new',
#    'ca',
#    "n't",
#    'get',
#    'tsa'],
#   'negative'],
#  [['southwestair',
#    'any',
#    'possible',
#    'chance',
#    'swa',
#    'bringing',
#    'back',
#    'service',
#    'lga-bwi',
#    'it',
#    'would',
#    'make',
#    'much',
#    'easier',
#    'connect',
#    'west',
#    'coast'],
#   'neutral'],
#  [['usairways',
#    'americanair',
#    'run',
#    'show',
#    'airport',
#    'boarding',
#    'pas',
#    'say',
#    'u',
#    'airway',
#    'i',
#    'wait',
#    'american',
#    'line',
#    'yousuck'],
#   'negative'],
#  [['united',
#    'computer',
#    'stopped',
#    'giving',
#    'update',
#    'took',
#    'flight',
#    'info',
#    'app',
#    'that',
#    "'s",
#    'ridiculous',
#    'keep',
#    'people',
#    'updated'],
#   'negative'],
#  [['united', 'good', 'fly', 'united', 'businessfirst'], 'positive'],
#  [['united',
#    'i',
#    'flying',
#    'msp',
#    'dxb',
#    'child',
#    'turn',
#    '2',
#    'trip',
#    'i',
#    'buy',
#    'return',
#    'ticket',
#    'child'],
#   'neutral'],
#  [['jetblue',
#    'love',
#    'cancelled',
#    'flightling',
#    'ticket',
#    'telling',
#    'customer',
#    'flyunited'],
#   'negative'],
#  [['united',
#    'in',
#    'ord',
#    'waited',
#    '20',
#    'min',
#    'crew',
#    'member',
#    'left',
#    'gate',
#    'item',
#    'came',
#    'flight',
#    'attendant',
#    'sarcastically',
#    'said',
#    'good',
#    'luck',
#    'walked',
#    'away'],
#   'negative'],
#  [['southwestair',
#    'jason',
#    '108639',
#    'gate',
#    '3',
#    'san',
#    'made',
#    'afternoon',
#    'southwestairlines',
#    'stellarservice',
#    'thanks'],
#   'positive'],
#  [['americanair',
#    'everything',
#    'sorted',
#    'thanks',
#    'help',
#    'excited',
#    'get',
#    'home',
#    'tonight'],
#   'positive'],
#  [['americanair',
#    'understand',
#    'weather',
#    'would',
#    'nice',
#    'hear',
#    'apology',
#    'phone',
#    'moved',
#    'flight',
#    'inconvenient',
#    'day'],
#   'negative'],
#  [['southwestair', 'thanks'], 'positive'],
#  [['united',
#    "'s",
#    'booked',
#    'first',
#    'class',
#    'curbside',
#    'delivery',
#    '24',
#    'hour',
#    'i',
#    "'m",
#    'counting',
#    'teamusa'],
#   'negative'],
#  [['jetblue',
#    'oh',
#    'totally',
#    'look',
#    'par',
#    'americanair',
#    "'s",
#    'admiral',
#    'club',
#    'way',
#    'slide',
#    'u',
#    'couple',
#    'pass'],
#   'positive'],
#  [['americanair',
#    'we',
#    "'ve",
#    '15',
#    'official',
#    'complaint',
#    'signed',
#    'americanairlines',
#    'lima',
#    'supervisor',
#    'customer',
#    'relation',
#    'pls',
#    'compensate',
#    '4',
#    '10-hour',
#    'delay'],
#   'negative'],
#  [['jetblue',
#    '4',
#    'hour',
#    'policy-',
#    'i',
#    'called',
#    'said',
#    'i',
#    "n't",
#    'report',
#    'soon',
#    'enough',
#    'what',
#    'would',
#    'changed',
#    'i',
#    'noticed',
#    'sooner'],
#   'negative'],
#  [['united',
#    'frustrating',
#    'flying',
#    'experience',
#    'one',
#    'continuous',
#    '``',
#    'i',
#    'dunno',
#    'time',
#    'leave',
#    'today',
#    '``',
#    'dunno',
#    'that',
#    "'s",
#    'code',
#    '...'],
#   'negative'],
#  [['southwestair',
#    'hi',
#    'i',
#    'got',
#    'message',
#    'part',
#    'flight',
#    'cancelled',
#    'flightled',
#    'i',
#    'ca',
#    "n't",
#    'rebook',
#    'online',
#    'nobody',
#    'answer',
#    'phone',
#    'call',
#    'help'],
#   'negative'],
#  [['southwestair',
#    'i',
#    'need',
#    'update',
#    'flight',
#    '464',
#    'amp',
#    '3574',
#    'i',
#    'hold',
#    '2',
#    'hour'],
#   'negative'],
#  [['usairways',
#    'i',
#    "'m",
#    'supposed',
#    'fly',
#    'dallas',
#    'can',
#    'help',
#    'get',
#    'new',
#    'itinerary'],
#   'neutral'],
#  [['americanair',
#    'fail',
#    'flight',
#    'rdu',
#    'sitting',
#    'waiting',
#    'flight',
#    'attendant',
#    'logistics',
#    'good'],
#   'negative'],
#  [['united', 'i', 'impressed', 'super-fast', 'reply', 'cgjase'], 'positive'],
#  [['united',
#    'i',
#    "n't",
#    'spoke',
#    'baggage',
#    'contact',
#    '1-800',
#    'number',
#    'said',
#    'try',
#    'get',
#    'bag',
#    'stay',
#    'iad',
#    'pick',
#    'tmrw'],
#   'negative'],
#  [['usairways',
#    'who',
#    'intentionally',
#    'buy',
#    'flight',
#    '10',
#    'hour',
#    'layover',
#    'and',
#    'kind',
#    'airline',
#    'would',
#    'charge',
#    '200',
#    'fix',
#    'wow',
#    '...',
#    'usairways'],
#   'negative'],
#  [['southwestair', 'auto', 'callback', 'i', "n't", 'wait', 'hold'],
#   'negative'],
#  [['united', 'i', 'get', 'service', 'desk', 'iad'], 'neutral'],
#  [['jetblue',
#    'blue',
#    'helped',
#    'bring',
#    'color',
#    'eye',
#    'and',
#    'i',
#    'promise',
#    'i',
#    "n't",
#    'eat',
#    'free',
#    'snack'],
#   'positive'],
#  [['united', 'yes', 'd', 'y', 'from', 'therealaviation', 'instagram'],
#   'positive'],
#  [['jetblue',
#    'i',
#    'report',
#    'updated',
#    'info',
#    "n't",
#    'know',
#    'reach',
#    'without',
#    'super',
#    'long',
#    'wait',
#    'hold',
#    'main',
#    'number'],
#   'negative'],
#  [['jetblue',
#    'i',
#    'want',
#    'enter',
#    'family',
#    'pooling',
#    'contest',
#    'say',
#    '``',
#    '2/19',
#    "''",
#    'website',
#    'i',
#    'please',
#    'enter',
#    'still'],
#   'neutral'],
#  [['usairways', 'choose', 'seat', 'free', 'clicking', '100', 'button'],
#   'neutral'],
#  [['united', 'plus', 'food', 'and', 'taxi'], 'negative'],
#  [['usairways', '3hr30min', 'right', '...', 'end', 'sight'], 'negative'],
#  [['southwestair',
#    "'re",
#    'really',
#    'going',
#    'let',
#    'delta',
#    'virginamerica',
#    'get',
#    'best',
#    'http',
#    '//t.co/vudwjm1lyb'],
#   'negative'],
#  [['usairways',
#    'claim',
#    'flight',
#    'cancelled',
#    'flighted',
#    'due',
#    'weather',
#    'destination',
#    'delta',
#    'cancelled',
#    'flighted',
#    'flight',
#    'route'],
#   'negative'],
#  [['jetblue', 'thanks', 'much', 'help', 'u', 'u', 'r', 'amazing'], 'positive'],
#  [['americanair',
#    'haha',
#    'i',
#    'they',
#    'said',
#    "n't",
#    'fault',
#    'somehow',
#    'you',
#    'guy',
#    'r',
#    'joke'],
#   'negative'],
#  [['americanair',
#    'customer',
#    'service',
#    'inferior',
#    'nationalized',
#    'third',
#    'world',
#    'nation',
#    "'s",
#    'airline',
#    'get',
#    'together'],
#   'negative'],
#  [['americanair', 'why', 'iphone', 'app', 'sort', 'notification', 'option'],
#   'negative'],
#  [['united', 'thank'], 'positive'],
#  [['americanair',
#    'i',
#    "'ve",
#    'trying',
#    'reach',
#    'customer',
#    'service',
#    'two',
#    'day',
#    'i',
#    'received',
#    'zero',
#    'response',
#    'never',
#    'traveling',
#    'aa'],
#   'negative'],
#  [['united',
#    'flight',
#    '4567',
#    'agent',
#    'wandered',
#    'pilot',
#    'came',
#    'looking',
#    'went',
#    'charge',
#    'personal',
#    'phone',
#    "'d",
#    'txting'],
#   'negative'],
#  [['united',
#    'first',
#    'lost',
#    'bag',
#    'cancelled',
#    'flight',
#    'flight',
#    'home',
#    '30',
#    'min',
#    'wait',
#    'talk',
#    'somebody',
#    'poorservice',
#    'notgoodenough'],
#   'negative'],
#  [['southwestair',
#    'sat',
#    'plane',
#    '2+',
#    'hr',
#    '2/15',
#    'then',
#    'finally',
#    'took',
#    '..'],
#   'negative'],
#  [['jetblue', 'anywhere', 'http', '//t.co/fefhpmfple'], 'neutral'],
#  [['usairways',
#    'i',
#    'spend',
#    'cost',
#    'flight',
#    'get',
#    'free',
#    'room',
#    'transportation',
#    'airport'],
#   'negative'],
#  [['southwestair',
#    'understand',
#    'weather',
#    'kid',
#    'need',
#    'get',
#    'home',
#    'nice',
#    'kid',
#    'volunteer',
#    'work',
#    'ri',
#    'high',
#    'school',
#    'please',
#    'help'],
#   'neutral'],
#  [['americanair',
#    'my',
#    'friend',
#    'need',
#    'help',
#    'flt',
#    "'s",
#    'twiiter',
#    'i',
#    'dm',
#    'info'],
#   'neutral'],
#  [['americanair',
#    'mom',
#    '’',
#    'flight',
#    'tomorrow',
#    'cancelled',
#    'flighted',
#    'w/',
#    'notice',
#    'phone',
#    'system',
#    'said',
#    'callback',
#    '2',
#    'hour',
#    '’',
#    '4',
#    'i',
#    'need',
#    'go',
#    'bed'],
#   'negative'],
#  [['americanair',
#    'flight',
#    'veers',
#    'icy',
#    'runway',
#    'dfwairport',
#    'most',
#    'dfw',
#    'flight',
#    'cancelled',
#    'flighted',
#    'mon',
#    'http',
#    '//t.co/q37pown6uv',
#    'cowboycerrone',
#    'figure',
#    'right'],
#   'negative'],
#  [['united',
#    'could',
#    'tell',
#    'bag',
#    'would',
#    'accepted',
#    'personal',
#    'item',
#    'can',
#    'bring',
#    'one',
#    'carry-on',
#    'bag',
#    'plus',
#    'http',
#    '//t.co/u390czplhl'],
#   'neutral'],
#  [['united',
#    'yo',
#    'need',
#    'new',
#    'website',
#    'really',
#    'badly',
#    'this',
#    'day',
#    'age',
#    '...'],
#   'negative'],
#  [['southwestair',
#    'theellenshow',
#    'imaginedragons',
#    'kdepetro313',
#    '.what',
#    'great',
#    'first',
#    'night',
#    'destinationdragons',
#    'http',
#    '//t.co/n3lrfo4uay'],
#   'positive'],
#  [['usairways', 'right', 'up', 'up', 'amp', 'away', '✈️🌞'], 'positive'],
#  [['united',
#    'now',
#    'two',
#    'dozen',
#    'back',
#    'line',
#    'see',
#    'single',
#    'csr',
#    'reflight',
#    'booking',
#    'problem',
#    'final',
#    'leg',
#    'kiosk',
#    'fritz'],
#   'negative'],
#  [['jetblue',
#    'why',
#    'would',
#    'charge',
#    'money',
#    'transfer',
#    'point',
#    'someone'],
#   'negative'],
#  [['usairways',
#    'is',
#    'possible',
#    'earn',
#    'dividend',
#    'mile',
#    'passenger',
#    'even',
#    'i',
#    'purchasing',
#    'ticket'],
#   'neutral'],
#  [['lmfaooo',
#    '“',
#    'jetblue',
#    'our',
#    'fleet',
#    "'s",
#    'fleek',
#    'http',
#    '//t.co/1g9rnmyuqe',
#    '”'],
#   'positive'],
#  [['usairways',
#    'is',
#    'phone',
#    'line',
#    'call',
#    "n't",
#    'affected',
#    '``',
#    'bad',
#    'weather',
#    "''",
#    'trying',
#    'book',
#    'vacation',
#    '...',
#    '👀'],
#   'neutral'],
#  [['americanair',
#    'i',
#    'never',
#    'seen',
#    'incompetency',
#    'gate',
#    'agent',
#    'year',
#    'business',
#    'travel',
#    'dfw',
#    'b16',
#    'gate',
#    'agent',
#    'need',
#    'training',
#    'new',
#    'job'],
#   'negative'],
#  [['usairways',
#    'f623',
#    'den',
#    'phx',
#    'impressive',
#    'lack',
#    'concern',
#    '1hr+',
#    'late',
#    'flight',
#    'flight',
#    'attndt',
#    'wrecking',
#    'havoc',
#    'customer',
#    'travel',
#    'smugsmirk',
#    'norush'],
#   'negative'],
#  [['united',
#    'have',
#    'client',
#    '11',
#    'hr',
#    'layover',
#    'iah',
#    'day',
#    'will',
#    'claim',
#    'amp',
#    'recheck',
#    'luggage',
#    'or',
#    'taken',
#    'care'],
#   'neutral'],
#  [['united',
#    'even',
#    'change',
#    'could',
#    'made',
#    'online-',
#    'instructed',
#    'call',
#    'agent-',
#    'maybe',
#    'syastem',
#    'allow',
#    'agent',
#    '2',
#    'link',
#    'passenger'],
#   'negative'],
#  [['united',
#    'ca',
#    "n't",
#    'claim',
#    '``',
#    'weather',
#    "''",
#    'hardworking',
#    'crew',
#    'pulling',
#    'seat',
#    'plane',
#    'do',
#    'right',
#    'thing',
#    'but',
#    'know',
#    'wo',
#    "n't"],
#   'negative'],
#  [['americanair',
#    'finally',
#    'called',
#    'ca',
#    "n't",
#    'get',
#    'met',
#    'seattle',
#    'refund',
#    'processed',
#    'thanks'],
#   'positive'],
#  [['united',
#    'played',
#    'most',
#    'bizarre',
#    '``',
#    'safety',
#    "''",
#    'video',
#    'i',
#    "'ve",
#    'ever',
#    'seen',
#    '...',
#    'http',
#    '//t.co/hlm2oks6xl'],
#   'neutral'],
#  [['southwestair',
#    'i',
#    "'m",
#    'sure',
#    'i',
#    'messaging',
#    'part',
#    'right',
#    'please',
#    'let',
#    'know',
#    'received'],
#   'neutral'],
#  [['southwestair',
#    'booked',
#    '8th',
#    '....',
#    'save',
#    'emergency',
#    'exit',
#    '...',
#    'got',
#    'ta',
#    'stretch'],
#   'neutral'],
#  [['southwestair',
#    'try',
#    'get',
#    'customer',
#    'destination',
#    'no',
#    'help',
#    'get',
#    'another',
#    'airline',
#    'flight',
#    '3',
#    'day'],
#   'negative'],
#  [['jetblue', 'did', 'catch', 'name', 'i', 'sure', 'jason', 'know'],
#   'neutral'],
#  [['usairways',
#    'yet',
#    'another',
#    'delay/missed',
#    'connection',
#    '....',
#    'customer',
#    'service',
#    'attitude',
#    'wow'],
#   'negative'],
#  [['usairways',
#    'no',
#    'access',
#    'dividend',
#    'mile',
#    'week',
#    'automated',
#    'phone',
#    'keep',
#    'telling',
#    'call',
#    'back',
#    'late',
#    'flightr',
#    'frustrated',
#    'livepersonplease'],
#   'negative'],
#  [['united',
#    'when',
#    'direct',
#    'flight',
#    'belfast',
#    'intl',
#    'newark',
#    'resume',
#    'winter',
#    'break',
#    'thanks'],
#   'neutral'],
#  [['united',
#    'lgjw7b',
#    'i',
#    'voluntarily',
#    'rerouted',
#    '1st',
#    'leg',
#    'journey',
#    'economy',
#    'supposed',
#    '8b',
#    're',
#    'agent',
#    'said',
#    "'d",
#    'reserve'],
#   'neutral'],
#  [['southwestair',
#    'nashville',
#    'airport',
#    'runway',
#    'open',
#    'it',
#    'appears',
#    'southwest',
#    'airline',
#    'cancelled',
#    'flighting',
#    'flight',
#    'is',
#    'likely',
#    'change'],
#   'negative'],
#  [['usairways',
#    'flight',
#    'plan',
#    'delayed',
#    'tuesday',
#    'due',
#    'computer',
#    'crash'],
#   'negative'],
#  [['southwestair',
#    'this',
#    'unbelievable',
#    '...',
#    'thank',
#    'much',
#    'destinationdragons'],
#   'positive'],
#  [['united',
#    'big',
#    'surprise',
#    'nogate',
#    'waiting',
#    'plane',
#    'same',
#    'fucken',
#    'issue',
#    'everything',
#    'i',
#    'fly',
#    'fail',
#    'worstairlineever'],
#   'negative'],
#  [['usairways',
#    'tough',
#    'night',
#    'two',
#    '90',
#    'minute',
#    'call',
#    'hold',
#    'delayed',
#    'phoenix',
#    'two',
#    'day',
#    'one',
#    'aircraft',
#    'ready',
#    'not',
#    'acceptable'],
#   'negative'],
#  [['united',
#    "'s",
#    'hard',
#    'stay',
#    'upset',
#    'someone',
#    'least',
#    'try',
#    'show',
#    'remorse'],
#   'negative'],
#  [['united',
#    '50',
#    'min',
#    'hold',
#    'trying',
#    'book',
#    'award',
#    'flight',
#    'site',
#    'error',
#    'agent',
#    'ask',
#    'pin',
#    'see',
#    'platinum',
#    'availability',
#    'badbadbad'],
#   'negative'],
#  [['usairways',
#    '23',
#    'min',
#    'hold',
#    '...',
#    'drove',
#    '2.5',
#    'hour',
#    'get',
#    'delayed',
#    'bag',
#    'i',
#    'want',
#    'pick',
#    'sju'],
#   'negative'],
#  [['usairways',
#    'i',
#    'reserve',
#    'seat',
#    'aa',
#    'flight',
#    'i',
#    'transfer',
#    'ord',
#    'evv'],
#   'neutral'],
#  [['united',
#    'start',
#    '3xdaily',
#    'embraersa',
#    'erj145',
#    'flight',
#    'chicago',
#    'fly2ohare',
#    'evansville',
#    '4jun',
#    'avgeek'],
#   'neutral'],
#  [['united',
#    'flight',
#    '1136',
#    'chicago',
#    'houston',
#    '2',
#    'hour',
#    'pretzel',
#    'peanut',
#    'seriously',
#    'passed'],
#   'negative'],
#  [['united',
#    'i',
#    'left',
#    'comment',
#    'customer',
#    'care',
#    'thanks',
#    'contacting'],
#   'positive'],
#  [['united', 'they', 'held', 'plane', 'made'], 'positive'],
#  [['americanair',
#    'that',
#    "'s",
#    'ok',
#    '...',
#    'you',
#    'may',
#    'keep',
#    '25',
#    'lose',
#    'bag',
#    'info',
#    'longer',
#    'trust',
#    'bad',
#    'way',
#    'handle'],
#   'negative'],
#  [['virginamerica', 'thestarter', '😁'], 'neutral'],
#  [['jetblue',
#    'learning',
#    'awesome',
#    'twitter',
#    'management',
#    'today',
#    'social',
#    'medium',
#    'marketing',
#    'class',
#    'keep',
#    'good',
#    'work',
#    'sxu',
#    'phd_mama_'],
#   'positive'],
#  [['americanair',
#    'dropping',
#    'ball',
#    'again',
#    'no',
#    'catering',
#    'plane',
#    'switch',
#    'no',
#    'gate',
#    'attendant',
#    '2',
#    'hour',
#    'late',
#    'flight',
#    'really',
#    'nice'],
#   'negative'],
#  [['americanair',
#    'good',
#    'care',
#    'customer',
#    'anything',
#    'happen',
#    'take',
#    'delta',
#    'getting',
#    'back',
#    'nyc',
#    'screw',
#    'americanair'],
#   'negative'],
#  [['americanair',
#    'i',
#    "n't",
#    'think',
#    'help',
#    'based',
#    'behavior',
#    'the',
#    'voucher',
#    'cot',
#    'seem',
#    'like',
#    'enough',
#    'lol',
#    '😃'],
#   'neutral'],
#  [['united',
#    'i',
#    'think',
#    'problem',
#    'resolution',
#    'decided',
#    'end',
#    'especially',
#    "'d",
#    'like',
#    'continue',
#    'flying',
#    'airline'],
#   'negative'],
#  [['usairways',
#    'i',
#    "'ve",
#    'hold',
#    '36',
#    'min',
#    'counting',
#    'cause',
#    'charged',
#    'credit',
#    'card',
#    'bag',
#    'provided',
#    'receipt',
#    'said',
#    'error',
#    'awful'],
#   'negative'],
#  [['united', 'great', 'looking', 'forward', 'response', 'dm'], 'positive'],
#  [['united',
#    "'s",
#    '21st',
#    'birthday',
#    'sister',
#    'coming',
#    'celebrate',
#    'flight',
#    'keep',
#    'cancelled',
#    'flighting',
#    'plz',
#    'get'],
#   'negative'],
#  [['usairways',
#    'ur',
#    'employee',
#    'named',
#    'van',
#    'ticket',
#    'counter',
#    'philadelphia',
#    'extremely',
#    'rude',
#    'father',
#    'trying',
#    'get',
#    'home',
#    'sick',
#    'kid',
#    'missed',
#    'flight'],
#   'negative'],
#  [['southwestair',
#    'horrible',
#    'experience',
#    'ever',
#    'airline',
#    '..',
#    'have',
#    'reconsider',
#    'future',
#    'flight',
#    'customer',
#    'service',
#    '...',
#    'http',
#    '//t.co/eczhcmm5vi'],
#   'negative'],
#  [['americanair',
#    'tomorrow',
#    'site',
#    'show',
#    'flight',
#    '1642',
#    'ewr',
#    'cancelled',
#    'flightled'],
#   'negative'],
#  [['virginamerica',
#    'i',
#    'like',
#    'customer',
#    'service',
#    '40',
#    'min',
#    'delay',
#    'connecting',
#    'passenger',
#    'seems',
#    'long',
#    'va370'],
#   'negative'],
#  [['virginamerica',
#    'cutest',
#    'salt',
#    'pepper',
#    'shaker',
#    'ever',
#    'just',
#    'i',
#    'think',
#    'guy',
#    'ca',
#    "n't",
#    'get',
#    'better',
#    'http',
#    '//t.co/vc6keulg2j'],
#   'positive'],
#  [['americanair',
#    'unbelievable',
#    'i',
#    'even',
#    'wait',
#    'hold',
#    'speak',
#    'human',
#    'resolve',
#    'issue',
#    'the',
#    'system',
#    'simply',
#    'hang'],
#   'negative'],
#  [['americanair',
#    'continues',
#    'win',
#    'i',
#    "'ve",
#    'never',
#    'missed',
#    'flight',
#    'nice',
#    'little',
#    'quiet',
#    'gate',
#    'change',
#    'made',
#    'possible',
#    'sheesh'],
#   'positive'],
#  [['usairways',
#    'even',
#    'offered',
#    'fly',
#    'another',
#    'airport',
#    'said',
#    'could',
#    "n't",
#    'no',
#    'explanation',
#    'ca',
#    "n't"],
#   'neutral'],
#  [['usairways',
#    'phone',
#    'number',
#    'gate',
#    'gave',
#    "n't",
#    'work',
#    'either',
#    'what',
#    'customer',
#    'service',
#    'phone',
#    'number'],
#   'negative'],
#  [['jetblue', 'flight', '1041', 'savannah', 'ga'], 'neutral'],
#  [['americanair',
#    'yes',
#    'still',
#    'human',
#    'i',
#    'hope',
#    'dealing',
#    'horror',
#    'story',
#    'people',
#    'share',
#    '...',
#    'i',
#    'complained',
#    'dot',
#    'everyone'],
#   'negative'],
#  [['jetblue', 'sent', 'plane', 'doe', 'anyone', 'jetblue', 'clue'],
#   'negative'],
#  [['southwestair', 'winner', 'imaginedragons', 'destinationdragons'],
#   'neutral'],
#  [['united',
#    'quick',
#    'serious',
#    'question',
#    'resources/ratings',
#    'showing',
#    'quality',
#    'service',
#    'better',
#    '8th',
#    'place',
#    'http',
#    '//t.co/dewithpew2'],
#   'negative'],
#  [['united',
#    'get',
#    'first',
#    'flight',
#    'day',
#    'ground',
#    'time',
#    '1531',
#    'let',
#    "'s",
#    'go',
#    '.......'],
#   'negative'],
#  [['“',
#    'southwestair',
#    'southwest',
#    'mobile',
#    'boarding',
#    'pass',
#    'available',
#    'io',
#    'passbook',
#    'http',
#    '//t.co/xmrvr4lgeg',
#    'http',
#    '//t.co/wjoc9f14su',
#    '”',
#    'tori_leggieri'],
#   'neutral'],
#  [['southwestair', 'i', "'m", 'stuck', 'fort', 'lauderdale'], 'negative'],
#  [['jetblue',
#    'i',
#    'clear',
#    'folder',
#    'regularly',
#    'jetblue',
#    'white',
#    'listed',
#    'never',
#    'got'],
#   'neutral'],
#  [['united',
#    'keep',
#    'flight',
#    'cheap',
#    'early/on',
#    'time',
#    'good',
#    'flew',
#    'americanair',
#    'cancelled',
#    'flightled',
#    'flight',
#    '4',
#    'time',
#    'last',
#    'month',
#    'united',
#    'gt'],
#   'positive'],
#  [['jetblue',
#    'i',
#    'believe',
#    "'s",
#    'irina',
#    'on',
#    'flip-side',
#    'super',
#    'disappointed',
#    'eatup',
#    'cafe',
#    "n't",
#    'available',
#    'bos',
#    '--',
#    'gt',
#    'sfo',
#    'flight',
#    'today'],
#   'negative'],
#  [['usairways',
#    '5534',
#    'that',
#    "'s",
#    'flight',
#    'i',
#    'placed',
#    'original',
#    'flight',
#    'charlotte',
#    'cancelled',
#    'flightled',
#    'now',
#    '5534',
#    '1hr',
#    'delay'],
#   'negative'],
#  [['usairways',
#    'the',
#    'captain',
#    'turned',
#    'seat',
#    'belt',
#    'sign',
#    'people',
#    'get',
#    'walk',
#    'around',
#    'that',
#    "'s",
#    'good'],
#   'negative'],
#  [['united',
#    'http',
#    '//t.co/5hpsqvrjk8',
#    'flight',
#    'gone',
#    'i',
#    'got',
#    'plane',
#    'businesstravel',
#    'goodenoughmother'],
#   'negative'],
#  [['americanair',
#    'call',
#    'chairman',
#    'call',
#    'emerald',
#    'after',
#    'today',
#    'call',
#    'former',
#    'customer'],
#   'negative'],
#  [['jetblue', 'saw', 'one', 'useless', 'tsa', 'agent', 'inspected', 'shoe'],
#   'negative'],
#  [['united', 'thank', 'response'], 'neutral'],
#  [['americanair',
#    'one',
#    'received',
#    'text',
#    'alert',
#    'automated',
#    'call',
#    'anything',
#    'either',
#    'literally',
#    'information',
#    'happening'],
#   'negative'],
#  [['usairways', 'made', 'send', 'bloody', 'mary', "'s", 'row', '27'],
#   'positive'],
#  [['united',
#    '5',
#    'gate',
#    'change',
#    'two',
#    'delay',
#    'even',
#    'crew',
#    'think',
#    'airline',
#    'suck'],
#   'negative'],
#  [['usairways',
#    'thank',
#    'you',
#    'empathy',
#    'story',
#    'luggage',
#    'thank',
#    'reaching'],
#   'positive'],
#  [['jetblue',
#    'thanks',
#    'jb',
#    'actually',
#    'a',
#    'birder',
#    'i',
#    'love',
#    'they',
#    'need',
#    'outside',
#    'it',
#    "n't",
#    'hard',
#    'trap',
#    'move'],
#   'positive'],
#  [['usairways',
#    'flt',
#    '5302',
#    'clt',
#    'day',
#    'supposed',
#    'depart',
#    '5:51',
#    '6:20',
#    '...',
#    'still',
#    'crew',
#    'schedule/contact',
#    'pilot'],
#   'negative'],
#  [['jetblue',
#    'allow',
#    'payment',
#    'apple',
#    'pay',
#    'patriarc',
#    'http',
#    '//t.co/bduauzfhw2'],
#   'neutral'],
#  [['united',
#    'rep',
#    'hung',
#    '35',
#    'min',
#    'hold',
#    'i',
#    'asked',
#    'supervisor',
#    'i',
#    "'m",
#    'furious',
#    'right'],
#   'negative'],
#  [['americanair',
#    "'re",
#    "'re",
#    'trying',
#    'book',
#    'past',
#    'need',
#    '2',
#    'arrive',
#    "'re",
#    'still',
#    'selling',
#    'seat',
#    'day',
#    'i',
#    "'m",
#    'trying',
#    '2',
#    'travel'],
#   'negative'],
#  [['usairways',
#    'americanair',
#    'seriously',
#    'service',
#    'issue',
#    'right',
#    'decide',
#    'tweet',
#    'unbelievable'],
#   'negative'],
#  [['americanair', 'i', 'also', 'passed', 'website', 'around', 'passenger'],
#   'neutral'],
#  [['united',
#    'clicked',
#    'link',
#    'got',
#    'confused',
#    'http',
#    '//t.co/xmaqcucwzl'],
#   'neutral'],
#  [['americanair',
#    'well',
#    'cleared',
#    'custom',
#    'auh',
#    'i',
#    'need',
#    'get',
#    'iah',
#    'i',
#    'arrive',
#    'dfw',
#    'is',
#    'possible',
#    'retrieve',
#    'luggage',
#    'iad'],
#   'neutral'],
#  [['southwestair',
#    'taylorlumsden',
#    'taylor',
#    'u',
#    'got',
#    'ta',
#    'love',
#    'swa',
#    'responsiveness',
#    'least',
#    'huh'],
#   'negative'],
#  [['americanair',
#    'flight',
#    'cancelled',
#    'flightled',
#    'ca',
#    "n't",
#    'get',
#    'desk',
#    'nothing',
#    'showing',
#    'online',
#    'reservation',
#    'i'],
#   'negative'],
#  [['americanair',
#    'usairways',
#    'i',
#    "'m",
#    'pregnant',
#    'twin',
#    "'re",
#    'going',
#    'abandon',
#    'overnight',
#    'airport',
#    'no',
#    'hotel',
#    'when',
#    "'s",
#    'fault'],
#   'negative'],
#  [['united',
#    'thanks',
#    'prompt',
#    'response',
#    'another',
#    'hour',
#    'enjoy',
#    'vacation',
#    'perhaps',
#    'bug',
#    'app',
#    'still',
#    'show',
#    '2:55'],
#   'positive'],
#  [['united', 'tried', 'can', 'figure', 'go', 'get'], 'neutral'],
#  [['united', 'except', 'delayed', 'flight', 'anyway'], 'negative'],
#  [['jetblue', 'get', 'flight', '16', 'air'], 'negative'],
#  [['united',
#    'let',
#    'assure',
#    'travel',
#    'time',
#    '4h2m',
#    '5h2m',
#    'timezones',
#    'accuratetraveltimes',
#    '3rdtimethishashappened',
#    'http',
#    '//t.co/e0c9bi09cf'],
#   'negative'],
#  [['united', 'thanks', 'catch', 'conection'], 'positive'],
#  [['“',
#    'jetblue',
#    'our',
#    'fleet',
#    "'s",
#    'fleek',
#    'http',
#    '//t.co/ajm3bhjvaa',
#    '”',
#    'foh'],
#   'neutral'],
#  [['virginamerica', 'i', 'flight', 'artisanal', 'cheese', 'wine', 'pairing'],
#   'positive'],
#  [['united',
#    'flight',
#    'ua3364',
#    'sitting',
#    'tarmac',
#    '30',
#    'min',
#    'report',
#    '...',
#    'input'],
#   'negative'],
#  [['usairways', 'sits', 'throne', 'lie'], 'negative'],
#  [['southwestair',
#    '3',
#    'flight',
#    'cancelled',
#    'flightled',
#    'today',
#    'now',
#    'hold',
#    'hour'],
#   'negative'],
#  [['southwestair',
#    'late',
#    'flightly',
#    "'ve",
#    'always',
#    'late',
#    'flight',
#    'please',
#    'get',
#    'back',
#    'old',
#    'swa'],
#   'negative'],
#  [['americanair',
#    'my',
#    'ex-boyfriend',
#    'pick',
#    'call',
#    'cancelled',
#    'flightedflight',
#    'nocustomerservice',
#    'americanairlines',
#    'fail'],
#   'negative'],
#  [['southwestair',
#    'i',
#    'would',
#    'do',
#    'anything',
#    'for',
#    'ticket',
#    'vega',
#    '...',
#    'anything',
#    'i',
#    'love',
#    'imagine',
#    'dragon',
#    'much'],
#   'positive'],
#  [['southwestair',
#    'thanks',
#    'attention',
#    'i',
#    "'ve",
#    'flying',
#    'southwest',
#    '3',
#    'year',
#    "n't",
#    'issue',
#    'past'],
#   'positive'],
#  [['usairways',
#    'never',
#    'let',
#    "'s",
#    'every',
#    'single',
#    'flight',
#    'get',
#    'delayed'],
#   'negative'],
#  [['usairways',
#    'wife',
#    'flying',
#    'atlanta',
#    'vega',
#    'march',
#    '7th',
#    'since',
#    'could',
#    "n't",
#    'get',
#    'tricities',
#    'tn'],
#   'neutral'],
#  [['united',
#    'flight',
#    'ua1665',
#    'got',
#    'delayed',
#    '2',
#    'hour',
#    'due',
#    'mechanical',
#    'issue',
#    '...',
#    'could',
#    'use',
#    'free',
#    'drink',
#    '3',
#    'make',
#    'inconvenience'],
#   'negative'],
#  [['virginamerica',
#    'dream',
#    'http',
#    '//t.co/oa2drfaoq2',
#    'http',
#    '//t.co/lwwdac2khx'],
#   'neutral'],
#  [['southwestair',
#    'i',
#    "'m",
#    'line',
#    'airport',
#    'right',
#    'will',
#    'cover',
#    'hotel',
#    'fair',
#    'i',
#    'sleep',
#    'airport'],
#   'negative'],
#  [['jetblue',
#    'i',
#    "n't",
#    'know-',
#    'one',
#    'would',
#    'tell',
#    'coming',
#    'i',
#    'would',
#    'guess',
#    "'s",
#    'change',
#    'flight'],
#   'negative'],
#  [['americanair',
#    'worry',
#    "'re",
#    'swamped',
#    'i',
#    'know',
#    'dmd',
#    'back',
#    'thank',
#    'u'],
#   'neutral'],
#  [['southwestair',
#    'forgot',
#    'put',
#    'tsa',
#    'pre',
#    'number',
#    'i',
#    'checked',
#    'it',
#    'profile',
#    'boarding',
#    'pas'],
#   'neutral'],
#  [['southwestair', 'five', 'people', 'shown', 'yet'], 'neutral'],
#  [['americanair',
#    'i',
#    "'ve",
#    'never',
#    'anything',
#    'bad',
#    'say',
#    'no',
#    'love',
#    'faithful',
#    'customer'],
#   'negative'],
#  [['southwestair',
#    'hello',
#    '..',
#    'flight',
#    'taking',
#    'dallaslovefield',
#    'airport',
#    'noon',
#    'am',
#    'supposed',
#    'travel',
#    'flight',
#    '376',
#    'san',
#    'antonio'],
#   'neutral'],
#  [['southwestair',
#    'i',
#    'love',
#    'appreciate',
#    'fact',
#    'guy',
#    'rarely',
#    'cancelled',
#    'flight',
#    'flight',
#    'time',
#    'i',
#    'need',
#    'cancelled',
#    'flightlation',
#    'time',
#    '🙏'],
#   'positive'],
#  [['americanair', 'connection', 'us2065'], 'neutral'],
#  [['united', 'good', 'man', "n't", 'fault', 'plane', 'maintenance', 'issue'],
#   'positive'],
#  [['americanair',
#    'i',
#    "'m",
#    'sensitive',
#    'fact',
#    'i',
#    "n't",
#    'believe',
#    'warrant',
#    'poor',
#    'service',
#    'a',
#    'little',
#    'help',
#    'amp',
#    'compassion',
#    'go',
#    'long',
#    'way'],
#   'negative'],
#  [['jetblue',
#    'online',
#    'resource',
#    'say',
#    "'re",
#    'time',
#    'clearly',
#    'this',
#    'information',
#    'age',
#    '...'],
#   'negative'],
#  [['united',
#    'you',
#    'make',
#    'hard',
#    'fly',
#    'delayed',
#    'hour',
#    'plane',
#    'turning',
#    'around',
#    'amp',
#    'heading',
#    'back',
#    'gate',
#    'connection'],
#   'negative'],
#  [['usairways',
#    'people',
#    'kind',
#    'hardworking',
#    'infrastructure',
#    'given',
#    'horrid',
#    'massivefail',
#    'failphone',
#    'fail'],
#   'negative'],
#  [['jetblue',
#    'thanks',
#    'her',
#    '80th',
#    'bday',
#    'saturday',
#    'we',
#    "'re",
#    'aviation',
#    'themed',
#    'surprise',
#    'party'],
#   'positive'],
#  [['jetblue',
#    'airway',
#    'reveals',
#    "'bluemanity",
#    'livery',
#    'travelpulse',
#    'http',
#    '//t.co/fttfyfmvco'],
#   'positive'],
#  [['usairways',
#    'josephtreis',
#    'dont',
#    'bother',
#    'they',
#    'dont',
#    'pick',
#    'phone',
#    'worst',
#    'customer',
#    'service',
#    'going'],
#   'negative'],
#  [['americanair', 'are', 'expecting', 'delay', 'dfw', 'tomorrow', 'morning'],
#   'neutral'],
#  [['usairways',
#    'flight',
#    '1808',
#    'leaving',
#    '2:45',
#    "n't",
#    'even',
#    'begun',
#    'board',
#    'yet',
#    'please',
#    'update',
#    'website',
#    'asap'],
#   'negative'],
#  [['americanair',
#    'incredibly',
#    'arrogant',
#    'thing',
#    'say',
#    'i',
#    'sit',
#    "o'hare",
#    'waiting',
#    'incompetent',
#    'airline',
#    'refuel',
#    '...'],
#   'negative'],
#  [['jetblue',
#    'airline',
#    'trouble',
#    'winter',
#    'amp',
#    'getting',
#    'good',
#    'customer',
#    'service',
#    'contact',
#    'http',
#    '//t.co/aqjn4hwnac',
#    'negotiate',
#    'resolution',
#    'you'],
#   'neutral'],
#  [['united',
#    'thankful',
#    'great',
#    'service',
#    'newark',
#    'seat',
#    'fixed',
#    'i',
#    'seated',
#    'daughter',
#    'fab',
#    'landing',
#    'fort',
#    'myers'],
#   'positive'],
#  [['united',
#    'feeling',
#    'like',
#    'true',
#    'united',
#    'customer',
#    'stuck.on',
#    'tarmac',
#    'dc',
#    '2',
#    'hr',
#    'unitedfail'],
#   'negative'],
#  [['united',
#    'cool',
#    'your',
#    'customer',
#    'told',
#    "n't",
#    'care',
#    'either',
#    'it',
#    'expected'],
#   'negative'],
#  [['southwestair',
#    'today',
#    "'s",
#    'scavenger',
#    'hunt',
#    'start',
#    'i',
#    "'m",
#    'trying',
#    'help',
#    'little',
#    'brother',
#    'win',
#    'destinationdragons'],
#   'neutral'],
#  [['united',
#    'lt',
#    'lt',
#    'lt',
#    'lt',
#    'lt',
#    '--',
#    '--',
#    '--',
#    'shoddy',
#    'customer',
#    'service',
#    'of',
#    'use',
#    'whatsoever',
#    'unitedairline'],
#   'negative'],
#  [['jetblue',
#    'any',
#    'option',
#    'luggage',
#    'assistance',
#    'ground',
#    'hpn',
#    'flight',
#    '2168',
#    'delayed',
#    '2+',
#    'hour',
#    'amp',
#    '2',
#    'sleeping',
#    'kid',
#    'land'],
#   'negative'],
#  [['southwestair', 'i', 'dm', "'d"], 'neutral'],
#  [['united',
#    'yep—used',
#    'twice',
#    'case',
#    'id',
#    'number',
#    'assigned',
#    'tried',
#    'again-get',
#    'screen',
#    'say',
#    '“',
#    'thank',
#    'submitting',
#    'request',
#    '”'],
#   'negative'],
#  [['americanair',
#    'you',
#    'guy',
#    'amazing',
#    'job',
#    'today',
#    'know',
#    '’',
#    'hard',
#    'thanks',
#    'kate',
#    'appleton',
#    'hard',
#    'work',
#    'reflight',
#    'booking',
#    'problem',
#    'friend'],
#   'positive'],
#  [['americanair',
#    'really',
#    'need',
#    'customer',
#    'service',
#    'training',
#    'unhappy',
#    'ee',
#    'morning',
#    'chicago',
#    'gate',
#    'k20',
#    '430',
#    'chking',
#    'schd'],
#   'negative'],
#  [['southwestair', 'employee', 'great'], 'positive'],
#  [['americanair',
#    'souljacoy',
#    'aa',
#    'going',
#    'fix',
#    'utterly',
#    'embarrassing',
#    'customer',
#    'service',
#    'you',
#    'wo',
#    "n't",
#    'even',
#    'answer',
#    'dang',
#    'phone'],
#   'negative'],
#  [['southwestair',
#    'please',
#    'bring',
#    'back',
#    'rdu',
#    'fll',
#    'direct',
#    'route',
#    'i',
#    'noticed',
#    'missing',
#    'starting',
#    'late',
#    'flight',
#    'august',
#    'the',
#    'flight',
#    'always',
#    'packed'],
#   'neutral'],
#  [['usairways', "n't", 'want', 'get', 'home'], 'negative'],
#  [['usairways',
#    'the',
#    'phone',
#    'line',
#    'disconnect',
#    'how',
#    'i',
#    'queue',
#    'answered',
#    'phone',
#    'line',
#    'simply',
#    'disconnect',
#    'i',
#    'call'],
#   'negative'],
#  [['jetblue',
#    'i',
#    "'m",
#    'sitting',
#    'plane',
#    'too',
#    'many',
#    'predictable',
#    'mechanical',
#    'problem',
#    'still',
#    'onboard',
#    'this',
#    'getting',
#    'bad',
#    '...'],
#   'negative'],
#  [['usairways', 'shivadelrahim', 'upgrade'], 'neutral'],
#  [['usairways',
#    'never',
#    'received',
#    'horrible',
#    'service',
#    'treated',
#    'poorly',
#    'richard',
#    'p.',
#    'today',
#    'no',
#    'excuse',
#    'attitude',
#    'amp',
#    'ripping',
#    'ticket'],
#   'neutral'],
#  [['jetblue',
#    'i',
#    'get',
#    'copy',
#    'last',
#    'flight',
#    'showing',
#    'original',
#    'time',
#    'delay',
#    'i',
#    'need',
#    'work',
#    'thanks'],
#   'neutral'],
#  [['jetblue',
#    'get',
#    'honest',
#    'update',
#    'departure',
#    'flite',
#    '454',
#    'been',
#    'plane',
#    'infant',
#    'child'],
#   'negative'],
#  [['usairways',
#    'u',
#    '728',
#    'wait',
#    'gate',
#    'opened',
#    'back',
#    'go',
#    'good',
#    'maybe',
#    'get'],
#   'neutral'],
#  [['americanair',
#    'not',
#    'maintenance',
#    'md80',
#    'sits',
#    'two',
#    'day',
#    'frozen',
#    'line',
#    'found',
#    'boarded',
#    'come',
#    'faail',
#    'mci'],
#   'negative'],
#  [['southwestair',
#    'seriously',
#    'the',
#    'worst',
#    'i',
#    "n't",
#    'remember',
#    'last',
#    'time',
#    'i',
#    'someone',
#    'i',
#    'knew',
#    'flight',
#    "n't",
#    'delayed',
#    'cancelled',
#    'flightled',
#    'etc'],
#   'negative'],
#  [['united',
#    'wont',
#    'transfer',
#    'flight',
#    'ticket',
#    'accompany',
#    '11',
#    'yr',
#    'old',
#    "'s",
#    'active',
#    'military',
#    'mom',
#    'emergency',
#    'brain',
#    'surgery',
#    'wow'],
#   'negative'],
#  [['usairways',
#    'ticket',
#    'counter',
#    'people',
#    'helping',
#    'want',
#    'charge',
#    'money',
#    'even',
#    'horrible',
#    'day'],
#   'negative'],
#  [['united',
#    '4',
#    'seg',
#    'flt',
#    'yvr',
#    'zurich',
#    'would',
#    'credit',
#    'mile',
#    '2',
#    'segs',
#    'full',
#    'fare'],
#   'negative'],
#  [['americanair',
#    'need',
#    'know',
#    "n't",
#    'done',
#    'like',
#    'promised',
#    'would',
#    'yesterday'],
#   'negative'],
#  [['jetblue', 'kudos', 'and', "'re", 'done', 'heading', 'warmer', 'weather'],
#   'positive'],
#  [['southwestair',
#    'yall',
#    'trying',
#    'fly',
#    'chicago',
#    'i',
#    "n't",
#    'live',
#    'send',
#    'home',
#    'bullshit',
#    'as',
#    'customer',
#    'service'],
#   'negative'],
#  [['southwestair',
#    'stay',
#    'chicago',
#    'overnight',
#    'meet',
#    'bag',
#    'i',
#    'hope',
#    'stay',
#    'put',
#    "n't",
#    'get',
#    'put',
#    'flight'],
#   'negative'],
#  [['united', 'severely', 'staffed', 'iah'], 'negative'],
#  [['americanair',
#    'fantastic',
#    'thanks',
#    'will',
#    'try',
#    'tweet',
#    'photo',
#    'view'],
#   'positive'],
#  [['southwestair',
#    'i',
#    'love',
#    'companion',
#    'pas',
#    'qualified',
#    '4th',
#    'year',
#    'hollymais'],
#   'positive'],
#  [['americanair',
#    'said',
#    'aa',
#    'provide',
#    'in-flight',
#    'wifi',
#    'route',
#    'china',
#    'based',
#    'federal',
#    'law',
#    'united'],
#   'negative'],
#  [['southwestair',
#    'boarding',
#    'pass',
#    'compatible',
#    'iphone',
#    'passbook',
#    'http',
#    '//t.co/1esmmnizek'],
#   'neutral'],
#  [['usairways',
#    'disaster',
#    'flight',
#    '3739',
#    'missed',
#    'passenger',
#    'count',
#    '5',
#    'since',
#    'done',
#    'manually',
#    'really'],
#   'negative'],
#  [['jetblue', 'u', 'suck', 'big', 'donkey', 'ball'], 'negative'],
#  [['southwestair',
#    'thanks',
#    'confirmation',
#    'number',
#    'dmed',
#    'appreciate',
#    'help'],
#   'positive'],
#  [['jetblue',
#    'i',
#    "n't",
#    'made',
#    'feel',
#    'like',
#    'criminal',
#    'i',
#    'want',
#    'sit',
#    'near',
#    '5',
#    'year',
#    'old',
#    'flight',
#    'jetblue',
#    'http',
#    '//t.co/qgtcao1j2u'],
#   'negative'],
#  [['americanair', "'ve", 'already', 'made', 'arrangement'], 'neutral'],
#  [['usairways',
#    'add',
#    'frequent',
#    'flyer',
#    'number',
#    'website',
#    'can',
#    'help'],
#   'negative'],
#  [['southwestair',
#    'ticket',
#    'booked',
#    '1/27',
#    'cun',
#    'doe',
#    'arrival',
#    'time',
#    'reflect',
#    'cun',
#    'est',
#    'time'],
#   'neutral'],
#  [['united',
#    'lot',
#    'unhappy',
#    'cold',
#    'people',
#    'bridge',
#    'freezing',
#    'temp',
#    'hour',
#    'not',
#    'given',
#    'info'],
#   'negative'],
#  [['jetblue',
#    'we',
#    "'d",
#    'love',
#    'help',
#    'shanese',
#    'bryant-melton',
#    'hard-working',
#    'grandmother',
#    'dc',
#    'go',
#    'miami',
#    'it',
#    "'s",
#    'bucket',
#    'list',
#    'flyitforward'],
#   'neutral'],
#  [['united',
#    'want',
#    'book',
#    'multi-city',
#    'fare',
#    'have',
#    'mile',
#    '1of',
#    '2',
#    'flight',
#    'an',
#    'option',
#    'pay',
#    '1st',
#    'flight',
#    'mile',
#    '+2nd',
#    'ump',
#    'visa',
#    'thanks'],
#   'neutral'],
#  [['united',
#    'when',
#    'email',
#    'address/username',
#    'sign-on',
#    'available',
#    'it',
#    "'s"],
#   'negative'],
#  [['united',
#    'yes',
#    'i',
#    "'ve",
#    'waiting',
#    'four',
#    'hour',
#    'one',
#    'able',
#    'help'],
#   'negative'],
#  [['americanair',
#    'i',
#    'thank',
#    'what',
#    'i',
#    'i',
#    'ca',
#    "n't",
#    'get',
#    'flight',
#    'hold',
#    'cancelled',
#    'flight'],
#   'neutral'],
#  [['usairways',
#    'flight',
#    'scheduled',
#    '730pm',
#    '...',
#    'told',
#    '150am',
#    'flight',
#    'cancelled',
#    'flightled',
#    'sitting',
#    'cold',
#    'plane',
#    '2',
#    'hour'],
#   'negative'],
#  [['united',
#    'yes',
#    'plenty',
#    'seat',
#    'available',
#    'so',
#    'vicky',
#    'thomas',
#    'refuse',
#    'give',
#    'one',
#    'million',
#    'mile',
#    'flyer'],
#   'negative'],
#  [['united',
#    'ua63',
#    'madrid',
#    'arrived',
#    'agent',
#    'mass',
#    'confusion',
#    'sent',
#    'fro',
#    '3',
#    'ua',
#    'employee',
#    'maryjo',
#    'rude',
#    'unhelpful'],
#   'negative'],
#  [['usairways',
#    'americanair',
#    'terminal',
#    'e',
#    'miami',
#    'still',
#    'worst',
#    'smelly',
#    'airport',
#    'ever',
#    'thanks',
#    'nothing'],
#   'negative'],
#  [['united',
#    'great',
#    'decision',
#    'making',
#    'skill',
#    'flight',
#    'ops',
#    'iah',
#    'bag',
#    'make',
#    '10',
#    'minute',
#    'connection',
#    'i',
#    "n't",
#    'flight',
#    'pushed',
#    'early',
#    'disappointed'],
#   'negative'],
#  [['jetblue',
#    'when',
#    'i',
#    'checked',
#    'yesterday',
#    'looked',
#    'like',
#    'did',
#    'something',
#    'change'],
#   'neutral'],
#  [['united', 'weighed', '45.5', 'checked', 'bag'], 'negative'],
#  [['usairways',
#    'when',
#    'i',
#    'check',
#    'online',
#    'state',
#    'status',
#    'closed',
#    'what',
#    'mean',
#    'a',
#    'i',
#    'yet',
#    'able',
#    'reach',
#    'live',
#    'person',
#    '...'],
#   'negative'],
#  [['united',
#    'asked',
#    'dm',
#    'ignore',
#    'please',
#    'assist',
#    'changing',
#    'another',
#    'flight',
#    'today-',
#    '21',
#    'feb',
#    'fra',
#    'mco',
#    'avoiding',
#    'iad'],
#   'negative'],
#  [['americanair',
#    'americanairlines',
#    'approach',
#    'mex',
#    '....',
#    'http',
#    '//t.co/se57dmjhiw'],
#   'neutral'],
#  [['united',
#    'amp',
#    'finally',
#    'told',
#    'couldnt',
#    'use',
#    'front',
#    'plane',
#    'restrm',
#    'row7',
#    'though',
#    'myself/others',
#    'row',
#    'behind',
#    'used',
#    'w/no',
#    'issue'],
#   'negative'],
#  [['americanair',
#    'earlier',
#    'flight',
#    'sap-',
#    'gt',
#    'mia',
#    'amp',
#    'mia',
#    'gt',
#    'new',
#    'york',
#    'lga',
#    '03.03',
#    'i',
#    "'m",
#    'currently',
#    'booked',
#    'flight',
#    '1504',
#    '1102'],
#   'neutral'],
#  [['united',
#    'last',
#    'night',
#    'waited',
#    'forever',
#    'gate',
#    'someone',
#    'corporate',
#    'dispatch',
#    'forgot',
#    'call',
#    'crew',
#    'unfriendlyskies'],
#   'negative'],
#  [['united',
#    'seriously',
#    "'s",
#    '2015',
#    'no',
#    'wifi',
#    '5hr',
#    'flight',
#    'cle-sfo',
#    '1589',
#    'you',
#    "'re",
#    'only',
#    'airline',
#    'without',
#    'wifi',
#    '...'],
#   'negative'],
#  [['united',
#    'told',
#    'changed',
#    'flight',
#    'im',
#    'ottawa',
#    'airport',
#    'ac',
#    'cant',
#    'find',
#    'reservation',
#    'whats',
#    'wrong'],
#   'negative'],
#  [['“',
#    'jetblue',
#    'analystdoc',
#    'unfortunately',
#    "'s",
#    'available',
#    'option',
#    'current',
#    'system',
#    'sorry',
#    'guy',
#    'that',
#    "'s",
#    'certain',
#    'fail',
#    'fix',
#    'plz'],
#   'negative'],
#  [['united',
#    "n't",
#    'need',
#    'apology',
#    'need',
#    'bag',
#    'took',
#    '56',
#    'minute',
#    'landing',
#    'get',
#    'unacceptable'],
#   'negative'],
#  [['americanair',
#    'see',
#    'photo',
#    'b787',
#    'scale',
#    'model',
#    'amp',
#    'pn',
#    '320008a',
#    'wheel',
#    'deflator',
#    'specified',
#    'chapter',
#    '32',
#    'b787',
#    'amm',
#    'http',
#    '//t.co/kfd4wqrklw'],
#   'neutral'],
#  [['united',
#    'flying',
#    'stl',
#    'saturday',
#    'expecting',
#    'ice',
#    'amp',
#    'snow',
#    'when',
#    'start',
#    'looking',
#    'travel',
#    'waiver',
#    'thanks'],
#   'neutral'],
#  [['americanair',
#    'thanks',
#    'getting',
#    'back',
#    'but',
#    'i',
#    'find',
#    'airline',
#    'future'],
#   'negative'],
#  [['virginamerica', 'know', 'need', 'spotify', 'stat', 'guiltypleasures'],
#   'positive'],
#  [['united',
#    'i',
#    'patient',
#    'luxurious',
#    'middle',
#    'seat',
#    'next',
#    'delayed',
#    'flight'],
#   'negative'],
#  [['usairways',
#    '4',
#    'hour',
#    'tarmac',
#    'charleston',
#    'still',
#    'ca',
#    "n't",
#    'get',
#    'response',
#    'week',
#    'unacceptable'],
#   'negative'],
#  [['southwestair',
#    'what',
#    "'s",
#    'happened',
#    'customer',
#    'service',
#    '2',
#    'cancelled',
#    'flightled',
#    'flight',
#    '2',
#    'day',
#    'amp',
#    'uninformed',
#    'unapologetic',
#    'staff',
#    'nolove',
#    'cali'],
#   'negative'],
#  [['united',
#    '777',
#    'sfo',
#    'hnl',
#    'zero',
#    'entertainment',
#    'system',
#    'youareonyourown'],
#   'negative'],
#  [['americanair',
#    '3078',
#    'overweight',
#    'pull',
#    '2',
#    'dozen',
#    'passenger',
#    'why',
#    'luggage',
#    'seriously'],
#   'negative'],
#  [['jetblue',
#    'disappointed',
#    'flight',
#    'back',
#    'boston',
#    'pr',
#    'cancelled',
#    'flightled',
#    'rebooked',
#    '4',
#    'next',
#    'day',
#    'delayed',
#    'one',
#    'compensation'],
#   'negative'],
#  [['united', 'better', 'customer', 'service', 'john', 'wayne', 'airport'],
#   'negative'],
#  [['americanair',
#    'waiting',
#    'delayed',
#    'plane',
#    'sat',
#    'plane',
#    'hour',
#    'waiting',
#    'late',
#    'flight',
#    'passenger',
#    'that',
#    "'s",
#    'b',
#    '..'],
#   'negative'],
#  [['united', 'a', 'always', 'help', 'communicate', 'customer'], 'negative'],
#  [['united',
#    "'re",
#    'customer',
#    'service',
#    'unbelievably',
#    'bad',
#    'abysmal',
#    'i',
#    "'ve",
#    'phone',
#    'well',
#    '2hrs',
#    'tonight',
#    'hung',
#    'yr',
#    'ppl',
#    '3x'],
#   'negative'],
#  [['southwestair',
#    '3rd',
#    'time',
#    'flying',
#    'southwest',
#    'two',
#    'year',
#    'have',
#    'another',
#    'trip',
#    'back',
#    'mx',
#    'october'],
#   'neutral'],
#  [['americanair', 'priority', 'baggage', 'evidently', 'mean', 'come', 'last'],
#   'negative'],
#  [['united',
#    'i',
#    'mention',
#    'one',
#    'bag',
#    'infant',
#    'car',
#    'seat',
#    'amp',
#    "'ve",
#    'stuck',
#    'yr',
#    'poor',
#    'replacement',
#    'icy',
#    'mtn',
#    'road'],
#   'negative'],
#  [['united', 'just', 'thanks', 'checking'], 'positive'],
#  [['americanair',
#    'i',
#    'understand',
#    'i',
#    "'m",
#    'even',
#    'put',
#    'hold',
#    'say',
#    '``',
#    'try',
#    'late',
#    'flightr',
#    'goodbye',
#    "''"],
#   'negative'],
#  [['united',
#    'i',
#    'wo',
#    "n't",
#    'check',
#    'carry',
#    'watched',
#    'handler',
#    'throw',
#    'bag',
#    '--',
#    'miss',
#    'conveyer',
#    'belt',
#    '--',
#    'sat',
#    '10',
#    'min',
#    'http',
#    '//t.co/lyoocx5msh'],
#   'negative'],
#  [['southwestair',
#    'you',
#    'rerouted',
#    'bf',
#    "'s",
#    'flight',
#    "'s",
#    'diabetic',
#    'little',
#    'insulin',
#    'even',
#    'though',
#    'tried',
#    'change',
#    'agent',
#    'would',
#    "n't"],
#   'negative'],
#  [['americanair',
#    "'s",
#    'lot',
#    'talk',
#    'mia-sfo',
#    '20+',
#    'year',
#    'old',
#    'plane',
#    'nonewplanes',
#    'old',
#    'shame',
#    'http',
#    '//t.co/twetpxuppn'],
#   'negative'],
#  [['americanair',
#    'flight',
#    'dca',
#    'i',
#    'need',
#    'change',
#    'asap',
#    'help',
#    'ca',
#    "n't",
#    'get'],
#   'negative'],
#  [['united',
#    'all',
#    'change',
#    'way',
#    'stick',
#    'premiere',
#    '1k',
#    'loyal',
#    'customer',
#    'why',
#    'make',
#    'thing',
#    'harder',
#    'loyal'],
#   'negative'],
#  [['usairways',
#    'ok',
#    '...',
#    'know',
#    'door',
#    'close',
#    '~10',
#    'minute',
#    'takeoff',
#    'stop',
#    'telling',
#    'flight',
#    'leave',
#    '20',
#    'minute',
#    "n't",
#    'boarded'],
#   'negative'],
#  [['united', 'i', 'hope', 'see', 'issue', 'return', 'flight', 'tomorrow'],
#   'negative'],
#  [['united', 'customer', 'service', '👎'], 'negative'],
#  [['usairways',
#    'my',
#    'wife',
#    'sick',
#    '3yr-old-twins',
#    'i',
#    'waiting',
#    'line',
#    '2hrs',
#    'see',
#    'agent',
#    'phone',
#    'agent',
#    'said',
#    'nothing',
#    'til',
#    'tuesday'],
#   'negative'],
#  [['jetblue',
#    'ruining',
#    'vacation',
#    'left',
#    'right',
#    'who',
#    'would',
#    'thought',
# ...
#    'promotion',
#    'moment',
#    'modelodenegocio',
#    'innovation',
#    'innovacion',
#    'businessmodel'],
#   'neutral'],
#  [['united', 'our', 'newest', 'delay', 'right', 'http', '//t.co/96ftlzwtvo'],
#   'negative'],
#  [['united',
#    'hello',
#    'united',
#    'you',
#    'take',
#    'care',
#    'call',
#    'center',
#    'mexico',
#    'city',
#    'office',
#    'terrible',
#    'attitude',
#    'lady',
#    'helping'],
#   'negative'],
#  [['jetblue',
#    'offer',
#    'service',
#    'daytona',
#    'beach',
#    'new',
#    'york',
#    'albany',
#    'business',
#    'review',
#    'http',
#    '//t.co/duhbj41jhx'],
#   'positive'],
#  [['americanair',
#    'i',
#    "'m",
#    'trying',
#    'choose',
#    'seat',
#    'every',
#    'time',
#    'i',
#    'go',
#    'next',
#    'flight',
#    'i',
#    'get',
#    'system',
#    'error'],
#   'negative'],
#  [['jetblue',
#    '...',
#    "n't",
#    'heard',
#    'anyone',
#    'week',
#    'nonstop',
#    'flight',
#    'baggage',
#    'lost/stolen',
#    'customer',
#    'service',
#    '👎'],
#   'negative'],
#  [['jetblue',
#    "'ve",
#    'delayed',
#    'almost',
#    '2',
#    'hr',
#    'i',
#    'take',
#    'jetblue',
#    'i',
#    "'ve",
#    'good',
#    'luck',
#    'today',
#    'really',
#    'frustrating'],
#   'negative'],
#  [['jetblue',
#    'w/',
#    '70',
#    'upgrade',
#    'unsure',
#    'ca',
#    "n't",
#    'switch',
#    'someone',
#    'around',
#    'i',
#    'called',
#    '24',
#    'hr',
#    'advance',
#    'reason'],
#   'negative'],
#  [['jetblue', 'great', 'thanks'], 'positive'],
#  [['united',
#    'thank',
#    'getting',
#    'daughter',
#    'home',
#    'americanair',
#    'cancelled',
#    'flightled',
#    'flight',
#    'nashville'],
#   'positive'],
#  [['united',
#    'yes',
#    '...',
#    'a',
#    'ride',
#    'home',
#    'would',
#    'perfect',
#    '..',
#    'a',
#    'fete',
#    'one',
#    'would',
#    'assume',
#    'possible',
#    'charging',
#    '1600',
#    'domestic',
#    'flight',
#    '...',
#    'p',
#    'deplaned'],
#   'negative'],
#  [['southwestair',
#    'totally',
#    'ruined',
#    'birthday',
#    'weekend',
#    'cancelled',
#    'flighting',
#    'flight',
#    'reason',
#    'offer',
#    'point',
#    'drink',
#    'transport',
#    'nolove',
#    'cali'],
#   'negative'],
#  [['united',
#    'nope',
#    'you',
#    'need',
#    'little',
#    'red',
#    'stamp',
#    'counter',
#    'check',
#    'wreck',
#    'son',
#    'http',
#    '//t.co/0prgysvurm'],
#   'negative'],
#  [['united', 'referral', 'program', 'milageplus', 'explorer', 'card'],
#   'neutral'],
#  [['americanair',
#    'guy',
#    'fail',
#    '..',
#    'i',
#    'need',
#    'use',
#    'voucher',
#    'ticket',
#    'i',
#    'ca',
#    "n't",
#    'online',
#    'yourphonesystemsucks'],
#   'negative'],
#  [['southwestair',
#    'look',
#    'like',
#    '1',
#    'yr',
#    'anni',
#    'trip',
#    'replaced',
#    'w',
#    'someone',
#    "'s",
#    'itinerary',
#    'worried',
#    'abt',
#    'c',
#    'flight',
#    'http',
#    '//t.co/bape6rumne'],
#   'negative'],
#  [['americanair',
#    'thanks',
#    'finally',
#    'letting',
#    'get',
#    'book',
#    'flight',
#    'frustration',
#    'set',
#    '...',
#    'donedeal',
#    'talktoahuman'],
#   'negative'],
#  [['united',
#    'took',
#    'one',
#    'not',
#    'window',
#    'also',
#    'fun',
#    'get',
#    'motion',
#    'sick',
#    'http',
#    '//t.co/m81rv0blxs'],
#   'negative'],
#  [['jetblue', 'keep', 'getting', 'better', 'no', 'water', 'plane'],
#   'negative'],
#  [['jetblue',
#    'thank',
#    'hopefully',
#    "'s",
#    'soon',
#    'we',
#    'supposed',
#    'leave',
#    '11:23'],
#   'negative'],
#  [['united',
#    'thank',
#    "y'all",
#    'amazing',
#    'airline',
#    'know',
#    'treat',
#    'customer',
#    'guy',
#    'rock'],
#   'positive'],
#  [['southwestair',
#    'sent',
#    'looking',
#    'functionality',
#    'app',
#    'though',
#    'one',
#    'click',
#    'action'],
#   'negative'],
#  [['americanair',
#    'i',
#    'need',
#    'help',
#    'my',
#    'record',
#    'locator',
#    'bringing',
#    'two',
#    'different',
#    'flight',
#    'system',
#    'one',
#    'op',
#    'aa',
#    'amp',
#    'one',
#    'u',
#    'airway'],
#   'neutral'],
#  [['jetblue',
#    "'s",
#    'okay',
#    '...',
#    'i',
#    "'m",
#    'actually',
#    'tea',
#    'kinda',
#    'guy',
#    'anyway',
#    'thanks'],
#   'positive'],
#  [['united',
#    'held',
#    'almost',
#    '45',
#    'minute',
#    'promised',
#    'free',
#    'movie',
#    "n't",
#    'work',
#    'neither',
#    'wifi',
#    'paid',
#    'boo'],
#   'negative'],
#  [['americanair',
#    'what',
#    "'s",
#    'baggage',
#    'handler',
#    'calling',
#    'dfw',
#    'today',
#    'no',
#    'luggage',
#    'onboard',
#    'plane'],
#   'negative'],
#  [['usairways',
#    'i',
#    'would',
#    'go',
#    'though',
#    'entire',
#    'process',
#    'get',
#    'people',
#    'phone',
#    'usairwayssucks'],
#   'negative'],
#  [['usairways',
#    'crazy',
#    'treated',
#    'mom',
#    'poorly',
#    'not',
#    'happy',
#    'usairwaysfail'],
#   'negative'],
#  [['southwestair', 'many', 'left'], 'neutral'],
#  [['usairways',
#    'you',
#    'work',
#    'hard',
#    'making',
#    'sure',
#    'thing',
#    'flow',
#    'smoothly',
#    'keeping',
#    'positive'],
#   'positive'],
#  [['usairways',
#    'do',
#    "n't",
#    'blame',
#    'weather',
#    'rep',
#    'counter',
#    'cost',
#    'entire',
#    'day',
#    'weather',
#    'printed',
#    'boarding',
#    'pas',
#    'late',
#    'flight',
#    'takeresponsibility'],
#   'negative'],
#  [['united',
#    'thanks',
#    'updating',
#    '1+',
#    'hour',
#    'delay',
#    'exact',
#    'second',
#    'i',
#    'got',
#    'atl',
#    '🙅🙅🙅'],
#   'positive'],
#  [['united',
#    'how',
#    'considered',
#    '``',
#    'time',
#    "''",
#    "'s",
#    'arriving',
#    'destination',
#    'half',
#    'hour',
#    'late',
#    'flightr',
#    'scheduled',
#    'http',
#    '//t.co/ymftw1uyhr'],
#   'negative'],
#  [['americanair',
#    'i',
#    'rebooked',
#    "n't",
#    'get',
#    'notified',
#    'cancelled',
#    'flightled'],
#   'negative'],
#  [['usairways',
#    'shoutout',
#    '2',
#    'kristie',
#    'sp',
#    'gate4',
#    'pvd',
#    'today',
#    'she',
#    "'s",
#    'rockstar',
#    'tremendous',
#    'help',
#    'tough',
#    'situation',
#    'promotethatgirl'],
#   'positive'],
#  [['united',
#    'check-in',
#    'luggage',
#    'employee',
#    'told',
#    'include',
#    'wheel',
#    'dimension'],
#   'neutral'],
#  [['united', '25', 'minute', 'hold', '1', 'hr', '25', 'min', 'abc11_wtvd'],
#   'negative'],
#  [['usairways', 'you', 'guy', 'screwing', 'trip', 'thanks', 'nothing', 'lazy'],
#   'negative'],
#  [['united',
#    'passenger',
#    'waited',
#    'inside',
#    'flight',
#    'runway',
#    'returned',
#    'back',
#    'gate',
#    'count',
#    'valid',
#    'journey'],
#   'negative'],
#  [['usairways',
#    'frustrating',
#    'day',
#    'no',
#    'flight',
#    'home',
#    'changed',
#    'airline',
#    'thank',
#    'phl',
#    'usairway',
#    'employee',
#    'amp',
#    'united',
#    'help',
#    'getting',
#    'back',
#    'iah'],
#   'positive'],
#  [['united',
#    'u',
#    'guy',
#    'changed',
#    'age',
#    'double',
#    'booked',
#    'seat',
#    'i',
#    'i',
#    "'ve",
#    'even',
#    'though',
#    'i',
#    'platinum',
#    'person',
#    'none'],
#   'negative'],
#  [['usairways',
#    'cancelled',
#    'flightled',
#    'last',
#    'part',
#    'ticket',
#    'confused',
#    'email',
#    'i',
#    'received',
#    'whether',
#    'value',
#    'remains',
#    'is',
#    'someone',
#    'i',
#    'ask'],
#   'neutral'],
#  [['united',
#    'if',
#    'business',
#    'decision',
#    'made',
#    'inconvenience',
#    'possibly',
#    'cause',
#    'lost',
#    'customer',
#    'good',
#    'business',
#    'decision',
#    'cranky'],
#   'negative'],
#  [['usairways',
#    'flight',
#    'got',
#    'cancelled',
#    'flightled',
#    'charlotte',
#    'been',
#    'hold',
#    'hour',
#    'pls',
#    'pick'],
#   'negative'],
#  [['virginamerica', 'wow', 'blew', 'mind'], 'positive'],
#  [['americanair',
#    'aa2416',
#    'time',
#    'awesome',
#    'flight',
#    'great',
#    'job',
#    'american'],
#   'positive'],
#  [['southwestair', "n't", 'realize', 'clothes', 'hotel', 'suggestion'],
#   'neutral'],
#  [['southwestair',
#    'got',
#    'mine',
#    'just',
#    'time',
#    'wife',
#    '15th',
#    'anniversary'],
#   'positive'],
#  [['“',
#    'southwestair',
#    'pancho_joe',
#    'no',
#    'must',
#    "'ve",
#    'heard',
#    'u',
#    'wrong',
#    'sweet',
#    'mixtape',
#    'though',
#    "''",
#    '4',
#    'record',
#    'i',
#    "n't",
#    'leave',
#    '80',
#    "'s",
#    '80',
#    "'s",
#    'left'],
#   'neutral'],
#  [['americanair',
#    'sitting',
#    'gate',
#    'flight',
#    '719',
#    'hour',
#    'due',
#    'sabre',
#    'what',
#    'backup',
#    'plan',
#    'place',
#    'sabre',
#    'fixed'],
#   'negative'],
#  [['southwestair',
#    'favorite',
#    'airline',
#    'i',
#    "'ve",
#    'never',
#    'issue',
#    'plus',
#    'crew',
#    'entertaining'],
#   'positive'],
#  [['usairways', 'i', 'made', 'thanks', 'help'], 'positive'],
#  [['usairways',
#    'utterly',
#    'unreliable',
#    'they',
#    "n't",
#    'schedule',
#    'pilot',
#    'us624',
#    'flight',
#    'seattle',
#    'flight',
#    'delayed',
#    'usairwaysfail'],
#   'negative'],
#  [['southwestair',
#    'tremendous',
#    'job',
#    'atlanta',
#    'airport',
#    'saw',
#    'sw',
#    'celebrate',
#    'mardi',
#    'gras',
#    'another',
#    'reason',
#    'i',
#    "'m",
#    'nut',
#    'guy',
#    'http',
#    '//t.co/8wbzorrn3c'],
#   'neutral'],
#  [['united',
#    'seems',
#    'like',
#    'one',
#    'united',
#    'help',
#    'lot',
#    'finger',
#    'pointed',
#    'zero',
#    'people',
#    'stepping',
#    'at',
#    'least',
#    'gate',
#    'oreo'],
#   'negative'],
#  [['southwestair', '8fkqw', 'conf', 'thanks', 'reply'], 'neutral'],
#  [['united',
#    'rebooked',
#    '24',
#    'hour',
#    'original',
#    'flight',
#    'say',
#    'handling',
#    'situation',
#    'bad',
#    'would',
#    'understatement'],
#   'negative'],
#  [['americanair',
#    'flight',
#    'leaving',
#    'dallas',
#    'right',
#    'in',
#    'maui',
#    'trying',
#    'figure',
#    'delayed',
#    'flight',
#    '7',
#    'going'],
#   'negative'],
#  [['southwestair', 'one', 'heck', 'airline', 'http', '//t.co/cyoonzftdc'],
#   'positive'],
#  [['southwestair',
#    'flying',
#    'flight',
#    '3130',
#    'tonight',
#    '7:20',
#    'pbi-',
#    'i',
#    'boarding',
#    'position',
#    'c-42',
#    'is',
#    'overbooked',
#    'really',
#    "n't",
#    'want',
#    'bumped'],
#   'neutral'],
#  [['jetblue',
#    'client',
#    'got',
#    'zero',
#    '32',
#    'year',
#    'career',
#    'never',
#    'thought',
#    'possible.2',
#    'suitcase',
#    'worth',
#    'thousand',
#    'italian',
#    'clothing',
#    'robbed'],
#   'negative'],
#  [['usairways',
#    'you',
#    'cancelled',
#    'flightled',
#    'flight',
#    '...',
#    'are',
#    'paying',
#    'hotel'],
#   'negative'],
#  [['americanair',
#    'your',
#    'response',
#    'incredible',
#    'truly',
#    'amazed',
#    'step',
#    'taken',
#    'enhance',
#    'customer',
#    'relation',
#    'big',
#    'thank',
#    '😄'],
#   'positive'],
#  [['americanair',
#    'wow',
#    'regina',
#    'told',
#    'i',
#    'ca',
#    "n't",
#    'file',
#    'request',
#    'lost',
#    'bag',
#    'statement',
#    'i',
#    'finish',
#    'travel',
#    'so',
#    'i',
#    'get',
#    'dc',
#    'argg'],
#   'negative'],
#  [['united',
#    'since',
#    'i',
#    'international',
#    'connection',
#    '9am',
#    'i',
#    "'m",
#    'hoping',
#    'thing'],
#   'negative'],
#  [['jetblue', 'day'], 'negative'],
#  [['united',
#    'long',
#    'take',
#    'mile',
#    're-purchased',
#    'expired',
#    'show',
#    'i',
#    'recieved',
#    'email',
#    'request',
#    '..'],
#   'negative'],
#  [['united',
#    'probably',
#    'least',
#    'satisfactory',
#    'airline',
#    'i',
#    "'ve",
#    'ever',
#    'never',
#    'fails',
#    'disappoint'],
#   'negative'],
#  [['united',
#    'airline',
#    'is',
#    'changing',
#    'it',
#    'mileageplus',
#    'program',
#    'winner',
#    'and',
#    'loser',
#    'http',
#    '//t.co/f1yvaio9ul',
#    'http',
#    '//t.co/vglx6ykwqg'],
#   'neutral'],
#  [['americanair',
#    'seguinej',
#    'aa',
#    'joke',
#    'right',
#    'that',
#    'line',
#    "n't",
#    'even',
#    'accepting',
#    'call',
#    'right',
#    'hang'],
#   'negative'],
#  [['united',
#    'nonrefundable',
#    'hence',
#    'i',
#    'wrote',
#    '200',
#    'doe',
#    "n't",
#    'make',
#    'sense',
#    '150',
#    'credit',
#    'nothanks'],
#   'negative'],
#  [['jetblue',
#    'even',
#    '5',
#    'year',
#    'earthquake',
#    '...',
#    'haiti',
#    'still',
#    'need',
#    'help',
#    'rebuilding',
#    'flyingitforward'],
#   'neutral'],
#  [['usairways',
#    'despite',
#    'mechanical',
#    'issue',
#    'many',
#    'delay',
#    'followed',
#    'cancelled',
#    'flightlation',
#    'still',
#    'getting',
#    'vega',
#    'thanks',
#    'great',
#    'gate',
#    'agent'],
#   'positive'],
#  [['jetblue', 'excuse', 'though', '3', 'gate', 'change', 'though'],
#   'negative'],
#  [['jetblue',
#    'i',
#    'may',
#    'need',
#    'i',
#    '40',
#    'minute',
#    'layover',
#    '15',
#    'min',
#    'delay',
#    'first',
#    'flight'],
#   'negative'],
#  [['united',
#    'how',
#    'i',
#    'get',
#    'reimbursed',
#    'hotel',
#    'taxi',
#    'cancelled',
#    'flightation'],
#   'negative'],
#  [['americanair',
#    'yet',
#    'receive',
#    'assistance',
#    'one',
#    'agent',
#    'securing',
#    'new',
#    'connection',
#    'many',
#    'miss',
#    'work',
#    'tomorrow'],
#   'negative'],
#  [['usairways',
#    'british_airways',
#    'three',
#    'hour',
#    'flight',
#    'delay',
#    'on',
#    'phone',
#    '45min',
#    'counting'],
#   'negative'],
#  [['americanair', '2298', 'everyone', 'else', 'outstanding'], 'negative'],
#  [['united',
#    'i',
#    'think',
#    'rough',
#    'moment',
#    'w/',
#    'bad',
#    'passenger',
#    'earlier',
#    'flight',
#    'thing',
#    'got',
#    'considerably',
#    'better',
#    'thanks'],
#   'positive'],
#  [['usairways', 'thanks'], 'positive'],
#  [['americanair',
#    'i',
#    'cancelled',
#    'flightled',
#    'ticket',
#    'taking',
#    'two',
#    'month',
#    '++',
#    'refund',
#    'still',
#    'waiting'],
#   'negative'],
#  [['usairways', '’'], 'negative'],
#  [['usairways',
#    'shout',
#    'pilot',
#    'fc',
#    'attendant',
#    'eliz',
#    'u',
#    '673',
#    'super',
#    'strong',
#    'crosswind',
#    'landing',
#    'eliz',
#    'super',
#    'job',
#    'throughout'],
#   'positive'],
#  [['united',
#    'i',
#    'see',
#    'coming',
#    'get',
#    'aggiemensgolf',
#    'hawaii',
#    '12thman',
#    'http',
#    '//t.co/g8dka3edhf'],
#   'neutral'],
#  [['americanair', 'dfwairport', '2', 'together', 'best', 'part', 'flying'],
#   'positive'],
#  [['united',
#    'late',
#    'flight',
#    'future',
#    'flight',
#    'train',
#    'staff',
#    'better',
#    'handle',
#    'emergency',
#    'situation',
#    'ground',
#    'staff',
#    'customer',
#    'service'],
#   'negative'],
#  [['united', 'oh', 'united', 'much', 'i', 'despise', 'thee'], 'negative'],
#  [['united',
#    'airline',
#    'ceo',
#    'jeff',
#    'smisek',
#    'disloyal',
#    'loyal',
#    'worker',
#    'http',
#    '//t.co/0cevy3p42b',
#    'via',
#    'huffpostbiz'],
#   'neutral'],
#  [['united',
#    '3/10',
#    'disappointed',
#    'service',
#    'will',
#    'missing',
#    'connection',
#    'hour',
#    'delay',
#    'cramped',
#    'seat',
#    'at',
#    'least',
#    'app',
#    'good'],
#   'negative'],
#  [['americanair',
#    'sit',
#    'airport',
#    'long',
#    'periolodicly',
#    'time',
#    'plane',
#    'nasty'],
#   'negative'],
#  [['united', '618', 'flight', 'houston'], 'neutral'],
#  [['united', 'fuck', 'caring', '😢'], 'negative'],
#  [['southwestair',
#    'info',
#    'destinationdragons',
#    'winner',
#    'announced',
#    'amp',
#    'best',
#    'friend',
#    'hoping',
#    'win',
#    'thanks'],
#   'neutral'],
#  [['southwestair', 'thanks'], 'positive'],
#  [['southwestair',
#    'tweet',
#    'weekend/',
#    'bad',
#    'weather',
#    'close',
#    'customer',
#    'relation',
#    'center',
#    'process',
#    'refund',
#    'cancelled',
#    'flighted',
#    'flight'],
#   'negative'],
#  [['southwestair',
#    'missing',
#    '6,000',
#    'point',
#    'one',
#    'account',
#    'they',
#    "'re",
#    'spread',
#    'four',
#    'assuming',
#    'i',
#    'create',
#    'account'],
#   'negative'],
#  [['united',
#    'i',
#    'used',
#    'committed',
#    'continentalairlines',
#    'flyer',
#    'merger',
#    'i',
#    'remember',
#    'i',
#    'switched',
#    'southwestair',
#    'communicationfail'],
#   'negative'],
#  [['united', 'i', 'soon', 'i', 'done', 'article', 'thanks', '~tom'],
#   'positive'],
#  [['americanair',
#    "'re",
#    'finding',
#    'bc',
#    'united',
#    'rebooked',
#    'u',
#    'airline',
#    'realized',
#    'could',
#    "n't",
#    'get',
#    'u',
#    'home',
#    "'re",
#    'ord'],
#   'negative'],
#  [['usairways', 'i', 'gave', 'http', '//t.co/2edgc6tbls'], 'negative'],
#  [['usairways',
#    'ticket',
#    'couldnt',
#    'used',
#    'bc',
#    'unable',
#    'get',
#    'departing',
#    'dest',
#    'rsw',
#    'bc',
#    'blizzard',
#    'bos',
#    'told',
#    'way',
#    'use',
#    'credit',
#    '200',
#    'fine'],
#   'negative'],
#  ...]

# %%
####### making into x and y
x = [" ".join(i[0]) for i in arr]
y = [i[1] for i in arr]
x,y
# Out:
# (['southwestair i scheduled morning 2 day fact yes .. sure evening flight one cancelled flightled',
#   'southwestair seeing worker time time going beyond i love flying guy thank',
#   'united flew ord miami back great crew service leg thanks',
#   "southwestair dultch97 's horse radish 😤🐴",
#   'united flight ord delayed air force one last flight sbn 8:20 5 min landed',
#   'united why load u flying sardine knew pilot 2 hour late flight incompetent beyond belief',
#   "jetblue stock response delay frustrating poor cust serv amp told 3 ppl wait amp 'd come back",
#   "jetblue that 'd nice hoping rack enough mile take trip seattle enjoy perfect latte city coffee",
#   'united frankly worse customer service ever problem happen deal defines company never united',
#   "southwestair yeah haha never one it 's expensive 😂😂 so much fun destinationdragons",
#   "southwestair mco- gt dca flight almost full people screwed msy-dca cancelled flightation united usairways n't cancelled flight swa=mistake",
#   "jetblue 's easiest way get ticket receipt can i get one check i get one online thanks",
#   'usairways love change lounge cheese veggie olive addition cracker snack mix',
#   'southwestair i receive bad customer service ended spending several hundred dollar accommodate family cxl flight',
#   "usairways 're killing sche flight board 3 min mine arrived gate side airport genious",
#   "usairways 8 week refund ticket 0372389047497 totally unacceptable fix i 'll put blast social medium tv",
#   'americanair private msg provide detail ... u really need customer svc training staff',
#   "rt jetblue our fleet 's fleek http //t.co/413gial0yl",
#   'jetblue info flight 704 sju jfk already delayed 2 1/2 hour',
#   "americanair i 've tried le 8 time today get touch service desk beginning 8:30 est i 'm luck -help",
#   "usairways new problem ... wrong last name reservation airway fixed new ca n't get tsa",
#   'southwestair any possible chance swa bringing back service lga-bwi it would make much easier connect west coast',
#   'usairways americanair run show airport boarding pas say u airway i wait american line yousuck',
#   "united computer stopped giving update took flight info app that 's ridiculous keep people updated",
#   'united good fly united businessfirst',
#   'united i flying msp dxb child turn 2 trip i buy return ticket child',
#   'jetblue love cancelled flightling ticket telling customer flyunited',
#   'united in ord waited 20 min crew member left gate item came flight attendant sarcastically said good luck walked away',
#   'southwestair jason 108639 gate 3 san made afternoon southwestairlines stellarservice thanks',
#   'americanair everything sorted thanks help excited get home tonight',
#   'americanair understand weather would nice hear apology phone moved flight inconvenient day',
#   'southwestair thanks',
#   "united 's booked first class curbside delivery 24 hour i 'm counting teamusa",
#   "jetblue oh totally look par americanair 's admiral club way slide u couple pass",
#   "americanair we 've 15 official complaint signed americanairlines lima supervisor customer relation pls compensate 4 10-hour delay",
#   "jetblue 4 hour policy- i called said i n't report soon enough what would changed i noticed sooner",
#   "united frustrating flying experience one continuous `` i dunno time leave today `` dunno that 's code ...",
#   "southwestair hi i got message part flight cancelled flightled i ca n't rebook online nobody answer phone call help",
#   'southwestair i need update flight 464 amp 3574 i hold 2 hour',
#   "usairways i 'm supposed fly dallas can help get new itinerary",
#   'americanair fail flight rdu sitting waiting flight attendant logistics good',
#   'united i impressed super-fast reply cgjase',
#   "united i n't spoke baggage contact 1-800 number said try get bag stay iad pick tmrw",
#   'usairways who intentionally buy flight 10 hour layover and kind airline would charge 200 fix wow ... usairways',
#   "southwestair auto callback i n't wait hold",
#   'united i get service desk iad',
#   "jetblue blue helped bring color eye and i promise i n't eat free snack",
#   'united yes d y from therealaviation instagram',
#   "jetblue i report updated info n't know reach without super long wait hold main number",
#   "jetblue i want enter family pooling contest say `` 2/19 '' website i please enter still",
#   'usairways choose seat free clicking 100 button',
#   'united plus food and taxi',
#   'usairways 3hr30min right ... end sight',
#   "southwestair 're really going let delta virginamerica get best http //t.co/vudwjm1lyb",
#   'usairways claim flight cancelled flighted due weather destination delta cancelled flighted flight route',
#   'jetblue thanks much help u u r amazing',
#   "americanair haha i they said n't fault somehow you guy r joke",
#   "americanair customer service inferior nationalized third world nation 's airline get together",
#   'americanair why iphone app sort notification option',
#   'united thank',
#   "americanair i 've trying reach customer service two day i received zero response never traveling aa",
#   "united flight 4567 agent wandered pilot came looking went charge personal phone 'd txting",
#   'united first lost bag cancelled flight flight home 30 min wait talk somebody poorservice notgoodenough',
#   'southwestair sat plane 2+ hr 2/15 then finally took ..',
#   'jetblue anywhere http //t.co/fefhpmfple',
#   'usairways i spend cost flight get free room transportation airport',
#   'southwestair understand weather kid need get home nice kid volunteer work ri high school please help',
#   "americanair my friend need help flt 's twiiter i dm info",
#   'americanair mom ’ flight tomorrow cancelled flighted w/ notice phone system said callback 2 hour ’ 4 i need go bed',
#   'americanair flight veers icy runway dfwairport most dfw flight cancelled flighted mon http //t.co/q37pown6uv cowboycerrone figure right',
#   'united could tell bag would accepted personal item can bring one carry-on bag plus http //t.co/u390czplhl',
#   'united yo need new website really badly this day age ...',
#   'southwestair theellenshow imaginedragons kdepetro313 .what great first night destinationdragons http //t.co/n3lrfo4uay',
#   'usairways right up up amp away ✈️🌞',
#   'united now two dozen back line see single csr reflight booking problem final leg kiosk fritz',
#   'jetblue why would charge money transfer point someone',
#   'usairways is possible earn dividend mile passenger even i purchasing ticket',
#   "lmfaooo “ jetblue our fleet 's fleek http //t.co/1g9rnmyuqe ”",
#   "usairways is phone line call n't affected `` bad weather '' trying book vacation ... 👀",
#   'americanair i never seen incompetency gate agent year business travel dfw b16 gate agent need training new job',
#   'usairways f623 den phx impressive lack concern 1hr+ late flight flight attndt wrecking havoc customer travel smugsmirk norush',
#   'united have client 11 hr layover iah day will claim amp recheck luggage or taken care',
#   'united even change could made online- instructed call agent- maybe syastem allow agent 2 link passenger',
#   "united ca n't claim `` weather '' hardworking crew pulling seat plane do right thing but know wo n't",
#   "americanair finally called ca n't get met seattle refund processed thanks",
#   "united played most bizarre `` safety '' video i 've ever seen ... http //t.co/hlm2oks6xl",
#   "southwestair i 'm sure i messaging part right please let know received",
#   'southwestair booked 8th .... save emergency exit ... got ta stretch',
#   'southwestair try get customer destination no help get another airline flight 3 day',
#   'jetblue did catch name i sure jason know',
#   'usairways yet another delay/missed connection .... customer service attitude wow',
#   'usairways no access dividend mile week automated phone keep telling call back late flightr frustrated livepersonplease',
#   'united when direct flight belfast intl newark resume winter break thanks',
#   "united lgjw7b i voluntarily rerouted 1st leg journey economy supposed 8b re agent said 'd reserve",
#   'southwestair nashville airport runway open it appears southwest airline cancelled flighting flight is likely change',
#   'usairways flight plan delayed tuesday due computer crash',
#   'southwestair this unbelievable ... thank much destinationdragons',
#   'united big surprise nogate waiting plane same fucken issue everything i fly fail worstairlineever',
#   'usairways tough night two 90 minute call hold delayed phoenix two day one aircraft ready not acceptable',
#   "united 's hard stay upset someone least try show remorse",
#   'united 50 min hold trying book award flight site error agent ask pin see platinum availability badbadbad',
#   'usairways 23 min hold ... drove 2.5 hour get delayed bag i want pick sju',
#   'usairways i reserve seat aa flight i transfer ord evv',
#   'united start 3xdaily embraersa erj145 flight chicago fly2ohare evansville 4jun avgeek',
#   'united flight 1136 chicago houston 2 hour pretzel peanut seriously passed',
#   'united i left comment customer care thanks contacting',
#   'united they held plane made',
#   "americanair that 's ok ... you may keep 25 lose bag info longer trust bad way handle",
#   'virginamerica thestarter 😁',
#   'jetblue learning awesome twitter management today social medium marketing class keep good work sxu phd_mama_',
#   'americanair dropping ball again no catering plane switch no gate attendant 2 hour late flight really nice',
#   'americanair good care customer anything happen take delta getting back nyc screw americanair',
#   "americanair i n't think help based behavior the voucher cot seem like enough lol 😃",
#   "united i think problem resolution decided end especially 'd like continue flying airline",
#   "usairways i 've hold 36 min counting cause charged credit card bag provided receipt said error awful",
#   'united great looking forward response dm',
#   "united 's 21st birthday sister coming celebrate flight keep cancelled flighting plz get",
#   'usairways ur employee named van ticket counter philadelphia extremely rude father trying get home sick kid missed flight',
#   'southwestair horrible experience ever airline .. have reconsider future flight customer service ... http //t.co/eczhcmm5vi',
#   'americanair tomorrow site show flight 1642 ewr cancelled flightled',
#   'virginamerica i like customer service 40 min delay connecting passenger seems long va370',
#   "virginamerica cutest salt pepper shaker ever just i think guy ca n't get better http //t.co/vc6keulg2j",
#   'americanair unbelievable i even wait hold speak human resolve issue the system simply hang',
#   "americanair continues win i 've never missed flight nice little quiet gate change made possible sheesh",
#   "usairways even offered fly another airport said could n't no explanation ca n't",
#   "usairways phone number gate gave n't work either what customer service phone number",
#   'jetblue flight 1041 savannah ga',
#   'americanair yes still human i hope dealing horror story people share ... i complained dot everyone',
#   'jetblue sent plane doe anyone jetblue clue',
#   'southwestair winner imaginedragons destinationdragons',
#   'united quick serious question resources/ratings showing quality service better 8th place http //t.co/dewithpew2',
#   "united get first flight day ground time 1531 let 's go .......",
#   '“ southwestair southwest mobile boarding pass available io passbook http //t.co/xmrvr4lgeg http //t.co/wjoc9f14su ” tori_leggieri',
#   "southwestair i 'm stuck fort lauderdale",
#   'jetblue i clear folder regularly jetblue white listed never got',
#   'united keep flight cheap early/on time good flew americanair cancelled flightled flight 4 time last month united gt',
#   "jetblue i believe 's irina on flip-side super disappointed eatup cafe n't available bos -- gt sfo flight today",
#   "usairways 5534 that 's flight i placed original flight charlotte cancelled flightled now 5534 1hr delay",
#   "usairways the captain turned seat belt sign people get walk around that 's good",
#   'united http //t.co/5hpsqvrjk8 flight gone i got plane businesstravel goodenoughmother',
#   'americanair call chairman call emerald after today call former customer',
#   'jetblue saw one useless tsa agent inspected shoe',
#   'united thank response',
#   'americanair one received text alert automated call anything either literally information happening',
#   "usairways made send bloody mary 's row 27",
#   'united 5 gate change two delay even crew think airline suck',
#   'usairways thank you empathy story luggage thank reaching',
#   "jetblue thanks jb actually a birder i love they need outside it n't hard trap move",
#   'usairways flt 5302 clt day supposed depart 5:51 6:20 ... still crew schedule/contact pilot',
#   'jetblue allow payment apple pay patriarc http //t.co/bduauzfhw2',
#   "united rep hung 35 min hold i asked supervisor i 'm furious right",
#   "americanair 're 're trying book past need 2 arrive 're still selling seat day i 'm trying 2 travel",
#   'usairways americanair seriously service issue right decide tweet unbelievable',
#   'americanair i also passed website around passenger',
#   'united clicked link got confused http //t.co/xmaqcucwzl',
#   'americanair well cleared custom auh i need get iah i arrive dfw is possible retrieve luggage iad',
#   'southwestair taylorlumsden taylor u got ta love swa responsiveness least huh',
#   "americanair flight cancelled flightled ca n't get desk nothing showing online reservation i",
#   "americanair usairways i 'm pregnant twin 're going abandon overnight airport no hotel when 's fault",
#   'united thanks prompt response another hour enjoy vacation perhaps bug app still show 2:55',
#   'united tried can figure go get',
#   'united except delayed flight anyway',
#   'jetblue get flight 16 air',
#   'united let assure travel time 4h2m 5h2m timezones accuratetraveltimes 3rdtimethishashappened http //t.co/e0c9bi09cf',
#   'united thanks catch conection',
#   "“ jetblue our fleet 's fleek http //t.co/ajm3bhjvaa ” foh",
#   'virginamerica i flight artisanal cheese wine pairing',
#   'united flight ua3364 sitting tarmac 30 min report ... input',
#   'usairways sits throne lie',
#   'southwestair 3 flight cancelled flightled today now hold hour',
#   "southwestair late flightly 've always late flight please get back old swa",
#   'americanair my ex-boyfriend pick call cancelled flightedflight nocustomerservice americanairlines fail',
#   'southwestair i would do anything for ticket vega ... anything i love imagine dragon much',
#   "southwestair thanks attention i 've flying southwest 3 year n't issue past",
#   "usairways never let 's every single flight get delayed",
#   "usairways wife flying atlanta vega march 7th since could n't get tricities tn",
#   'united flight ua1665 got delayed 2 hour due mechanical issue ... could use free drink 3 make inconvenience',
#   'virginamerica dream http //t.co/oa2drfaoq2 http //t.co/lwwdac2khx',
#   "southwestair i 'm line airport right will cover hotel fair i sleep airport",
#   "jetblue i n't know- one would tell coming i would guess 's change flight",
#   "americanair worry 're swamped i know dmd back thank u",
#   'southwestair forgot put tsa pre number i checked it profile boarding pas',
#   'southwestair five people shown yet',
#   "americanair i 've never anything bad say no love faithful customer",
#   'southwestair hello .. flight taking dallaslovefield airport noon am supposed travel flight 376 san antonio',
#   'southwestair i love appreciate fact guy rarely cancelled flight flight time i need cancelled flightlation time 🙏',
#   'americanair connection us2065',
#   "united good man n't fault plane maintenance issue",
#   "americanair i 'm sensitive fact i n't believe warrant poor service a little help amp compassion go long way",
#   "jetblue online resource say 're time clearly this information age ...",
#   'united you make hard fly delayed hour plane turning around amp heading back gate connection',
#   'usairways people kind hardworking infrastructure given horrid massivefail failphone fail',
#   "jetblue thanks her 80th bday saturday we 're aviation themed surprise party",
#   "jetblue airway reveals 'bluemanity livery travelpulse http //t.co/fttfyfmvco",
#   'usairways josephtreis dont bother they dont pick phone worst customer service going',
#   'americanair are expecting delay dfw tomorrow morning',
#   "usairways flight 1808 leaving 2:45 n't even begun board yet please update website asap",
#   "americanair incredibly arrogant thing say i sit o'hare waiting incompetent airline refuel ...",
#   'jetblue airline trouble winter amp getting good customer service contact http //t.co/aqjn4hwnac negotiate resolution you',
#   'united thankful great service newark seat fixed i seated daughter fab landing fort myers',
#   'united feeling like true united customer stuck.on tarmac dc 2 hr unitedfail',
#   "united cool your customer told n't care either it expected",
#   "southwestair today 's scavenger hunt start i 'm trying help little brother win destinationdragons",
#   'united lt lt lt lt lt -- -- -- shoddy customer service of use whatsoever unitedairline',
#   'jetblue any option luggage assistance ground hpn flight 2168 delayed 2+ hour amp 2 sleeping kid land',
#   "southwestair i dm 'd",
#   'united yep—used twice case id number assigned tried again-get screen say “ thank submitting request ”',
#   'americanair you guy amazing job today know ’ hard thanks kate appleton hard work reflight booking problem friend',
#   'americanair really need customer service training unhappy ee morning chicago gate k20 430 chking schd',
#   'southwestair employee great',
#   "americanair souljacoy aa going fix utterly embarrassing customer service you wo n't even answer dang phone",
#   'southwestair please bring back rdu fll direct route i noticed missing starting late flight august the flight always packed',
#   "usairways n't want get home",
#   'usairways the phone line disconnect how i queue answered phone line simply disconnect i call',
#   "jetblue i 'm sitting plane too many predictable mechanical problem still onboard this getting bad ...",
#   'usairways shivadelrahim upgrade',
#   'usairways never received horrible service treated poorly richard p. today no excuse attitude amp ripping ticket',
#   'jetblue i get copy last flight showing original time delay i need work thanks',
#   'jetblue get honest update departure flite 454 been plane infant child',
#   'usairways u 728 wait gate opened back go good maybe get',
#   'americanair not maintenance md80 sits two day frozen line found boarded come faail mci',
#   "southwestair seriously the worst i n't remember last time i someone i knew flight n't delayed cancelled flightled etc",
#   "united wont transfer flight ticket accompany 11 yr old 's active military mom emergency brain surgery wow",
#   'usairways ticket counter people helping want charge money even horrible day',
#   'united 4 seg flt yvr zurich would credit mile 2 segs full fare',
#   "americanair need know n't done like promised would yesterday",
#   "jetblue kudos and 're done heading warmer weather",
#   "southwestair yall trying fly chicago i n't live send home bullshit as customer service",
#   "southwestair stay chicago overnight meet bag i hope stay put n't get put flight",
#   'united severely staffed iah',
#   'americanair fantastic thanks will try tweet photo view',
#   'southwestair i love companion pas qualified 4th year hollymais',
#   'americanair said aa provide in-flight wifi route china based federal law united',
#   'southwestair boarding pass compatible iphone passbook http //t.co/1esmmnizek',
#   'usairways disaster flight 3739 missed passenger count 5 since done manually really',
#   'jetblue u suck big donkey ball',
#   'southwestair thanks confirmation number dmed appreciate help',
#   "jetblue i n't made feel like criminal i want sit near 5 year old flight jetblue http //t.co/qgtcao1j2u",
#   "americanair 've already made arrangement",
#   'usairways add frequent flyer number website can help',
#   'southwestair ticket booked 1/27 cun doe arrival time reflect cun est time',
#   'united lot unhappy cold people bridge freezing temp hour not given info',
#   "jetblue we 'd love help shanese bryant-melton hard-working grandmother dc go miami it 's bucket list flyitforward",
#   'united want book multi-city fare have mile 1of 2 flight an option pay 1st flight mile +2nd ump visa thanks',
#   "united when email address/username sign-on available it 's",
#   "united yes i 've waiting four hour one able help",
#   "americanair i thank what i i ca n't get flight hold cancelled flight",
#   'usairways flight scheduled 730pm ... told 150am flight cancelled flightled sitting cold plane 2 hour',
#   'united yes plenty seat available so vicky thomas refuse give one million mile flyer',
#   'united ua63 madrid arrived agent mass confusion sent fro 3 ua employee maryjo rude unhelpful',
#   'usairways americanair terminal e miami still worst smelly airport ever thanks nothing',
#   "united great decision making skill flight ops iah bag make 10 minute connection i n't flight pushed early disappointed",
#   'jetblue when i checked yesterday looked like did something change',
#   'united weighed 45.5 checked bag',
#   'usairways when i check online state status closed what mean a i yet able reach live person ...',
#   'united asked dm ignore please assist changing another flight today- 21 feb fra mco avoiding iad',
#   'americanair americanairlines approach mex .... http //t.co/se57dmjhiw',
#   'united amp finally told couldnt use front plane restrm row7 though myself/others row behind used w/no issue',
#   "americanair earlier flight sap- gt mia amp mia gt new york lga 03.03 i 'm currently booked flight 1504 1102",
#   'united last night waited forever gate someone corporate dispatch forgot call crew unfriendlyskies',
#   "united seriously 's 2015 no wifi 5hr flight cle-sfo 1589 you 're only airline without wifi ...",
#   'united told changed flight im ottawa airport ac cant find reservation whats wrong',
#   "“ jetblue analystdoc unfortunately 's available option current system sorry guy that 's certain fail fix plz",
#   "united n't need apology need bag took 56 minute landing get unacceptable",
#   'americanair see photo b787 scale model amp pn 320008a wheel deflator specified chapter 32 b787 amm http //t.co/kfd4wqrklw',
#   'united flying stl saturday expecting ice amp snow when start looking travel waiver thanks',
#   'americanair thanks getting back but i find airline future',
#   'virginamerica know need spotify stat guiltypleasures',
#   'united i patient luxurious middle seat next delayed flight',
#   "usairways 4 hour tarmac charleston still ca n't get response week unacceptable",
#   "southwestair what 's happened customer service 2 cancelled flightled flight 2 day amp uninformed unapologetic staff nolove cali",
#   'united 777 sfo hnl zero entertainment system youareonyourown',
#   'americanair 3078 overweight pull 2 dozen passenger why luggage seriously',
#   'jetblue disappointed flight back boston pr cancelled flightled rebooked 4 next day delayed one compensation',
#   'united better customer service john wayne airport',
#   "americanair waiting delayed plane sat plane hour waiting late flight passenger that 's b ..",
#   'united a always help communicate customer',
#   "united 're customer service unbelievably bad abysmal i 've phone well 2hrs tonight hung yr ppl 3x",
#   'southwestair 3rd time flying southwest two year have another trip back mx october',
#   'americanair priority baggage evidently mean come last',
#   "united i mention one bag infant car seat amp 've stuck yr poor replacement icy mtn road",
#   'united just thanks checking',
#   "americanair i understand i 'm even put hold say `` try late flightr goodbye ''",
#   "united i wo n't check carry watched handler throw bag -- miss conveyer belt -- sat 10 min http //t.co/lyoocx5msh",
#   "southwestair you rerouted bf 's flight 's diabetic little insulin even though tried change agent would n't",
#   "americanair 's lot talk mia-sfo 20+ year old plane nonewplanes old shame http //t.co/twetpxuppn",
#   "americanair flight dca i need change asap help ca n't get",
#   'united all change way stick premiere 1k loyal customer why make thing harder loyal',
#   "usairways ok ... know door close ~10 minute takeoff stop telling flight leave 20 minute n't boarded",
#   'united i hope see issue return flight tomorrow',
#   'united customer service 👎',
#   'usairways my wife sick 3yr-old-twins i waiting line 2hrs see agent phone agent said nothing til tuesday',
#   'jetblue ruining vacation left right who would thought airline cancelled flight ticket without telling buyer',
#   "southwestair guy 've got something inability check online international flight ... 1/2",
#   'usairways seriously flight delay cinci philly due new ground staff miss connection man uk argue hotel wtf',
#   'united line denver rebook due weather issue do better http //t.co/tmccexyaaq',
#   'usairways how i redeem pas admiral club i 1 free visit barclay card membership and i bring companion',
#   'usairways failingyourcustomer one by one',
#   'jetblue guy continue impress your crew mco gate 4helped family seat issue professional',
#   "southwestair n't charge ticket change fee do incur mysterious `` cost '' incur united",
#   'americanair taking call i need change flight',
#   'usairways flight 1735 sitting fully loaded hour air conditioning barely working',
#   'jetblue dropping passenger small baby 3 infant san juan terminal a unloading baby officer writes ticket 75',
#   'southwestair i continue amazed amazing customer service thank swa',
#   'southwestair hilarious flight attendant vega detroit tonight http //t.co/nw7vx7dgmf',
#   'americanair are people cruel stupid why posting personal email damn internet have u lost mind',
#   'americanair narrowly made standby ... lot snag trip',
#   'southwestair thank thankful feelingtheluv',
#   'americanair took flight yesterday fron tpa-dfw-aus bag went iah today bag went iah-dfw back iah still bag',
#   'americanair one agent helping stagnant line almost 100 customer super',
#   "southwestair pair ticket imaginedragons show atlanta i 'd love go destinationdragons",
#   "southwestair got `` duped '' w/ connection 1st flight sneaky u wo n't give seat earlier flight w/ availability shameful",
#   'southwestair really gon na hear mouth bag situation',
#   "virginamerica what phone number i ca n't find call flight reservation",
#   'usairways thanks it would better gate agent c14 charlotte boarding flight 1791',
#   'jetblue always pleasure ☺️',
#   'usairways usairways disappoints again cancelled flighted flight missed appointment promised refund lie',
#   "united ca n't get anyone deal person cowardly customer service i ca n't looked eye anyone",
#   "americanair something wrong website matter flight i select say 's longer available",
#   'southwestair after multiple attempt i finally able submit late flight last night',
#   "southwestair broke stroller wife baby gate checked they told 's problem calling a list preferred line",
#   'jetblue unfortunately hoping i catch one sometime near future',
#   "jetblue you mean take time write physical letter fraud department n't email telephone right",
#   'americanair trip cut 7 hr short due flight change/massive layovers/ peanut crackers/ asked h2o received 2oz',
#   'united can please follow dm missing bag',
#   "usairways please secure 'footrest shelf business class a330 airplane http //t.co/zl4bvexmcj",
#   'americanair maryella_green received actually thank',
#   'jetblue amagrino cover cost car service waiting time',
#   "americanair now 've cancelled flightled flight first priority ticket bumped you 're losing customer people furious",
#   "americanair connect person without wait 2+ hour hold i still n't able resolve problem",
#   "usairways they 're reservation number none hungary and phone working you make difficult",
#   'southwestair checked right 24hr mark boarding c group kid age 6 amp 8 dnt want split what sld',
#   "jetblue i 'm flight booze served 30 min ... what give lostrevenue angryandsober bachelorpartymishap",
#   "americanair sweetmel if weather bad would n't folk try extra hard communicate ... load bag onto flight 1320 ... ... anything",
#   'americanair 4369. 4 flight using gate w/buses plane awful boarding process hour half late flight',
#   'united staff rather efficient got u solution freaked little limbo air',
#   "united flight vega houston cancelled flighted morning `` due operation '' mean thank god i woke early today",
#   'usairways phl take hour offload bag especially taking 30+ min get jetway get plane landing',
#   "americanair i 'd like apologize gate agent flight aa76 i aware zone 1 nine precious gem",
#   'americanair 4hrs late flightr get call back immediately disconnected',
#   "usairways wo n't waive 200 fee due neptune ca n't use credit w/o paying fee couldnt get destination use tic waivethefee",
#   'is insulting usairways americanair offer `` non required 50 voucher goodwill offering .. at least bag fly round trip',
#   "usairways i ca n't even use return flight home change fee charge expensive forcing purchase new ticket",
#   "united i 'm rebooked line 300 people deep",
#   'usairways cust serv rep unable change reservation system check unaware cancelled flight i got word night',
#   "united give your service terrible if i n't forced use united certain route i never would",
#   'southwestair i get kind update delayed flight boston houston 7:30 really need back home tonight',
#   'southwestair i impression 8 hour delay flight equipment failure compensation offered',
#   "southwestair look like 'on february 19 2015 open schedule sale october 30 2015 know time",
#   "americanair would appreciated just please n't send page long form amp limited character direct email",
#   'usairways email',
#   "united diverted missed connecting flight wa told bag 's way msy if people cared",
#   'united need assistance line door travelling 3 kid',
#   'united 100 i put together serious email issue arose vacation due staff i post',
#   "americanair upon entering plane 2 usairways stewardess `` i water '' `` n't please take seat ''",
#   "jetblue amount money i spent hotel week bc flight cancelled flightlation another flight n't make money lost",
#   'usairways flight 830 clt phl i 1st list.someone else got spot rude employee coach wouldt give id said cute red head',
#   "americanair thanks bummer poor planning part i assume card passbook wo n't work either",
#   'usairways still cricket customer service',
#   "united 1k i 'm always hoping improvement",
#   'americanair merger usairways usairwis cluster inefficiency misinformation when going done',
#   'southwestair much respect',
#   'southwestair really easy local get strip book',
#   'usairways charlotte staff need prayer .... disappointed response mishap ...... lotttttttt pissed people',
#   'southwestair unscheduled aircraft change please better system place worth paid upgrade refund',
#   'united from air another missed cnxn 2day atc went strike belize am now family amp i miss cnxn ewr please see dm',
#   'usairways thanks bad make two day train trip look appealing',
#   "united getting ridiculous now 're missing connection",
#   'united you really clean food coffee stain area around seat new passenger come aboard gross',
#   "united missing flight attendant delayed flight prime example 1 person impact 100 's people hnl gt iah ua252 wastedtime",
#   'usairways americanair call number listed sure next friday i get real live person line http //t.co/8tjuum22dd',
#   'americanair change fee price new ticket ... not logical',
#   "stop madness rt jetblue our fleet 's fleek http //t.co/7x9usbj2fv",
#   'united ok sent u info via dm i appreciate help consideration 😊',
#   "southwestair service rep n't say i dumb tone voice like i known",
#   'usairways im trying get dad wheelchair one answering dulles.we tried call back on.multiple time',
#   "usairways i 've hold approaching 2 hr issue i changed ticket online frustrating",
#   'united thank',
#   'united thanks effort i get earliest though i make complaint refund i losing one business day tomorrow',
#   'usairways lack communication office customer amp yall never update ur system u guy 2 established 4 mess',
#   'jetblue much paid fee plus hotel food change could flown reliable airline no2jetblue',
#   'seriously i want work jetblue social team rt jetblue vincenzolandino http //t.co/eigajyzcw2',
#   "southwestair right we 're delayed i 'm crabby also allow one family member purchase earlybird check hold row",
#   'united guy suck',
#   "united thank person houston could get flight routing newark nj i 'm going sfo",
#   'united lost bag huston leave bahamas cruise today nola buy new stuff customer service non existent',
#   'southwestair thx customer service rep alex patient help reflight booking problem cancelled flighted flight getting u tmrw',
#   'usairways faster way get columbia sc making stay clt night delayed flight',
#   'americanair highly disappointed baggage service merge usairways guy lost 1st bag missing item',
#   "southwestair a-list program complete joke your company value loyal customers.time look another `` go-to '' airliner",
#   'americanair i understand need drain lavatory fearing freezing policy checking boarding smh come ...',
#   "united n't hope nicer flight time try thing right you sold ticket connetion",
#   'southwestair thank thank thank my last attempt win destinationdragons ticket success i could happier',
#   'jetblue i hate 😒 http //t.co/g4wwr6vbrq',
#   'americanair cvgairport get together perfect combination delay cancelled flightlations',
#   "united you may `` dislike delay '' i paid .we agreement i paid got destination certain time",
#   'southwestair trying get cust relation is another use',
#   "jetblue yesterday flight i wanted chicago sale within point range today n't any way guy still honor",
#   'united possible add known traveler number ticket flight booking problem',
#   'virginamerica heyyyy guyyyys .. trying get hour someone call please',
#   "😐 “ jetblue our fleet 's fleek http //t.co/qavvlaxlkl ”",
#   'southwestair thanks opportunity ...',
#   'jetblue disappointed missed connection roc slc reimbursement even tho friend pilot said due atc',
#   'jetblue lipstick pig still pig ur new baggage claim sju disaster no chair 20 mins+ wait baggage fail',
#   "americanair prime ticketed seat get switched aa 343 not sure 's going ...",
#   "“ jetblue our fleet 's fleek http //t.co/g12sn5qsqz ” ... yall better",
#   "jetblue that 's great thank",
#   "americanair usual next flight show time 's suppose leave 5 minute n't boarded",
#   'southwestair the opal dragon book the dragon ali woven murdering way philippine australia http //t.co/c9p2iosphm',
#   "usairways happens n't located",
#   'americanair phone call email cancelled flight flight would lovely',
#   'usairways please thank mellie cae tammy baggage claim clt 4 excellent customer service 2day but i complaint',
#   'united mean within one week filed 2 compensation complaint website',
#   'united thanks help ... got i need issue _austrian i guess i sit awhile longer',
#   'usairways airline rather poor right in slc waiting take wa suppose take 2 hour 3 minute ago',
#   'usairways three hour hold disconnected conf ebhset need home sunday interview',
#   "usairways 's flight 5545 gate agent plane phx b18 nice customer service",
#   'united unfortunately bad experience flying saturday inpolite crew bad delay',
#   'usairways u 728 stated issue plane moving cargo door open plane umm ok. a little strange',
#   'united thanks trying take money without notice in industry cancelled flight service refund issued cont…',
#   "united ca n't leave tarmac .. united 's gate agent agree head count 20 min counting 100 people max epicfailunited",
#   'usairways flight delayed 5 hour no reason given sure love flying airline whatajoke',
#   "united our vacation 's going ruined w/ 3 day rain the change fee 2 u nearly cost original flight can help",
#   'southwestair any way help entry vega event my boyfriend amp i imaginedragons fan since 2009 they awesome',
#   'americanair i thought guy done messing make worse your airline ruin hope dream',
#   'americanair boarded flight 2334 8:30am now 11:40 still sitting runway lot fun',
#   "usairways i waited hold long i n't wait hold forever i never received confirm 1st place help",
#   'united i interviewed yesterday flight attendant i last person recruiter said lost file n came back interview',
#   'united item mine mysteriously ended checked bag ewr yow flight missing black box http //t.co/sjqemdtqma',
#   'united thank been trying two day set',
#   'southwestair wifi shit fix i jump closest bloody fucking emergency exit',
#   'virginamerica jump dallas-austin market dallas_news http //t.co/ewwgi97gdx',
#   "southwestair i n't conference number i spoke courtney texas david finally fixed mine hour",
#   "americanair why n't anyone make better effort retain customer it easy fix i want travel aa",
#   'united premier desk able rebook friend americanair only problem i pay checked bag',
#   "“ jetblue our fleet 's fleek http //t.co/g97habyep5 ” smh",
#   'southwestair guy held flight 330 thank about take mdw oakland thanks',
#   "united flight 211/ord gate agent tried prevent taking onboard bag i 've used 15 year flight crew reasonable",
#   'usairways thank',
#   'usairways success made flight please thank crew 556 great time recovery',
#   "southwestair considered adding `` 'll call back someone free '' feature support line",
#   'southwestair vega i 5 day ago miss warm weather',
#   "united unsmiling rep. told u hotel shuttle come `` like every 15 minute '' breezy 30 min late flightr 're taking cab you going reimburse",
#   'americanair i send trusted traveler id add reservation tsa pre',
#   "americanair thank ... i know 's busy today help would appreciated ...",
#   'jetblue still waiting bag flight 26 it landed hour ago',
#   "usairways 1st reaccommodation delayed flight one amp gate agent still n't mumbled word folk getting anxious",
#   'usairways dude named shaquille desk charlotte incredibly professional helpful vs. crazy angry people tonight',
#   'southwestair kudos adding passbook app i love it',
#   "united worse oh ca n't delayed reason way lon flight cancelled flighted no reason le 2 day returning",
#   "usairways i find funny phlairport responds n't your customer service worst wedontcarebecauseyoupaidalready",
#   'jetblue wtf stuck jfk 2+ hr delay boston cuz u say snow no snow weather map wtf',
#   'jetblue thank you guy awesome',
#   'americanair fat man stuck airplane bathroom',
#   'usairways sorry i meant flight 4420 supposed depart 5:00 say 6:30 what issue',
#   'united i received one previously 11th checked odd said complaint associated e-mail',
#   'jetblue definitely new favorite airline',
#   'united baldordash rebooked arrived 8 hour late flightr last year 9 hr san diego inflight entertainment',
#   "jetblue although n't totally answer i looking i appreciate prompt response",
#   'southwestair i easily get atlanta show i need ticket help',
#   'jetblue whatever lil mint heart desire http //t.co/wmx12f33zc',
#   'americanair message pic sent ...',
#   'americanair thanks',
#   "united `` airport snow removal method 22 ... '' keep good work folk cessna 's become 747 's http //t.co/9v8tmusjvu",
#   'usairways ability switch flight americanair tell bag',
#   "usairways made bahamas work luggage n't i know travel happens anyway i get help/info",
#   'usairways i never fly u airway american i share nightmare story many others know fly',
#   'united delayed 7 hr flight 5721 pit/iad finally board plane sit half hour amp crew hr limit amp deplane unacceptable',
#   'southwestair been hold 90 minute you fly answer phone',
#   'americanair aa 2258 cancelled flightled flight without courtesy notifying u alternative very poor',
#   "usairways 2nd time occurred 3 week i 'm patient i choice antitrust issue",
#   'southwestair hold rebook flight cmh 1.5 hr your rebook website crashed',
#   'virginamerica yes fyi my bff',
#   "jetblue 's delay system n't",
#   "virginamerica i 'm trying check 10:50am ct flight tmm desktop website 's working sort caching bug so",
#   'virginamerica beautiful front-end design right cool still book ticket b/c back-end secure',
#   "united 'll hearing sure",
#   'jetblue annnndddd i booked flight that easy',
#   'americanair i ’ line waiting 40 minute',
#   'usairways flt 1820 2rsw could extended courtsey waiting 2min 4 10 u .... gate closed r face ur fired',
#   'usairways last name pordes',
#   'americanair thanks i actually made connection flight delayed guess delay bad thing http //t.co/xggcntco8m',
#   "americanair i n't know may i also working home thanks nothing",
#   'usairways if i know i left something last flight i literally run make connection i retrieve please',
#   'jetblue offered flight 4/19 i paid changed it.this 2nd time done ruin cruise plan',
#   'united saying customer care report anyone their response humiliating company serf public',
#   'united sitting middle first time .. hope work well',
#   'jetblue airway corporation nasdaq jblu update jetblue say lufthansa ... market bureau http //t.co/apy3zlsquu',
#   'malhoit least got response americanair via twitter i went 0 2 yesterday',
#   'americanair please help aa 2258 monday cancelled flightled can advise reflight booking problem refund have child need make plan',
#   'usairways seat next 19b flight 1943 seattle tray table falling ... http //t.co/haj5lkqjw4',
#   "united flight ua3576 gate b1 and tell ray i somehow made 736 flight iah n't wait 917 one",
#   'usairways comcast airline 2hrs35minonhold',
#   "“ americanair `` jason 'll end missing connection please see dfw agent assistance. ” nope ha n't taken yet still",
#   'southwestair hold 2.5 hour waiting speak someone cancelled flightled flight philly orl',
#   'americanair patrichruben profit maximization top priority nothing else even register dinosaur',
#   "southwestair flying 2 week bringing blanket bc 's freezing 😜",
#   'united great flight pvd smallest plane i ever smoothest landing ever',
#   'americanair thanks she submitted damaged bag complaint online ... anything else goodcustomerservice',
#   'americanair but eagle always late flight',
#   'americanair looking status flight 1388 schedule 5:15 tomorrow morning thank',
#   "hypocrisy rt united gg8929 i 'm sorry 're able offer full refund exchange rate hoping ^kp",
#   'united terrible illogical re-route cancelled flightled connection then made pay check bag then lost bag ual',
#   'united after speaking united customer service rep night flight confirming everything ok reservation ..',
#   'usairways good news got fixed',
#   'usairways word whether flight 1971 seattle charlotte connection held or ...',
#   'southwestair so important accept others swadiversity',
#   'americanair changed aadvantage travel plan amp i called 800-433-7300 get help sea ur busy amp hang what give',
#   'southwestair everyones flight cancelled flightled today deserve 1',
#   'usairways airway joke i never dealt worse service',
#   "jetblue reading nytimes “ jetblue our fleet 's fleek http //t.co/lvirtdtqly ”",
#   "southwestair really unhelpful why ca n't i rebook online http //t.co/n5o43svl8i",
#   'jetblue flight 100 full',
#   'usairways 1-2 rock hit plane in delay never easy day u airway ya never fail let',
#   "jetblue thank i 'm excited fly first time",
#   "united gate definitely not full we parked wheel chocked customer service called `` unmet arrival ''",
#   'southwestair provide direct assistance my colleague i re-book b/c ticket booked via corporate account help',
#   'aww jetblue i guess i need book flight somewhere warm asap any suggestion',
#   'united never flying guy ever the customer service piss poor best',
#   "yes thanks much 💜 “ united whitterbug we see spoke reservation team 've reinstated flight thanks ^ey ”",
#   'usairways americanair anyone answering phone today listening damn message 1:10 minute',
#   'southwestair thank',
#   'americanair beyond redemption jfk baggage claim look like luggage warehouse',
#   'united know two hour u sitting plane bag loaded plane weight',
#   'americanair deplaned 3rd fucking time fuck aa',
#   'united joni great job flight 5653 lax thanks great flight',
#   "americanair i 'm willing hold agent n't helpful keep hanging americanairsucks hiremorepoeple",
#   'united delayed another hour',
#   "usairways `` admiral club '' clt rude ignorant front desk staff ... americanair fallen far ... thanks doug parker",
#   'jetblue booked work added upgrade seat need upgrade receipt',
#   "southwestair hi janet customer service i 'm calling back sitting que 40 min plz pick frustrated",
#   "americanair flight delayed amp i ca n't talk reach anyone customer service high call volume",
#   "united u miss first leg ur flight pay hundred 's keep second leg how much keep earned mile",
#   'united on standby denver delayed confirmed aspen whose flight cancelled flighted day 0 confidence',
#   'jetblue actually flight 1089 1098',
#   "united option co tonight doe n't look like ua5525 make time ua6259 should i reserve hotel room",
#   "southwestair thanks much make cancelled flightlation i 've sent u info",
#   "united i 'm aware flight detail thanks three hour late flight crew could give le shit",
#   'united ua1740 admit clue flight leave denver unfriendlyskies',
#   'jetblue thank jetblue credit nice save',
#   'americanair you lost customer today flight today cancelled flightled i find calling customer service yesterday',
#   'americanair still waiting flight ... i get money back',
#   "united i already emailed i n't know expedient contact please advise thanks",
#   'southwestair flight cancelled flightled ... tried get refund hold can i get flight would departed',
#   "southwestair thank help resolving problem shannon rock even though rhonda n't",
#   "united still n't received response please direct message contact information",
#   'usairways in future better harsh weather preparedness plan so much staff called everything snowballed',
#   'united airline cause missed connection u would think would take whatever step remedy screw',
#   'united poor old united never seem get response right',
#   "usairways americanair nvm bad 's hour half thanks",
#   'usairways 1899 thanks',
#   "usairways i know 're dealing weather phlairport hot mess pls send reinforcement",
#   'southwestair amp sammi_jon3s best friend imaginedragons any chance could get ticket destinationdragons',
#   'americanair thx responding i cant watch 2 min film w/out cutting 4 prolonged prds time beyond frustrating',
#   "united sure missed mark tonight 's redeye lax chicago what mess you better",
#   'united yes awful weather appears i get home',
#   "jetblue 2nd time row flight jfk disaster last time i n't allowed fly stndby 2 hour delay w/out notification",
#   "usairways hold 58 minute need help usair wo n't help",
#   'americanair flight 2934 dfw gsp going cancelled flightled tomorrow',
#   'united flight 1051 2/23 thx',
#   'usairways but good luck getting not cool',
#   'usairways how long departure gate stay open will i make connecting flight 1861 rdu flight 894',
#   "usairways mad i ca n't even believe guy cancelled flight connecting flight i leave first stop amp give useless hotel voucher",
#   'southwestair ridiculous want charge 209 change flight even multiple seat available flight i needed',
#   'southwestair another delay wow',
#   'americanair trying check flight on line working amp agent busy take call',
#   "jetblue 's going 1171 lga-fll .. poor communication gate agent",
#   "southwestair ftw ✈️ hope 'll sing u song flight phoenix today terminal 2 humphrey http //t.co/mavigetbbw",
#   'united ... lie lie lie .... still sitting gate moved inch http //t.co/lulgnweffh',
#   'united i following need follow dm',
#   'usairways americanair total lack cust service mom flying solo w. baby will flying w. am air',
#   "united n't ever print known traveler number ticket because i never get use tsa prescreen i paid",
#   'americanair i still think american airline great ... i would like treated better loyal customer first right',
#   'usairways americanair delay mechanical issue weekend flight ridiculous will tweet long delayed',
#   'united future delay cause 15 hour wait slept night airport ensuring seating choice replacement flight would good',
#   'americanair so break whatever want take responsibility .. too bad customer medium filmcrew chicagotribune wsj nytimes cnn',
#   "usairways i called 25 time redeem mile point ca n't get you advertise mile make hard use",
# ...
#   'jetblue excuse though 3 gate change though',
#   'jetblue i may need i 40 minute layover 15 min delay first flight',
#   'united how i get reimbursed hotel taxi cancelled flightation',
#   'americanair yet receive assistance one agent securing new connection many miss work tomorrow',
#   'usairways british_airways three hour flight delay on phone 45min counting',
#   'americanair 2298 everyone else outstanding',
#   'united i think rough moment w/ bad passenger earlier flight thing got considerably better thanks',
#   'usairways thanks',
#   'americanair i cancelled flightled ticket taking two month ++ refund still waiting',
#   'usairways ’',
#   'usairways shout pilot fc attendant eliz u 673 super strong crosswind landing eliz super job throughout',
#   'united i see coming get aggiemensgolf hawaii 12thman http //t.co/g8dka3edhf',
#   'americanair dfwairport 2 together best part flying',
#   'united late flight future flight train staff better handle emergency situation ground staff customer service',
#   'united oh united much i despise thee',
#   'united airline ceo jeff smisek disloyal loyal worker http //t.co/0cevy3p42b via huffpostbiz',
#   'united 3/10 disappointed service will missing connection hour delay cramped seat at least app good',
#   'americanair sit airport long periolodicly time plane nasty',
#   'united 618 flight houston',
#   'united fuck caring 😢',
#   'southwestair info destinationdragons winner announced amp best friend hoping win thanks',
#   'southwestair thanks',
#   'southwestair tweet weekend/ bad weather close customer relation center process refund cancelled flighted flight',
#   "southwestair missing 6,000 point one account they 're spread four assuming i create account",
#   'united i used committed continentalairlines flyer merger i remember i switched southwestair communicationfail',
#   'united i soon i done article thanks ~tom',
#   "americanair 're finding bc united rebooked u airline realized could n't get u home 're ord",
#   'usairways i gave http //t.co/2edgc6tbls',
#   'usairways ticket couldnt used bc unable get departing dest rsw bc blizzard bos told way use credit 200 fine',
#   ...],
#  ['negative',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'negative',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'positive',
#   'positive',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'positive',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'neutral',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'neutral',
#   'neutral',
#   'negative',
#   'neutral',
#   'positive',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'neutral',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'neutral',
#   'neutral',
#   'negative',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'positive',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'positive',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'neutral',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'neutral',
#   'positive',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'positive',
#   'neutral',
#   'neutral',
#   'neutral',
#   'positive',
#   'positive',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'positive',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'neutral',
#   'positive',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'neutral',
#   'positive',
#   'neutral',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'positive',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'positive',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'neutral',
#   'positive',
#   'neutral',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'positive',
#   'negative',
#   'negative',
#   'positive',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'negative',
#   'neutral',
#   'negative',
#   'neutral',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   'positive',
#   'negative',
#   'negative',
#   'negative',
#   ...])

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y)

# %%
cv = CountVectorizer(ngram_range = (1,2))
a = cv.fit_transform(x_train)
b = cv.transform(x_test)

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

# %%
svc = SVC(kernel = 'rbf', C = 8)
svc.fit(a, y_train)
# Out:
# SVC(C=8)

# %%
lr = LogisticRegression(max_iter=10000)
lr.fit(a,y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
# gnb = GaussianNB()
# gnb.fit(a.toarray(), y_train)
# Out:
# GaussianNB()

# %%
svc.score(b, y_test), lr.score(b, y_test)#, gnb.score(b.toarray(),y_test)
# Out:
# (0.7650273224043715, 0.7799635701275045)

# %%
####Lets optimize

# %%
from sklearn.model_selection import GridSearchCV

# %%
clf = GridSearchCV(svc, {
    'C' : [2,4,6,8]
})
clf.fit(a, y_train)
# Out:
# GridSearchCV(estimator=SVC(C=8), param_grid={'C': [2, 4, 6, 8]})

# %%
df = pd.DataFrame(clf.cv_results_)
df
df[['param_C','rank_test_score']]
# Out:
#   param_C  rank_test_score
# 0       2                3
# 1       4                4
# 2       6                1
# 3       8                2
