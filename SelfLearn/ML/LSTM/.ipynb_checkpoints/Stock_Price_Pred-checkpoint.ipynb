# %%
import yfinance as yf
import pandas as pd

# %%
obj = yf.Ticker('AAPL')

# %%
data= obj.history(period='5y')

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-08-12 00:00:00-04:00   48.346174   48.934700   48.232344   48.554459
# 2019-08-13 00:00:00-04:00   48.685239   51.378402   48.554454   50.610657
# 2019-08-14 00:00:00-04:00   49.203528   49.997914   49.065478   49.104229
# 2019-08-15 00:00:00-04:00   49.276180   49.683059   48.358274   48.859612
# 2019-08-16 00:00:00-04:00   49.474775   50.172287   49.368211   50.012440
# ...                               ...         ...         ...         ...
# 2024-08-06 00:00:00-04:00  205.300003  209.990005  201.070007  207.229996
# 2024-08-07 00:00:00-04:00  206.899994  213.639999  206.389999  209.820007
# 2024-08-08 00:00:00-04:00  213.110001  214.199997  208.830002  213.309998
# 2024-08-09 00:00:00-04:00  212.100006  216.779999  211.970001  216.240005
# 2024-08-12 00:00:00-04:00  216.000000  219.509903  215.600006  217.634094
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-08-12 00:00:00-04:00   89927600        0.0           0.0
# 2019-08-13 00:00:00-04:00  188874000        0.0           0.0
# 2019-08-14 00:00:00-04:00  146189600        0.0           0.0
# 2019-08-15 00:00:00-04:00  108909600        0.0           0.0
# 2019-08-16 00:00:00-04:00  110481600        0.0           0.0
# ...                              ...        ...           ...
# 2024-08-06 00:00:00-04:00   69660500        0.0           0.0
# 2024-08-07 00:00:00-04:00   63516400        0.0           0.0
# 2024-08-08 00:00:00-04:00   47161100        0.0           0.0
# 2024-08-09 00:00:00-04:00   42171700        0.0           0.0
# 2024-08-12 00:00:00-04:00   15319142        0.0           0.0
#
# [1259 rows x 7 columns]

# %%
close_data=data.Close

# %%
close_data.shape
# Out:
# (1259,)

# %%
import matplotlib.pyplot as plt
plt.plot(close_data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
import numpy as np
close_data = np.array(close_data)

# %%
close_data = scaler.fit_transform(close_data.reshape(-1, 1))

# %%
close_data
# Out:
# array([[0.        ],
#        [0.01103907],
#        [0.00295154],
#        ...,
#        [0.88451966],
#        [0.90024993],
#        [0.90773434]])

# %%
tr_size = int(0.65*len(close_data))
te_size = len(close_data) - tr_size

# %%
def create_dataset(data, look_period):
    dataX, dataY = [], []
    for i in range(data.shape[0] - look_period):
        dataX.append(data[i:i+look_period, 0])
        dataY.append(data[i+look_period, 0])
    return np.array(dataX), np.array(dataY)

# %%
x_train, y_train = create_dataset(close_data[:tr_size], 100)
x_test, y_test = create_dataset(close_data[tr_size:], 100)

# %%
##Creating the stacked lSTM model

# %%
import keras
from keras.models import Sequential
from keras.layers import LSTM, Dense

# %%
model = Sequential()

# %%
model.add(LSTM(50, return_sequences= True, input_shape= (100, 1)))
model.add(LSTM(50, return_sequences= True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer = 'adam', metrics = ['accuracy'])
# Out:
# C:\Users\Yash Garg\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.fit(x_train, y_train, epochs = 25, validation_data=(x_test, y_test), batch_size = 64, verbose = 1)
# Out:
# Epoch 1/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.0000e+00 - loss: 0.0993 - val_accuracy: 0.0029 - val_loss: 0.0453
# Epoch 2/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.0000e+00 - loss: 0.0123 - val_accuracy: 0.0029 - val_loss: 0.0040
# Epoch 3/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.0000e+00 - loss: 0.0060 - val_accuracy: 0.0029 - val_loss: 0.0219
# Epoch 4/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.0000e+00 - loss: 0.0033 - val_accuracy: 0.0029 - val_loss: 0.0076
# Epoch 5/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.0000e+00 - loss: 0.0021 - val_accuracy: 0.0029 - val_loss: 0.0036
# Epoch 6/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.0000e+00 - loss: 0.0017 - val_accuracy: 0.0029 - val_loss: 0.0033
# Epoch 7/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.0000e+00 - loss: 0.0018 - val_accuracy: 0.0029 - val_loss: 0.0031
# Epoch 8/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.0000e+00 - loss: 0.0016 - val_accuracy: 0.0029 - val_loss: 0.0028
# Epoch 9/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.0000e+00 - loss: 0.0017 - val_accuracy: 0.0029 - val_loss: 0.0039
# Epoch 10/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.0000e+00 - loss: 0.0016 - val_accuracy: 0.0029 - val_loss: 0.0035
# Epoch 11/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.0000e+00 - loss: 0.0017 - val_accuracy: 0.0029 - val_loss: 0.0044
# Epoch 12/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.0000e+00 - loss: 0.0018 - val_accuracy: 0.0029 - val_loss: 0.0051
# Epoch 13/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.0000e+00 - loss: 0.0017 - val_accuracy: 0.0029 - val_loss: 0.0045
# Epoch 14/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.0000e+00 - loss: 0.0015 - val_accuracy: 0.0029 - val_loss: 0.0041
# Epoch 15/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.0000e+00 - loss: 0.0014 - val_accuracy: 0.0029 - val_loss: 0.0034
# Epoch 16/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.0000e+00 - loss: 0.0014 - val_accuracy: 0.0029 - val_loss: 0.0025
# Epoch 17/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.0000e+00 - loss: 0.0014 - val_accuracy: 0.0029 - val_loss: 0.0019
# Epoch 18/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.0000e+00 - loss: 0.0013 - val_accuracy: 0.0029 - val_loss: 0.0016
# Epoch 19/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.0000e+00 - loss: 0.0014 - val_accuracy: 0.0029 - val_loss: 0.0037
# Epoch 20/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.0000e+00 - loss: 0.0013 - val_accuracy: 0.0029 - val_loss: 0.0027
# Epoch 21/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.0000e+00 - loss: 0.0012 - val_accuracy: 0.0029 - val_loss: 0.0019
# Epoch 22/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.0000e+00 - loss: 0.0012 - val_accuracy: 0.0029 - val_loss: 0.0047
# Epoch 23/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.0000e+00 - loss: 0.0014 - val_accuracy: 0.0029 - val_loss: 0.0022
# Epoch 24/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.0000e+00 - loss: 0.0011 - val_accuracy: 0.0029 - val_loss: 0.0035
# Epoch 25/25
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.0000e+00 - loss: 0.0011 - val_accuracy: 0.0029 - val_loss: 0.0019

# %%
train_predict = model.predict(x_train)
test_predict = model.predict(x_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
test_predict = scaler.inverse_transform(test_predict)
train_predict = scaler.inverse_transform(train_predict)

# %%
y_test = scaler.inverse_transform([y_test])
y_test
# Out:
# array([[164.52746582, 162.66989136, 163.56391907, 160.95141602,
#         159.72961426, 159.0342865 , 164.457901  , 164.11026001,
#         164.13012695, 165.36187744, 166.5141449 , 165.54067993,
#         163.92150879, 164.22946167, 162.67982483, 162.66989136,
#         167.28894043, 168.55050659, 168.46109009, 167.41809082,
#         166.33534241, 164.68638611, 172.41461182, 172.34506226,
#         170.62658691, 172.40464783, 172.59339905, 171.65837097,
#         171.16101074, 171.16101074, 171.77772522, 174.1252594 ,
#         174.23469543, 173.27975464, 170.65370178, 170.93222046,
#         172.07617188, 174.50325012, 176.36338806, 176.31365967,
#         179.1386261 , 179.99407959, 178.6313324 , 178.26329041,
#         176.88063049, 179.61610413, 180.00405884, 182.8190918 ,
#         182.34162903, 182.97825623, 185.02735901, 183.94313049,
#         184.03263855, 182.98820496, 186.01213074, 185.69381714,
#         184.29129028, 187.06652832, 188.25024414, 188.58843994,
#         192.9453125 , 191.44329834, 190.3192749 , 190.79672241,
#         189.67268372, 187.6136322 , 187.08642578, 188.76750183,
#         189.53344727, 189.68264771, 192.96522522, 192.70658875,
#         194.0693512 , 192.10977173, 190.92604065, 191.73176575,
#         192.59713745, 193.47251892, 192.19927979, 194.79548645,
#         195.41220093, 194.5766449 , 191.56266785, 190.16009521,
#         181.02861023, 177.90519714, 178.85015869, 177.24867249,
#         177.02984619, 177.08961487, 178.7530365 , 176.75094604,
#         175.87442017, 173.31452942, 173.80262756, 175.14727783,
#         176.53179932, 180.40647888, 175.68516541, 177.90637207,
#         179.48016357, 183.39465332, 186.91075134, 187.12989807,
#         188.71365356, 188.9526825 , 182.18943787, 176.86050415,
#         177.47805786, 178.65341187, 175.60548401, 173.52371216,
#         175.04768372, 174.32054138, 177.26890564, 178.36456299,
#         174.79867554, 173.24479675, 174.10142517, 175.38633728,
#         171.28257751, 169.7585907 , 170.01757812, 170.53553772,
#         173.06550598, 171.72084045, 172.97587585, 174.22096252,
#         176.79078674, 178.28488159, 177.6872406 , 179.0916748 ,
#         179.99809265, 178.14543152, 178.01593018, 176.45211792,
#         175.14727783, 174.76878357, 172.19895935, 172.31848145,
#         172.75674438, 170.42597961, 166.23254395, 167.55731201,
#         169.61912537, 170.09725952, 173.28465271, 176.87046814,
#         175.95410156, 178.52394104, 181.10374451, 182.16950989,
#         181.69142151, 185.91027832, 184.31448364, 186.94755554,
#         187.51605225, 189.21160889, 189.19165039, 190.94702148,
#         190.1391449 , 190.80740356, 189.47090149, 189.29136658,
#         189.89976501, 188.8724823 , 189.45095825, 190.73757935,
#         188.93231201, 192.91184998, 191.81474304, 193.7596283 ,
#         195.19584656, 192.67248535, 194.19847107, 197.43992615,
#         197.58952332, 197.0509491 , 195.37536621, 196.42260742,
#         194.31814575, 194.16851807, 193.09138489, 192.54281616,
#         192.64254761, 193.07142639, 192.02418518, 185.15228271,
#         183.76593018, 181.43209839, 180.70399475, 185.07249451,
#         184.65359497, 185.70085144, 185.10241699, 185.43154907,
#         183.14756775, 182.20005798, 188.13442993, 191.05673218,
#         193.38059998, 194.66722107, 193.98899841, 193.65988159,
#         191.91447449, 191.22627258, 187.54597473, 183.9155426 ,
#         186.36909485, 185.36174011, 187.18692017, 188.80267334,
#         188.91238403, 187.82525635, 188.59420776, 186.89649963,
#         184.78935242, 183.90055847, 183.61096191, 182.06304932,
#         181.31407166, 182.07305908, 184.12026978, 182.27278137,
#         180.91462708, 182.38262939, 181.17425537, 180.50517273,
#         179.41665649, 174.86282349, 169.88957214, 168.89091492,
#         168.77108765, 170.49873352, 172.51600647, 172.99534607,
#         170.89820862, 172.76567078, 172.38618469, 173.48469543,
#         175.8414917 , 178.42799377, 171.13787842, 172.04664612,
#         170.61859131, 169.48013306, 173.07524109, 171.24772644,
#         169.79969788, 168.61129761, 169.42019653, 168.59133911,
#         169.35029602, 168.22183228, 169.44017029, 167.55273437,
#         174.80290222, 176.31086731, 172.45608521, 169.15057373,
#         167.77244568, 166.81373596, 164.77650452, 165.61535645,
#         166.67391968, 168.7910614 , 169.65988159, 169.07067871,
#         173.26498413, 170.09928894, 169.07067871, 172.79562378,
#         183.13160706, 181.46388245, 182.15292358, 182.49247742,
#         184.32000732, 183.05000305, 186.27999878, 187.42999268,
#         189.72000122, 189.83999634, 189.86999512, 191.03999329,
#         192.3500061 , 190.8999939 , 186.88000488, 189.97999573,
#         189.99000549, 190.28999329, 191.28999329, 192.25      ,
#         194.02999878, 194.3500061 , 195.86999512, 194.47999573,
#         196.88999939, 193.11999512, 207.1499939 , 213.07000732,
#         214.24000549, 212.49000549, 216.66999817, 214.28999329,
#         209.67999268, 207.49000549, 208.13999939, 209.07000732,
#         213.25      , 214.1000061 , 210.61999512, 216.75      ,
#         220.27000427, 221.55000305, 226.33999634, 227.82000732,
#         228.67999268, 232.97999573, 227.57000732, 230.53999329,
#         234.3999939 , 234.82000732, 228.88000488, 224.17999268,
#         224.30999756, 223.96000671, 225.00999451, 218.53999329,
#         217.49000549, 217.96000671, 218.24000549, 218.80000305,
#         222.08000183, 218.36000061, 219.86000061, 209.27000427,
#         207.22999573, 209.82000732, 213.30999756, 216.24000549,
#         217.63409424]])

# %%
test_predict.shape, y_test.shape
# Out:
# ((341, 1), (1, 341))

# %%
plt.plot(test_predict)

# %%
temp = [[i] for i in y_test[0]]

# %%
temp = np.array(temp)
temp.shape
# Out:
# (341, 1)

# %%
y_test = temp

# %%
plt.plot(y_test)
plt.plot(test_predict)

# %%
y_train = scaler.inverse_transform(y_train.reshape(y_train.shape[0], 1))

# %%
plt.plot(y_train)
plt.plot(train_predict)
plt.plot(y_test)
plt.plot(test_predict)

# %%
y_train = [i[0] for i in y_train]

# %%
train_predict = [i[0] for i in train_predict]
y_test = [i[0] for i in y_test]
test_predict = [i[0] for i in test_predict]

# %%
given = y_train + y_test

# %%
got = train_predict + test_predict

# %%
plt.plot(given)
plt.plot(got)
