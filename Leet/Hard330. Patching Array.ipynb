# %%
nums = [1,2,32]
n = 2147483647
arrofsums = []
AOP = []

for i in range(len(nums)):
    for j in range(i+1,len(nums)+1):
        k = sum(nums[i:j])
        if k in arrofsums:
            continue
        else:
            arrofsums.append(k)

print(arrofsums, 'AOS line 13')

# narr = [i for i in range(1,n+1)]

g = 1 + 10000*(n//10000)

for i in range(1,n+1,g): #narr
    if i not in arrofsums:
        AOP += [i]
if AOP == []:
    print(0)
i = 0

print(AOP,' AOP')

while True:
    if 2**i >= AOP[len(AOP)-1]:
        break
    i+=1
ref = [2**j for j in range(i)] ############

if max(AOP) > max(ref):
    ref += [ref[len(ref)-1]*2]

refdic = {2**j:j for j in range(i)}

print(ref,' ref')

print(refdic,' refdic')

diffref = []
for j in range(len(AOP)):
    for k in range(len(ref)):
    Ye    if AOP[j] == ref[k]:
            break
        if ref[k] > AOP[j]:
            diff = AOP[j] - ref[k-1]
            if diff not in diffref:
                diffref += [diff]
            break

print(diffref,' diffref')

for i in refdic:
    if max(diffref) < i:
        ans = refdic[i]
        break

print(ans, ' before removal')        

for i in nums:
    if i in ref:
        ans-=1

print(ans,' ans')
# Out:
# [1, 3, 35, 2, 34, 32] AOS line 13
# [2147480002]  AOP
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 536870912, 1073741824, 2147483648]  ref
# {1: 0, 2: 1, 4: 2, 8: 3, 16: 4, 32: 5, 64: 6, 128: 7, 256: 8, 512: 9, 1024: 10, 2048: 11, 4096: 12, 8192: 13, 16384: 14, 32768: 15, 65536: 16, 131072: 17, 262144: 18, 524288: 19, 1048576: 20, 2097152: 21, 4194304: 22, 8388608: 23, 16777216: 24, 33554432: 25, 67108864: 26, 134217728: 27, 268435456: 28, 536870912: 29, 1073741824: 30}  refdic
# [1073738178]  diffref
# 30  before removal
# 27  ans

# %%
nums = [1,2,32]
n = 2147483647
arrofsums = []
AOP = []

for i in range(len(nums)):
    for j in range(i+1,len(nums)+1):
        k = sum(nums[i:j])
        if k in arrofsums:
            continue
        else:
            arrofsums.append(k)

print(arrofsums, 'AOS line 13')

# narr = [i for i in range(1,n+1)]

g = 1 + 10000*(n//10000)

for i in range(1,n+1,g): #narr
    if i not in arrofsums:
        AOP += [i]
if AOP == []:
    print(0)
i = 0

print(AOP,' AOP')

while True:
    if 2**i >= AOP[len(AOP)-1]:
        break
    i+=1
ref = [2**j for j in range(i)] ############

if max(AOP) > max(ref):
    ref += [ref[len(ref)-1]*2]

refdic = {2**j:j for j in range(i)}

print(ref,' ref')

print(refdic,' refdic')

diffref = []
for j in range(len(AOP)):
    for k in range(len(ref)):
        if AOP[j] == ref[k]:
            break
        if ref[k] > AOP[j]:
            diff = AOP[j] - ref[k-1]
            if diff not in diffref:
                diffref += [diff]
            break

print(diffref,' diffref')

for i in refdic:
    if max(diffref) < i:
        ans = refdic[i]
        break

print(ans, ' before removal')        

for i in nums:
    if i in ref:
        ans-=1

print(ans,' ans')
# Out:
# [1, 3, 35, 2, 34, 32] AOS line 13
# [2147480002]  AOP
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 536870912, 1073741824, 2147483648]  ref
# {1: 0, 2: 1, 4: 2, 8: 3, 16: 4, 32: 5, 64: 6, 128: 7, 256: 8, 512: 9, 1024: 10, 2048: 11, 4096: 12, 8192: 13, 16384: 14, 32768: 15, 65536: 16, 131072: 17, 262144: 18, 524288: 19, 1048576: 20, 2097152: 21, 4194304: 22, 8388608: 23, 16777216: 24, 33554432: 25, 67108864: 26, 134217728: 27, 268435456: 28, 536870912: 29, 1073741824: 30}  refdic
# [1073738178]  diffref
# 30  before removal
# 27  ans
